# %%
import time
import json
import requests


def get_landing(page=0):
	url='https://landing-sb.prdasbb18a1.com/zh-cn/Service/CentralService?GetData&ts='+str(int(time.time()*1000))

	ss = {
		'today': '/zh-cn/sports/football/matches-by-date/today/full-time-asian-handicap-and-over-under',		# 今日赛事
		'tomorrow': '/zh-cn/sports/football/matches-by-date/tomorrow/full-time-asian-handicap-and-over-under',	# 明日赛事
		'all': '/zh-cn/sports/football/competition/full-time-asian-handicap-and-over-under',					# 所有赛事
		}

	headers = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.132 Safari/537.36'}

	post_data = {
		'CompetitionID': -1,
		'IsEventMenu': False,
		'IsFirstLoad': True,
		'LiveCenterEventId': 0,
		'LiveCenterSportId': 0,
		'SportID': 1,
		'VersionF': -1,
		'VersionH': 0,
		'VersionL': -1,
		'VersionS': -1,
		'VersionT': -1,
		'VersionU': 0,
		'oIsFirstLoad': True,
		'oIsInplayAll': False,
		'oOddsType': 0,
		'oPageNo': page,
		'oSortBy': 1,
		'reqUrl': ss['tomorrow'],
	}





	d = requests.post(url,data=post_data,headers=headers).text
	d = json.loads(d)


	# 获得分类
	# res = []
	# res_dt = {}

	# for i in d['lpd']['psm']['psmd']:
	# 	name = i['sen']
	# 	yname = i['sn']
	# 	for j in i['puc']:
	# 		t_name = j['cn']
	# 		for v in j['ces']:
	# 			res.append((name,yname,t_name,v['at'],v['eid'],v['en'],v['esd'],v['est'],v['ht']))
	# 			res_dt[v['eid']] = (name,yname,t_name,v['at'],v['eid'],v['en'],v['esd'],v['est'],v['ht'])



	res_pl = []

	for i in d['mod']['d']:
		name = i['n']
		yname = i['en']
		for j in i['c']:
			t_name = j['n']
			for v in j['e']:
				x2st = v['o'].get('1x21st',())
				if x2st:
					x2st = (float(x2st[1]),float(x2st[3]),float(x2st[5]))
				x1x = v['o'].get('1x2',())
				if x1x:
					x1x = (float(x1x[1]),float(x1x[3]),float(x1x[5]))
				res_pl.append((name,yname,t_name,v['k'],v['edt'],v['i'][0],v['i'][1],{'1x21st':x2st,'1x2':x1x}))

	return res_pl


def get_marathonbet():

	url = 'https://www.marathonbet.com/zh/betting/Football/?page=0&pageAction=getPage&_='+str(int(time.time()*1000))
	d = requests.get(url).text
	d = json.loads(d)



land = get_landing(0)
print(land)
# Out:
# [('足球', 'football', '国际友谊赛', 3065085, '2019-03-20T15:45:00', '德国', '塞尔维亚', {'1x21st': (1.98, 5.8, 2.37), '1x2': (1.41, 7.2, 4.9)}), ('足球', 'football', '国际友谊赛', 3065087, '2019-03-20T15:45:00', '威尔斯', '千里达及多巴哥', {'1x21st': (1.58, 11.5, 2.62), '1x2': (1.16, 19.0, 7.2)}), ('足球', 'football', '德国丙组联赛', 3060898, '2019-03-20T14:00:00', '翁特哈兴', '科特布斯', {'1x21st': (2.51, 4.1, 2.1), '1x2': (1.93, 3.45, 3.4)}), ('足球', 'football', '丹麦甲组联赛', 3075981, '2019-03-20T14:00:00', '宁比', '锡尔克堡', {'1x21st': (3.2, 2.87, 2.17), '1x2': (2.67, 2.29, 3.45)}), ('足球', 'football', '埃及超级联赛', 3068776, '2019-03-20T13:00:00', '阿拉伯建筑', '扎马雷克', {'1x21st': (5.4, 2.35, 1.96), '1x2': (5.0, 1.58, 3.45)}), ('足球', 'football', '南美洲球会杯', 3066298, '2019-03-20T20:30:00', '圣塔菲联', '瓦伦独立', {'1x21st': (2.4, 5.9, 1.87), '1x2': (1.62, 5.6, 3.05)}), ('足球', 'football', '巴西圣保罗州甲组一联赛', 3061959, '2019-03-20T20:30:00', '伊图阿诺SP', '哥连泰斯SP', {'1x21st': (), '1x2': (3.45, 2.02, 2.97)}), ('足球', 'football', '巴西圣保罗州甲组一联赛', 3061961, '2019-03-20T20:30:00', '圣卡坦奴SP', '圣保罗SP', {'1x21st': (), '1x2': (4.0, 1.77, 3.25)}), ('足球', 'football', '巴西圣保罗州甲组一联赛', 3061962, '2019-03-20T20:30:00', '博塔福格SP', '山度士SP', {'1x21st': (), '1x2': (3.75, 1.83, 3.25)}), ('足球', 'football', '巴西卡德里那斯甲组联赛', 3062180, '2019-03-20T19:00:00', '乔沛高恩斯SC', '图坝奥SC', {'1x21st': (1.84, 6.0, 2.26), '1x2': (1.33, 6.1, 4.2)}), ('足球', 'football', '巴西卡德里那斯甲组联赛', 3062182, '2019-03-20T19:30:00', '麦罗波利塔诺SC', '费古伦斯SC', {'1x21st': (5.2, 1.96, 2.22), '1x2': (5.4, 1.4, 3.95)}), ('足球', 'football', '巴西卡德里那斯甲组联赛', 3062181, '2019-03-20T20:30:00', '阿瓦伊SC', '马施利奥迪亚斯SC', {'1x21st': (2.07, 5.4, 2.06), '1x2': (1.44, 5.5, 3.65)}), ('足球', 'football', '意大利丙组联赛', 3065986, '2019-03-20T09:30:00', '弗兰卡维拉', '维泰贝斯卡斯特伦斯', {'1x21st': (3.0, 3.6, 1.97), '1x2': (2.25, 2.83, 3.1)}), ('足球', 'football', '意大利丙组联赛', 3065987, '2019-03-20T09:30:00', '波坦察', '斯库拉勒恩兹奥', {'1x21st': (2.73, 4.2, 1.94), '1x2': (2.01, 3.4, 3.0)})]

# %%
import pandas as pd
pd.DataFrame(land)
# Out:
#      0         1            2        3                    4         5  \
# 0   足球  football        国际友谊赛  3065085  2019-03-20T15:45:00        德国
# 1   足球  football        国际友谊赛  3065087  2019-03-20T15:45:00       威尔斯
# 2   足球  football       德国丙组联赛  3060898  2019-03-20T14:00:00      翁特哈兴
# 3   足球  football       丹麦甲组联赛  3075981  2019-03-20T14:00:00        宁比
# 4   足球  football       埃及超级联赛  3068776  2019-03-20T13:00:00     阿拉伯建筑
# 5   足球  football       南美洲球会杯  3066298  2019-03-20T20:30:00      圣塔菲联
# 6   足球  football  巴西圣保罗州甲组一联赛  3061959  2019-03-20T20:30:00    伊图阿诺SP
# 7   足球  football  巴西圣保罗州甲组一联赛  3061961  2019-03-20T20:30:00    圣卡坦奴SP
# 8   足球  football  巴西圣保罗州甲组一联赛  3061962  2019-03-20T20:30:00    博塔福格SP
# 9   足球  football  巴西卡德里那斯甲组联赛  3062180  2019-03-20T19:00:00   乔沛高恩斯SC
# 10  足球  football  巴西卡德里那斯甲组联赛  3062182  2019-03-20T19:30:00  麦罗波利塔诺SC
# 11  足球  football  巴西卡德里那斯甲组联赛  3062181  2019-03-20T20:30:00     阿瓦伊SC
# 12  足球  football      意大利丙组联赛  3065986  2019-03-20T09:30:00     弗兰卡维拉
# 13  足球  football      意大利丙组联赛  3065987  2019-03-20T09:30:00       波坦察
#
#             6                                                  7
# 0        塞尔维亚  {'1x21st': (1.98, 5.8, 2.37), '1x2': (1.41, 7....
# 1     千里达及多巴哥  {'1x21st': (1.58, 11.5, 2.62), '1x2': (1.16, 1...
# 2        科特布斯  {'1x21st': (2.51, 4.1, 2.1), '1x2': (1.93, 3.4...
# 3        锡尔克堡  {'1x21st': (3.2, 2.87, 2.17), '1x2': (2.67, 2....
# 4        扎马雷克  {'1x21st': (5.4, 2.35, 1.96), '1x2': (5.0, 1.5...
# 5        瓦伦独立  {'1x21st': (2.4, 5.9, 1.87), '1x2': (1.62, 5.6...
# 6      哥连泰斯SP          {'1x21st': (), '1x2': (3.45, 2.02, 2.97)}
# 7       圣保罗SP           {'1x21st': (), '1x2': (4.0, 1.77, 3.25)}
# 8       山度士SP          {'1x21st': (), '1x2': (3.75, 1.83, 3.25)}
# 9       图坝奥SC  {'1x21st': (1.84, 6.0, 2.26), '1x2': (1.33, 6....
# 10     费古伦斯SC  {'1x21st': (5.2, 1.96, 2.22), '1x2': (5.4, 1.4...
# 11  马施利奥迪亚斯SC  {'1x21st': (2.07, 5.4, 2.06), '1x2': (1.44, 5....
# 12  维泰贝斯卡斯特伦斯  {'1x21st': (3.0, 3.6, 1.97), '1x2': (2.25, 2.8...
# 13    斯库拉勒恩兹奥  {'1x21st': (2.73, 4.2, 1.94), '1x2': (2.01, 3....
