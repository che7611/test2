# %%
# %matplotlib inline

from pytdx.hq import TdxHq_API
from pytdx.params import TDXParams
import pymysql
import pandas as pd
import matplotlib.pyplot as plt
import scipy as sp
import numpy as np
import datetime as dt
from matplotlib.lines import TICKLEFT, TICKRIGHT, Line2D
from matplotlib.patches import Rectangle


api = TdxHq_API()
if api.connect('119.147.212.81', 7709):
    data1=api.get_history_minute_time_data(TDXParams.MARKET_SH, '600300', 20161209)
    print("OK")
# Out:
# OK

# %%
api.connect('119.147.212.81', 7709)
api.get_and_parse_block_info(TDXParams.BLOCK_SZ)
shList=api.get_security_list(1, 0)
sh_df=api.to_df(shList)
szList=api.get_security_list(0, 0)
sz_df=api.to_df(szList)
sz_df
# Out:
#        code  volunit  decimal_point    name     pre_close
# 0    395001      100              2    主板Ａ股  4.620000e+02
# 1    395002      100              2    主板Ｂ股  2.880000e+02
# 2    395003      100              2     中小板  9.290000e+02
# 3    395004      100              2     创业板  7.490000e+02
# 4    395005      100              2    存托凭证  5.877472e-39
# 5    395011      100              2    封闭基金  3.276850e+04
# 6    395012      100              2    ＬＯＦｓ  2.390000e+02
# 7    395013      100              2    ＥＴＦｓ  4.160000e+02
# 8    395014      100              2    分级基金  2.240000e+02
# 9    395021      100              2   可 转 债  7.800000e+01
# 10   395022      100              2     企业债  1.544000e+03
# 11   395024      100              2     公司债  6.000000e+02
# 12   395031      100              2      国债  3.410000e+03
# 13   395032      100              2    债券回购  2.640000e+02
# 14   395041      100              2    股票权证  5.877472e-39
# 15   395099      100              2   总 成 交  2.188000e+03
# 16   399001      100              2    深证成指  1.043508e+04
# 17   399002      100              2    深成指R  1.262438e+04
# 18   399003      100              2    成份Ｂ指  5.632097e+03
# 19   399004      100              2  深证100R  5.594180e+03
# 20   399005      100              2    中小板指  6.574228e+03
# 21   399006      100              2    创业板指  1.726636e+03
# 22   399007      100              2   深证300  4.397625e+03
# 23   399008      100              2   中小300  1.308262e+03
# 24   399009      100              2   深证200  4.214599e+03
# 25   399010      100              2   深证700  6.502871e+03
# 26   399011      100              2  深证1000  5.004756e+03
# 27   399012      100              2   创业300  2.556838e+03
# 28   399013      100              2    深市精选  4.769309e+03
# 29   399015      100              2    中小创新  2.135342e+03
# ..      ...      ...            ...     ...           ...
# 970  002167      100              2    东方锆业  7.380000e+00
# 971  002168      100              2    惠程科技  7.760000e+02
# 972  002169      100              2    智光电气  5.770000e+00
# 973  002170      100              2    芭田股份  4.630000e+00
# 974  002171      100              2    楚江新材  6.930000e+00
# 975  002172      100              2    澳洋健康  5.900000e+00
# 976  002173      100              2    创新医疗  4.080375e+02
# 977  002174      100              2    游族网络  2.367000e+01
# 978  002175      100              2    东方网络  5.610000e+00
# 979  002176      100              2    江特电机  6.390000e+00
# 980  002177      100              2    御银股份  6.990000e+00
# 981  002178      100              2    延华智能  5.190000e+00
# 982  002179      100              2    中航光电  1.721200e+02
# 983  002180      100              2     纳思达  2.927000e+01
# 984  002181      100              2   粤 传 媒  6.010000e+00
# 985  002182      100              2    云海金属  1.840425e+02
# 986  002183      100              2   怡 亚 通  6.500000e+00
# 987  002184      100              2    海得控制  1.560047e+03
# 988  002185      100              2    华天科技  5.660000e+00
# 989  002186      100              2   全 聚 德  1.416010e+03
# 990  002187      100              2    广百股份  4.400225e+02
# 991  002188      100              2   *ST巴士  4.680000e+00
# 992  002189      100              2    利达光电  2.781000e+01
# 993  002190      100              2   *ST集成  2.034000e+01
# 994  002191      100              2    劲嘉股份  1.832045e+03
# 995  002192      100              2    融捷股份  3.049000e+01
# 996  002193      100              2    如意集团  8.880125e+02
# 997  002194      100              2   *ST凡谷  1.809000e+01
# 998  002195      100              2    二三四五  6.190000e+00
# 999  002196      100              2    方正电机  6.670000e+00
#
# [1000 rows x 5 columns]

# %%
print(api.get_finance_info(0, '000001'))
# Out:
# OrderedDict([('market', 0), ('code', '000001'), ('liutongguben', 17170246250.0), ('province', 18), ('industry', 1), ('updated_date', 20190402), ('ipo_date', 19910403), ('zongguben', 17170411250.0), ('guojiagu', 1801990000.0), ('faqirenfarengu', 231890000000.0), ('farengu', 1057860000000.0), ('bgu', 0.0), ('hgu', 0.0), ('zhigonggu', 13899.999856948853), ('zongzichan', 34185920000000.0), ('liudongzichan', 0.0), ('gudingzichan', 108990000000.0), ('wuxingzichan', 47710000000.0), ('gudongrenshu', 429409.0), ('liudongfuzhai', 0.0), ('changqifuzhai', 0.0), ('zibengongjijin', 564650000000.0), ('jingzichan', 2400420000000.0), ('zhuyingshouru', 1167160000000.0), ('zhuyinglirun', 0.0), ('yingshouzhangkuan', 0.0), ('yingyelirun', 323050000000.0), ('touzishouyu', 91860000000.0), ('jingyingxianjinliu', -573230000000.0), ('zongxianjinliu', 230800000000.0), ('cunhuo', 0.0), ('lirunzonghe', 322310000000.0), ('shuihoulirun', 248180000000.0), ('jinglirun', 248180000000.0), ('weifenpeilirun', 950370000000.0), ('meigujingzichan', 12.819999694824219), ('baoliu2', 12.0)])

# %%
def GetAllHis(stock,mk=1):
    data=[]
    for i in range(10):
        data+=api.get_index_bars(9,mk,stock,(9-i)*800,800)
    df=api.to_df(data)
    return df

# %%
api.connect('119.147.212.81', 7709)
z500=GetAllHis('000905')
sh=GetAllHis('000001')
sh50=GetAllHis('000016')
hs300=GetAllHis('000300')
sz=GetAllHis('399001',mk=0)
sz05=GetAllHis('399005',mk=0)
sz06=GetAllHis('399006',mk=0)
print(len(z500),len(sh),len(sh50),len(hs300),len(sz),len(sz05),len(sz06))
# Out:
# 2974 6922 3711 3468 6867 3212 2154

# %%
cnt=min(len(sh),len(hs300))
vv1=sh.tail(cnt)['close'].values
vv2=hs300['close'].values
res=round(np.corrcoef(vv1,vv2)[0][1],3)
vv1a=sz.tail(cnt)['close'].values
res4=round(np.corrcoef(vv1a,vv2)[0][1],3)

cnt=min(len(sh),len(z500))
vv3=sh.tail(cnt)['close'].values
vv4=z500['close'].values
res1=round(np.corrcoef(vv3,vv4)[0][1],3)

cnt=min(len(sh),len(sh50))
vv5=sh.tail(cnt)['close'].values
vv6=sh50['close'].values
res2=round(np.corrcoef(vv5,vv6)[0][1],3)

cnt=min(len(sh),len(sz))
vv7=sh.tail(cnt)['close'].values
vv8=sz['close'].values
res3=round(np.corrcoef(vv7,vv8)[0][1],3)

print("sh:hs300 corr:",res)
print("sh:z500 corr:",res1)
print("sh:sh50 corr:",res2)
print("sh:sz corr:",res3)
print("sz:hs300 corr:",res4)
# Out:
# sh:hs300 corr: 0.968
# sh:z500 corr: 0.549
# sh:sh50 corr: 0.974
# sh:sz corr: 0.956
# sz:hs300 corr: 0.933

# %%
fig = plt.figure(figsize=(30, 12))
ax = fig.add_subplot(111)
plt.plot(vv3,c='r')
plt.plot(vv4,c='b')
ax2 = ax.twinx()
plt.plot(vv4-vv3)

# %%
plt.plot(vv2-vv1);
plt.axhline((vv1-vv2).mean(), color="red", linestyle="--");
plt.xlabel("Time"); plt.ylabel("Price");
plt.legend(["Y-X", "Mean"]);

# %%
from statsmodels.tsa.stattools import adfuller

a3=vv2-vv1
adftest = adfuller(a3)#使用 adf 单位根检验平稳性 


result = pd.Series(adftest[0:4], index=['Test Statistic','p-value','Lags Used','Number of Observations Used'])


for key,value in adftest[4].items():
    result['Critical Value (%s)'%key] = value


print(result)
# Out:
# Test Statistic                   -1.466707
# p-value                           0.549912
# Lags Used                        26.000000
# Number of Observations Used    3428.000000
# Critical Value (1%)              -3.432259
# Critical Value (5%)              -2.862384
# Critical Value (10%)             -2.567219
# dtype: float64

# %%
# rolling_correlation_cn = 
import pandas as pd

rolling_correlation_cn.plot()
plt.xlabel('Day')
plt.ylabel('New 60-day Rolling Correlation')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-522-9e459e6685f1> in <module>()
#       2 import pandas as pd
#       3
# ----> 4 rolling_correlation_cn.plot()
#       5 plt.xlabel('Day')
#       6 plt.ylabel('New 60-day Rolling Correlation')
#
# NameError: name 'rolling_correlation_cn' is not defined

# %%
rolling_correlation_cn = pd.rolling_correlation_cn

# %%
rolling_correlation_cn = pd.rolling_correlation_cn

# %%
#------calc corrcoef 相关性
#匹配的K线个数
df1=sh
length=300
vv1=df1.tail(length)['close'].values
vv2=df1['close'].values
rows=len(vv2)

maxCorr=0

resList=[]
# dt1=dt.datetime.now
for i in range(0,rows-length*2):
    vv3=vv2[i:length+i]
    corr=round(np.corrcoef(vv1,vv3)[0][1],3)
    resList.append(corr)


df_corr=pd.DataFrame(resList)
df_corr.columns=['Corr']
df_corr.sort_values('Corr',ascending=False,inplace=True)

newList=[]
diff=60
for row in df_corr.iterrows():
    index=row[0]
    insert=True
    for i in newList:
        if i> index-diff and i< index+diff:
            insert=False
    if insert:
        newList.append(index)
        
df_res=df_corr.loc[newList]
df_res['datetime']=df_res.apply(lambda x:sh.iloc[x.name]['datetime'],axis=1)
df_res.head(20)
# Out:
#        Corr          datetime
# 4196  0.878  2008-01-25 15:00
# 2572  0.836  2001-05-14 15:00
# 4960  0.816  2011-03-21 15:00
# 670   0.811  1993-08-05 15:00
# 3416  0.797  2004-11-10 15:00
# 3347  0.776  2004-07-29 15:00
# 4135  0.752  2007-10-30 15:00
# 3221  0.728  2004-01-16 15:00
# 5981  0.726  2015-06-03 15:00
# 1823  0.707  1998-04-03 15:00
# 4256  0.702  2008-04-28 15:00
# 5125  0.692  2011-11-21 15:00
# 4609  0.667  2009-10-09 15:00
# 2512  0.655  2001-02-12 15:00
# 2767  0.653  2002-03-07 15:00
# 537   0.635  1993-02-01 15:00
# 4900  0.632  2010-12-17 15:00
# 1119  0.593  1995-05-18 15:00
# 6042  0.587  2015-08-28 15:00
# 5408  0.572  2013-01-18 15:00

# %%
# fig = plt.figure(figsize=(30, 12))
# ax = fig.add_subplot(111)
DrawIndex(4196,500,500)

# %%
add1=300
add2=0
df2=zs1.tail(500)
v1=1
DrawKK(df2,add1=add1,add2=add2,corr=v1,isSave=True,file="res/now.jpg")
# Out:
# <module 'matplotlib.pyplot' from 'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
def DrawIndex(ind,add1=0,add2=0):
#     index=ii
#     ind=newRec.index[index]
    if add1>ind:
        add1=ind
    begin=ind-add1
    end=begin+length+add2+add1
    df2=df1.iloc[begin:end]
    v1=df_res.loc[ind]['Corr']
#     print(newRec.iloc[index],v1)
    file="res/%s.jpg"%(ind)
    DrawKK(df2,add1=add1,add2=add2,corr=v1,file=file)

def DrawKK(aa,add1=0,add2=0,file='res/test.jpg',corr=0,isSave=False):
    fig = plt.figure(figsize=(30, 12))
    ax = fig.add_subplot(111)
    ax.clear()
    k_width = 50
    k_diff = 10
    kline = k_width + k_diff
    d=0
    rows=len(aa)
    if add1>0:
        ax.axvline((add1+1)*kline,ymax=1,c='b',ls='dashed')
    if add2>0:
        ax.axvline((rows-add2+1)*kline,ymax=1,c='b',ls='dashed')
    for i in aa.iterrows():
        d=d+1
        x = d * kline
        O = i[1]['open']
        C = i[1]['close']
        L = i[1]['low']
        H = i[1]['high']
        hh = abs(C - O)
        x1 = x + k_width / 2
        if C > O:
            a = False
            y = O
            cc = 'R'
            # 上影线 下影线
            line1 = Line2D((x1, x1), (C, H), color=cc)
            line2 = Line2D((x1, x1), (O, L), color=cc)

            ax.add_line(line1)
            ax.add_line(line2)
        else:
            a = True
            y = C
            cc = 'C'
            # 影线
            line = Line2D((x1, x1), (L, H), color=cc)
            ax.add_line(line)
        hh = abs(C - O)

        # K线实体
        rec = Rectangle((x, y), k_width, hh, fill=a, color=cc)
        ax.add_patch(rec)
    ax.grid()
    ax.autoscale_view()
    time1=aa.iloc[add1]['datetime']
    if add2==0:
        diff=-1
    else:
        diff=-add2-1
    time2=aa.iloc[diff]['datetime']
    title="%s--%s,Corr:%.3f" %(time1,time2,corr)
    plt.title(title, fontsize=20, color='r')
    if isSave:
        fig.savefig(file)
    return plt

# %%
cnt=200
df_source=sh[0:-200]
df_target=sh.tail(cnt)
sa=Analyse_CORR(df_source,df_target)
dt1=dt.datetime.now()
sa.corr()
dt2=dt.datetime.now()
print(dt2-dt1)
sa.DF_CORR.head(20)
# Out:
# 0:00:00.975055
#        Corr          datetime
# 3037  0.890  2003-04-16 15:00
# 5228  0.872  2012-04-26 15:00
# 765   0.845  1993-12-17 15:00
# 360   0.829  1992-05-21 15:00
# 1943  0.792  1998-09-21 15:00
# 1204  0.772  1995-09-14 15:00
# 5604  0.753  2013-11-18 15:00
# 2121  0.725  1999-06-21 15:00
# 4678  0.698  2010-01-15 15:00
# 4314  0.663  2008-07-22 15:00
# 2855  0.592  2002-07-16 15:00
# 947   0.592  1994-09-07 15:00
# 3     0.577  1990-12-24 15:00
# 1606  0.563  1997-05-12 15:00
# 3436  0.554  2004-12-08 15:00
# 187   0.536  1991-09-12 15:00
# 6340  0.519  2016-11-22 15:00
# 2666  0.488  2001-09-21 15:00
# 6084  0.484  2015-11-05 15:00
# 3593  0.470  2005-08-03 15:00

# %%
T1=df1.tail(200)
T2=sh

sa1=Analyse_CORR(T1,T2)
res=sa1.corr()
res.head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-131f22f8b73b> in <module>()
# ----> 1 T1=df1.tail(200)
#       2 T2=sh
#       3
#       4 sa1=Analyse_CORR(T1,T2)
#       5 res=sa1.corr()
#
# NameError: name 'df1' is not defined

# %%
from sa import Analyse_CORR
# print("test")
# Out:
# OK
# OK
