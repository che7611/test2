# %%
import pandas as pd
import numpy as np
from KRData.HKData import *
from KRData.util import draw_klines
from ib_insync import *
import datetime as dt
from IPython.display import display, clear_output
import sys
# Out:
# d:\ProgramData\Anaconda3\lib\site-packages\matplotlib\cbook\deprecation.py:106: MatplotlibDeprecationWarning: The finance module has been deprecated in mpl 2.0 and will be removed in mpl 2.2. Please use the module mpl_finance instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
hf = HKFuture('krdata', 'kairuitouzi')

# %%
data = hf.get_main_contract_bars('HSI', start='20181201') # 获取需要对照的历史K线

# %%
util.startLoop()
ib = IB()
ib.connect(clientId=9)
hsi1904 = Future('HSI', '201904')
ib.qualifyContracts(hsi1904)
# Out:
# API connection failed: ConnectionRefusedError(10061, "Connect call failed ('127.0.0.1', 7497)")
# Make sure API port on TWS/IBG is open
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# <ipython-input-4-5b612ff95222> in <module>()
#       1 util.startLoop()
#       2 ib = IB()
# ----> 3 ib.connect(clientId=9)
#       4 hsi1904 = Future('HSI', '201904')
#       5 ib.qualifyContracts(hsi1904)
#
# d:\ProgramData\Anaconda3\lib\site-packages\ib_insync\ib.py in connect(self, host, port, clientId, timeout)
#     223                 is raised. Set to 0 to disable timeout.
#     224         """
# --> 225         self._run(self.connectAsync(host, port, clientId, timeout))
#     226         return self
#     227
#
# d:\ProgramData\Anaconda3\lib\site-packages\ib_insync\ib.py in _run(self, *awaitables)
#     257
#     258     def _run(self, *awaitables: List[Awaitable]):
# --> 259         return util.run(*awaitables, timeout=self.RequestTimeout)
#     260
#     261     def waitOnUpdate(self, timeout: float = 0) -> bool:
#
# d:\ProgramData\Anaconda3\lib\site-packages\ib_insync\util.py in run(timeout, *awaitables)
#     234         if timeout:
#     235             future = asyncio.wait_for(future, timeout)
# --> 236         result = loop.run_until_complete(future)
#     237     return result
#     238
#
# d:\ProgramData\Anaconda3\lib\site-packages\nest_asyncio.py in run_until_complete(self, future)
#      59             return f.result()
#      60         else:
# ---> 61             return self._run_until_complete_orig(future)
#      62
#      63     bogus_handle = asyncio.Handle(None, None, loop)
#
# d:\ProgramData\Anaconda3\lib\asyncio\base_events.py in run_until_complete(self, future)
#     465             raise RuntimeError('Event loop stopped before Future completed.')
#     466
# --> 467         return future.result()
#     468
#     469     def stop(self):
#
# d:\ProgramData\Anaconda3\lib\asyncio\tasks.py in _step(***failed resolving arguments***)
#     178                 # We use the `send` method directly, because coroutines
#     179                 # don't have `__iter__` and `__next__` methods.
# --> 180                 result = coro.send(None)
#     181             else:
#     182                 result = coro.throw(exc)
#
# d:\ProgramData\Anaconda3\lib\site-packages\ib_insync\ib.py in connectAsync(self, host, port, clientId, timeout)
#    1541             self, host, port, clientId, timeout=2):
#    1542         self.wrapper.clientId = clientId
# -> 1543         await self.client.connectAsync(host, port, clientId, timeout)
#    1544         accounts = self.client.getAccounts()
#    1545         await asyncio.gather(
#
# d:\ProgramData\Anaconda3\lib\site-packages\ib_insync\client.py in connectAsync(self, host, port, clientId, timeout)
#     193                 msg = 'Make sure API port on TWS/IBG is open'
#     194                 self._logger.error(msg)
# --> 195             await fut  # consume exception
#     196             raise
#     197
#
# d:\ProgramData\Anaconda3\lib\site-packages\ib_insync\client.py in connectAsync(self, host, port, clientId, timeout)
#     182         try:
#     183             fut = asyncio.gather(self.conn.connect(), self._readyEvent.wait())
# --> 184             await asyncio.wait_for(fut, timeout)
#     185             self._logger.info('API connection ready')
#     186             self.apiStart.emit()
#
# d:\ProgramData\Anaconda3\lib\asyncio\tasks.py in wait_for(fut, timeout, loop)
#     356
#     357         if fut.done():
# --> 358             return fut.result()
#     359         else:
#     360             fut.remove_done_callback(cb)
#
# d:\ProgramData\Anaconda3\lib\asyncio\tasks.py in _step(***failed resolving arguments***)
#     180                 result = coro.send(None)
#     181             else:
# --> 182                 result = coro.throw(exc)
#     183         except StopIteration as exc:
#     184             if self._must_cancel:
#
# d:\ProgramData\Anaconda3\lib\asyncio\base_events.py in create_connection(self, protocol_factory, host, port, ssl, family, proto, flags, sock, local_addr, server_hostname)
#     775             else:
#     776                 if len(exceptions) == 1:
# --> 777                     raise exceptions[0]
#     778                 else:
#     779                     # If they all have the same str(), raise one.
#
# d:\ProgramData\Anaconda3\lib\asyncio\base_events.py in create_connection(self, protocol_factory, host, port, ssl, family, proto, flags, sock, local_addr, server_hostname)
#     762                     if self._debug:
#     763                         logger.debug("connect %r to %r", sock, address)
# --> 764                     yield from self.sock_connect(sock, address)
#     765                 except OSError as exc:
#     766                     if sock is not None:
#
# d:\ProgramData\Anaconda3\lib\asyncio\selector_events.py in sock_connect(self, sock, address)
#     449         fut = self.create_future()
#     450         self._sock_connect(fut, sock, address)
# --> 451         return (yield from fut)
#     452
#     453     def _sock_connect(self, fut, sock, address):
#
# d:\ProgramData\Anaconda3\lib\asyncio\futures.py in __iter__(self)
#     330         if not self.done():
#     331             self._asyncio_future_blocking = True
# --> 332             yield self  # This tells Task to wait for completion.
#     333         assert self.done(), "yield from wasn't used with future"
#     334         return self.result()  # May raise too.
#
# d:\ProgramData\Anaconda3\lib\asyncio\tasks.py in _wakeup(self, future)
#     248     def _wakeup(self, future):
#     249         try:
# --> 250             future.result()
#     251         except Exception as exc:
#     252             # This may also be a cancellation.
#
# d:\ProgramData\Anaconda3\lib\asyncio\futures.py in result(self)
#     243             self._tb_logger = None
#     244         if self._exception is not None:
# --> 245             raise self._exception
#     246         return self._result
#     247
#
# d:\ProgramData\Anaconda3\lib\asyncio\selector_events.py in _sock_connect_cb(self, fut, sock, address)
#     479             if err != 0:
#     480                 # Jump to any except clause below.
# --> 481                 raise OSError(err, 'Connect call failed %s' % (address,))
#     482         except (BlockingIOError, InterruptedError):
#     483             # socket is still registered, the callback will be retried later
#
# ConnectionRefusedError: [Errno 10061] Connect call failed ('127.0.0.1', 7497)

# %%
mkData = ib.reqHistoricalData(hsi1904, '', f'{60*100} S', '1 min', 'TRADES', useRTH=False, keepUpToDate=True)

# %%
def analyze(targetData: pd.DataFrame, sourceData: pd.DataFrame, corrThreshold=0.8):
    targetSize = len(targetData)
    sourceSize = len(sourceData)
    ret = []
    for i in range(sourceSize-targetSize):
        sc = sourceData[i:i+targetSize]
        corr=np.corrcoef(targetData, sc)[0][1]
        ret.append([sc.index[0], sc.index[-1], corr])
    
    gt_threshold = [r for r in ret if r[-1]>corrThreshold]
    
    # 过滤连续K线高相关
    filtedRet = []
    if len(gt_threshold)>=2:
        r=gt_threshold[0]
        for i in range(len(gt_threshold)-1):
            if (gt_threshold[i+1][1] -gt_threshold[i][0])*0.9<=(gt_threshold[i][1] -gt_threshold[i+1][0]):
                r =gt_threshold[i+1] if gt_threshold[i+1][-1]>r[-1] else r
            else:
                filtedRet.append(r)
                r=gt_threshold[i+1]
        else:
            filtedRet.append(r)
    else:
        filtedRet = gt_threshold
        
    return filtedRet

# %%
def analyzeHistoricalData(bars, hasNewBar):
    if hasNewBar:
        targetData = util.df(bars[-100:]).rename(columns={'date':'datetime'})
        print('NewBarComing...Calculating!!!')
        result = analyze(targetData.close, data.close, 0.7)
        if len(result) !=0:
            clear_output()
            backwardN = dt.timedelta(minutes=30)
            forwardN = dt.timedelta(minutes=30)
            print(f'Get {len(result)} match!!!')
            result.sort(key=lambda x: x[-1], reverse=True)
            startLine = Line2D([29, 29],[0,sys.maxsize] )
            endLine = Line2D([99, 99],[0,sys.maxsize] )
            top1 = result[0]
            top2 = result[1]
            top3  = result[2]
            print( f'Top1 Corr:{top1[-1]}')
            cur_bars = draw_klines(targetData)
            display(cur_bars)
            fig1 = draw_klines(data[top1[0]-backwardN:top1[1]+forwardN], extra_lines=[startLine, endLine])
            display(fig1)
            fig2 = draw_klines(data[top2[0]-backwardN:top2[1]+forwardN], extra_lines=[startLine, endLine])
            display(fig2)
            fig3 = draw_klines(data[top3[0]-backwardN:top3[1]+forwardN], extra_lines=[startLine, endLine])
            display(fig3)
        else:
            print("Get No match")

# %%
mkData.updateEvent += analyzeHistoricalData
# Out:
# Get 302 match!!!
# Top1 Corr:0.9555802074319122

# %%
# %pylab inline
# Out:
# Get 305 match!!!
# Top1 Corr:0.9284597053002885

# %%
dt.timedelta(minutes=4)
# Out:
# datetime.timedelta(0, 240)

# %%
from matplotlib.lines import Line2D

# %%
sys.maxsize
# Out:
# 9223372036854775807
