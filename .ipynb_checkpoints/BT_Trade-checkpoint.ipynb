# %%
import pymongo as pmg
import pandas as pd
import datetime as dt
import pymysql
import matplotlib.pyplot as plt
from matplotlib.lines import TICKLEFT, TICKRIGHT, Line2D
from matplotlib.patches import Rectangle
import matplotlib as mpl
import matplotlib.dates as mdate
from datetime import time
from KRData.HKData import HKFuture
import talib as tb
import configparser
from kline import Kline


conf_parser = configparser.ConfigParser()
conf_parser.read( 'conf.ini')
mg_host = conf_parser.get('MGDB', 'host')
mg_user = conf_parser.get('MGDB', 'user')
mg_password = conf_parser.get('MGDB', 'password')
# hf=HKFuture(pwd=mg_password,host=mg_host,user=mg_user)
hf=HKFuture()
begin='2011-01-01'
dt1=dt.datetime.now()
_fields = ['datetime', 'code', 'open', 'high', 'low', 'close', 'vol','trade_date']
df=hf.get_bars('HSI1201',_fields)
df.head()
# Out:
# OK
#                                datetime     code     open     high      low  \
# datetime
# 2011-11-30 09:15:00 2011-11-30 09:15:00  HSI1201  18157.0  18157.0  18113.0
# 2011-11-30 09:17:00 2011-11-30 09:17:00  HSI1201  18131.0  18131.0  18130.0
# 2011-11-30 09:19:00 2011-11-30 09:19:00  HSI1201  18140.0  18140.0  18140.0
# 2011-11-30 09:21:00 2011-11-30 09:21:00  HSI1201  18127.0  18127.0  18115.0
# 2011-11-30 09:28:00 2011-11-30 09:28:00  HSI1201  18107.0  18107.0  18107.0
#
#                        close trade_date
# datetime
# 2011-11-30 09:15:00  18113.0 2011-11-30
# 2011-11-30 09:17:00  18130.0 2011-11-30
# 2011-11-30 09:19:00  18140.0 2011-11-30
# 2011-11-30 09:21:00  18115.0 2011-11-30
# 2011-11-30 09:28:00  18107.0 2011-11-30

# %%
from bt_base import BT_Calc
class BT_Trade(BT_Calc):
#初始化---------------------------------------------------------------------------------
    def __init__(self,hf:HKFuture,index='HSI',**arg):
        self.hf=hf
        self._DateList=hf.get_main_contract_trade_dates(index)
        self.Test_Trade=True
        self.std_base=2.5
        self.cls()
        self.trade_para()
        print("---init-----")
#交易参数---------------------------------------------------------------
    def trade_para(self):
        pass
#每个交易日每条记录循环部分(只计算)---------------------------------------------------------
    def day_loop(self):
        self.day_calc_init()
        self.day_trade_init()
        df=self._para['df1']
        self._para['day_no']=0
        for i,row in df.iterrows():
            self._para['row']=row
            self.day_calc_main()
            self.day_trade_main()
            self._para['day_no']+=1
        self.day_calc_end()
        self.day_trade_end()

#每个交易日交易前初始化--------------------------------------------------------------------------
    def day_trade_init(self):
        pass

#每个交易日交易计算主体--------------------------------------------------------------------------
    def day_trade_main(self):
        pass

#每个交易日交易每天结束--------------------------------------------------------------------------
    def day_trade_end(self):
        pass
    
print("BT_Trade")
# Out:
# BT_Trade

# %%
class BT_Trade_STD(BT_Trade):
#交易参数---------------------------------------------------------------
    def trade_para(self):
        self._para['trade_state']='ready'
        
#每个交易日交易前初始化--------------------------------------------------------------------------
    def day_trade_init(self):
        self._para['trade_state']='ready'
        self.trade={}
        
#每个交易日交易计算主体--------------------------------------------------------------------------
    def day_trade_main(self):
        if self._para['trade_state']=='ready':
            self.day_trade_open()
        elif self._para['trade_state']=='open':
             self.day_trade_close()
#开仓条件--------------------------------------------------------------------------
    def day_trade_open(self):
        if len(self._res['std'])==0:
            return
        row=self._para['row']
        std=self._res['std'][-1]
        if abs(row['std1'])>2.5 and std['ma60_no']==0 and std['ma60_state']=='under':
            self.trade['open']=row['close']
            self._para['trade_state']='open'
            
#平仓仓条件--------------------------------------------------------------------------
    def day_trade_close(self):
        if self._para['ma60']['no']==1:
            row=self._para['row']
            self.trade['close']=row['close']
            self._para['trade_state']='ready'
            self._res['trade'].append(self.trade)
print("Done")
# Out:
# Done

# %%
import time
t1=time.time()
bt1=BT_Trade_STD(hf)
bt1.contract_all()
t2=time.time()
print(t2-t1)
bt1._res['trade']
# Out:
# ---init-----
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# close
# 332.1890001296997
# [{'open': 23545.0, 'close': 23424.0},
#  {'open': 23797.0, 'close': 23770.0},
#  {'open': 24240.0, 'close': 24271.0},
#  {'open': 24224.0, 'close': 24265.0},
#  {'open': 24194.0, 'close': 24299.0},
#  {'open': 24003.0, 'close': 24053.0},
#  {'open': 23972.0, 'close': 24007.0},
#  {'open': 23822.0, 'close': 23889.0},
#  {'open': 23940.0, 'close': 23791.0},
#  {'open': 23940.0, 'close': 23791.0},
#  {'open': 23633.0, 'close': 23660.0},
#  {'open': 22829.0, 'close': 23034.0},
#  {'open': 22685.0, 'close': 22716.0},
#  {'open': 22926.0, 'close': 23023.0},
#  {'open': 23470.0, 'close': 23518.0},
#  {'open': 22952.0, 'close': 23021.0},
#  {'open': 22835.0, 'close': 22951.0},
#  {'open': 22802.0, 'close': 22895.0},
#  {'open': 23266.0, 'close': 23276.0},
#  {'open': 22855.0, 'close': 22964.0},
#  {'open': 23613.0, 'close': 23730.0},
#  {'open': 23422.0, 'close': 23480.0},
#  {'open': 23056.0, 'close': 22474.0},
#  {'open': 22210.0, 'close': 22338.0},
#  {'open': 22654.0, 'close': 22662.0},
#  {'open': 22770.0, 'close': 22785.0},
#  {'open': 23036.0, 'close': 23033.0},
#  {'open': 23497.0, 'close': 23512.0},
#  {'open': 24270.0, 'close': 24313.0},
#  {'open': 24359.0, 'close': 24404.0},
#  {'open': 24359.0, 'close': 24404.0},
#  {'open': 23963.0, 'close': 23968.0},
#  {'open': 23964.0, 'close': 23961.0},
#  {'open': 24112.0, 'close': 24004.0},
#  {'open': 24063.0, 'close': 23960.0},
#  {'open': 23480.0, 'close': 23498.0},
#  {'open': 23883.0, 'close': 24019.0},
#  {'open': 24102.0, 'close': 24131.0},
#  {'open': 23524.0, 'close': 23576.0},
#  {'open': 23566.0, 'close': 23540.0},
#  {'open': 23104.0, 'close': 23133.0},
#  {'open': 23104.0, 'close': 23133.0},
#  {'open': 23075.0, 'close': 23053.0},
#  {'open': 22981.0, 'close': 22946.0},
#  {'open': 22908.0, 'close': 22945.0},
#  {'open': 22820.0, 'close': 22946.0},
#  {'open': 22877.0, 'close': 22917.0},
#  {'open': 22877.0, 'close': 22917.0},
#  {'open': 22801.0, 'close': 22720.0},
#  {'open': 23116.0, 'close': 23001.0},
#  {'open': 22649.0, 'close': 22742.0},
#  {'open': 22665.0, 'close': 22662.0},
#  {'open': 22525.0, 'close': 22593.0},
#  {'open': 22862.0, 'close': 22821.0},
#  {'open': 23123.0, 'close': 23128.0},
#  {'open': 23131.0, 'close': 23212.0},
#  {'open': 22728.0, 'close': 22769.0},
#  {'open': 22582.0, 'close': 22593.0},
#  {'open': 22444.0, 'close': 22569.0},
#  {'open': 22307.0, 'close': 22515.0},
#  {'open': 22167.0, 'close': 22185.0},
#  {'open': 21962.0, 'close': 22030.0},
#  {'open': 21811.0, 'close': 21704.0},
#  {'open': 21876.0, 'close': 21966.0},
#  {'open': 22124.0, 'close': 22149.0},
#  {'open': 22398.0, 'close': 22429.0},
#  {'open': 22776.0, 'close': 22780.0},
#  {'open': 22665.0, 'close': 22765.0},
#  {'open': 22525.0, 'close': 22548.0},
#  {'open': 21832.0, 'close': 21882.0},
#  {'open': 21874.0, 'close': 21791.0},
#  {'open': 21925.0, 'close': 21802.0},
#  {'open': 21687.0, 'close': 21762.0},
#  {'open': 21920.0, 'close': 21984.0},
#  {'open': 22263.0, 'close': 22328.0},
#  {'open': 22281.0, 'close': 22286.0},
#  {'open': 22585.0, 'close': 22515.0},
#  {'open': 22750.0, 'close': 22779.0},
#  {'open': 21980.0, 'close': 21923.0},
#  {'open': 20778.0, 'close': 20822.0},
#  {'open': 20219.0, 'close': 20136.0},
#  {'open': 19006.0, 'close': 19074.0},
#  {'open': 19464.0, 'close': 19457.0},
#  {'open': 19831.0, 'close': 19849.0},
#  {'open': 20162.0, 'close': 20184.0},
#  {'open': 19426.0, 'close': 19436.0},
#  {'open': 19121.0, 'close': 19403.0},
#  {'open': 19121.0, 'close': 19403.0},
#  {'open': 20092.0, 'close': 20101.0},
#  {'open': 20740.0, 'close': 20766.0},
#  {'open': 20156.0, 'close': 20273.0},
#  {'open': 19618.0, 'close': 19673.0},
#  {'open': 19275.0, 'close': 19380.0},
#  {'open': 19087.0, 'close': 19064.0},
#  {'open': 19087.0, 'close': 19064.0},
#  {'open': 18877.0, 'close': 19024.0},
#  {'open': 18819.0, 'close': 18850.0},
#  {'open': 18927.0, 'close': 18791.0},
#  {'open': 18066.0, 'close': 18095.0},
#  {'open': 17500.0, 'close': 17549.0},
#  {'open': 17889.0, 'close': 17928.0},
#  {'open': 16775.0, 'close': 16823.0},
#  {'open': 16775.0, 'close': 16823.0},
#  {'open': 16683.0, 'close': 16771.0},
#  {'open': 17624.0, 'close': 17591.0},
#  {'open': 17648.0, 'close': 17741.0},
#  {'open': 18205.0, 'close': 17917.0},
#  {'open': 18075.0, 'close': 18238.0},
#  {'open': 17845.0, 'close': 17997.0},
#  {'open': 18798.0, 'close': 18811.0},
#  {'open': 18952.0, 'close': 18819.0},
#  {'open': 19491.0, 'close': 19583.0},
#  {'open': 19082.0, 'close': 19064.0},
#  {'open': 19166.0, 'close': 19262.0},
#  {'open': 19940.0, 'close': 20023.0},
#  {'open': 19112.0, 'close': 19127.0},
#  {'open': 19241.0, 'close': 19385.0},
#  {'open': 19175.0, 'close': 19182.0},
#  {'open': 18682.0, 'close': 18691.0},
#  {'open': 18402.0, 'close': 18454.0},
#  {'open': 18110.0, 'close': 18135.0},
#  {'open': 18166.0, 'close': 18179.0},
#  {'open': 18166.0, 'close': 18179.0},
#  {'open': 17865.0, 'close': 17889.0},
#  {'open': 17891.0, 'close': 17743.0},
#  {'open': 17939.0, 'close': 17977.0},
#  {'open': 18039.0, 'close': 18099.0},
#  {'open': 18914.0, 'close': 18974.0},
#  {'open': 18868.0, 'close': 18865.0},
#  {'open': 19037.0, 'close': 19034.0},
#  {'open': 18590.0, 'close': 18729.0},
#  {'open': 18310.0, 'close': 18339.0},
#  {'open': 18388.0, 'close': 18377.0},
#  {'open': 17880.0, 'close': 17958.0},
#  {'open': 18004.0, 'close': 17849.0},
#  {'open': 18236.0, 'close': 18357.0},
#  {'open': 18574.0, 'close': 18573.0},
#  {'open': 18483.0, 'close': 18545.0},
#  {'open': 18364.0, 'close': 18337.0},
#  {'open': 18541.0, 'close': 18491.0},
#  {'open': 18541.0, 'close': 18491.0},
#  {'open': 18560.0, 'close': 18386.0},
#  {'open': 19003.0, 'close': 19028.0},
#  {'open': 19168.0, 'close': 19108.0},
#  {'open': 18998.0, 'close': 19037.0},
#  {'open': 20463.0, 'close': 20425.0},
#  {'open': 20377.0, 'close': 20390.0},
#  {'open': 20775.0, 'close': 20781.0},
#  {'open': 20967.0, 'close': 20911.0},
#  {'open': 20877.0, 'close': 20772.0},
#  {'open': 21208.0, 'close': 21298.0},
#  {'open': 21500.0, 'close': 21349.0},
#  {'open': 21500.0, 'close': 21349.0},
#  {'open': 21357.0, 'close': 21420.0},
#  {'open': 21348.0, 'close': 21402.0},
#  {'open': 21524.0, 'close': 21576.0},
#  {'open': 20864.0, 'close': 20918.0},
#  {'open': 20564.0, 'close': 20582.0},
#  {'open': 21350.0, 'close': 21328.0},
#  {'open': 21338.0, 'close': 21328.0},
#  {'open': 21000.0, 'close': 20936.0},
#  {'open': 20672.0, 'close': 20706.0},
#  {'open': 20578.0, 'close': 20635.0},
#  {'open': 20821.0, 'close': 20864.0},
#  {'open': 20821.0, 'close': 20864.0},
#  {'open': 20619.0, 'close': 20650.0},
#  {'open': 20427.0, 'close': 20520.0},
#  {'open': 20539.0, 'close': 20526.0},
#  {'open': 20539.0, 'close': 20526.0},
#  {'open': 20310.0, 'close': 20418.0},
#  {'open': 20060.0, 'close': 20082.0},
#  {'open': 20608.0, 'close': 20591.0},
#  {'open': 20555.0, 'close': 20582.0},
#  {'open': 20492.0, 'close': 20564.0},
#  {'open': 20840.0, 'close': 20779.0},
#  {'open': 20665.0, 'close': 20675.0},
#  {'open': 21026.0, 'close': 21089.0},
#  {'open': 20916.0, 'close': 20943.0},
#  {'open': 20325.0, 'close': 20393.0},
#  {'open': 20117.0, 'close': 20164.0},
#  {'open': 20111.0, 'close': 20120.0},
#  {'open': 19767.0, 'close': 19843.0},
#  {'open': 19702.0, 'close': 19751.0},
#  {'open': 19484.0, 'close': 19492.0},
#  {'open': 19155.0, 'close': 19193.0},
#  {'open': 18617.0, 'close': 18525.0},
#  {'open': 18540.0, 'close': 18583.0},
#  {'open': 18540.0, 'close': 18583.0},
#  {'open': 18637.0, 'close': 18702.0},
#  {'open': 18681.0, 'close': 18682.0},
#  {'open': 18388.0, 'close': 18200.0},
#  {'open': 18420.0, 'close': 18344.0},
#  {'open': 17921.0, 'close': 17924.0},
#  {'open': 18097.0, 'close': 18108.0},
#  {'open': 18611.0, 'close': 18656.0},
#  {'open': 18463.0, 'close': 18500.0},
#  {'open': 18463.0, 'close': 18500.0},
#  {'open': 19393.0, 'close': 19379.0},
#  {'open': 19345.0, 'close': 19353.0},
#  {'open': 19033.0, 'close': 19067.0},
#  {'open': 18989.0, 'close': 18930.0},
#  {'open': 19724.0, 'close': 19733.0},
#  {'open': 19786.0, 'close': 19821.0},
#  {'open': 19656.0, 'close': 19726.0},
#  {'open': 19473.0, 'close': 19479.0},
#  {'open': 19277.0, 'close': 19299.0},
#  {'open': 19014.0, 'close': 19068.0},
#  {'open': 19044.0, 'close': 19013.0},
#  {'open': 19327.0, 'close': 19348.0},
#  {'open': 19558.0, 'close': 19566.0},
#  {'open': 19550.0, 'close': 19560.0},
#  {'open': 19076.0, 'close': 19145.0},
#  {'open': 18725.0, 'close': 18763.0},
#  {'open': 19776.0, 'close': 19675.0},
#  {'open': 19640.0, 'close': 19716.0},
#  {'open': 19476.0, 'close': 19456.0},
#  {'open': 20031.0, 'close': 20020.0},
#  {'open': 20018.0, 'close': 19981.0},
#  {'open': 20041.0, 'close': 20068.0},
#  {'open': 20141.0, 'close': 20190.0},
#  {'open': 20134.0, 'close': 20140.0},
#  {'open': 20064.0, 'close': 20061.0},
#  {'open': 20064.0, 'close': 20061.0},
#  {'open': 20099.0, 'close': 20092.0},
#  {'open': 20083.0, 'close': 19945.0},
#  {'open': 20058.0, 'close': 20089.0},
#  {'open': 19925.0, 'close': 19916.0},
#  {'open': 19925.0, 'close': 19916.0},
#  {'open': 20084.0, 'close': 20030.0},
#  {'open': 19865.0, 'close': 19877.0},
#  {'open': 19756.0, 'close': 19744.0},
#  {'open': 19799.0, 'close': 19809.0},
#  {'open': 19557.0, 'close': 19583.0},
#  {'open': 19404.0, 'close': 19438.0},
#  {'open': 19406.0, 'close': 19448.0},
#  {'open': 19099.0, 'close': 19127.0},
#  {'open': 19710.0, 'close': 19746.0},
#  {'open': 20664.0, 'close': 20688.0},
#  {'open': 20782.0, 'close': 20818.0},
#  {'open': 20728.0, 'close': 20603.0},
#  {'open': 20538.0, 'close': 20552.0},
#  {'open': 20469.0, 'close': 20535.0},
#  {'open': 20810.0, 'close': 20759.0},
#  {'open': 20958.0, 'close': 20909.0},
#  {'open': 20829.0, 'close': 20887.0},
#  {'open': 20783.0, 'close': 20791.0},
#  {'open': 20859.0, 'close': 20837.0},
#  {'open': 21069.0, 'close': 21060.0},
#  {'open': 21107.0, 'close': 21076.0},
#  {'open': 21492.0, 'close': 21509.0},
#  {'open': 21438.0, 'close': 21504.0},
#  {'open': 21735.0, 'close': 21613.0},
#  {'open': 21491.0, 'close': 21507.0},
#  {'open': 21765.0, 'close': 21751.0},
#  {'open': 21765.0, 'close': 21751.0},
#  {'open': 22037.0, 'close': 22034.0},
#  {'open': 22037.0, 'close': 22034.0},
#  {'open': 21891.0, 'close': 22026.0},
#  {'open': 21911.0, 'close': 21925.0},
#  {'open': 21807.0, 'close': 21863.0},
#  {'open': 21437.0, 'close': 21440.0},
#  {'open': 21228.0, 'close': 21224.0},
#  {'open': 21151.0, 'close': 21247.0},
#  {'open': 21115.0, 'close': 21129.0},
#  {'open': 21418.0, 'close': 21418.0},
#  {'open': 21926.0, 'close': 21962.0},
#  {'open': 21664.0, 'close': 21687.0},
#  {'open': 21776.0, 'close': 21779.0},
#  {'open': 22158.0, 'close': 22161.0},
#  {'open': 22327.0, 'close': 22346.0},
#  {'open': 22478.0, 'close': 22485.0},
#  {'open': 22619.0, 'close': 22437.0},
#  {'open': 22514.0, 'close': 22608.0},
#  {'open': 22536.0, 'close': 22589.0},
#  {'open': 22472.0, 'close': 22537.0},
#  {'open': 22674.0, 'close': 22661.0},
#  {'open': 23235.0, 'close': 23242.0},
#  {'open': 23336.0, 'close': 23294.0},
#  {'open': 23182.0, 'close': 23285.0},
#  {'open': 23333.0, 'close': 23386.0},
#  {'open': 23240.0, 'close': 23239.0},
#  {'open': 23584.0, 'close': 23572.0},
#  {'open': 23592.0, 'close': 23584.0},
#  {'open': 23673.0, 'close': 23671.0},
#  {'open': 23673.0, 'close': 23671.0},
#  {'open': 23807.0, 'close': 23737.0},
#  {'open': 23732.0, 'close': 23742.0},
#  {'open': 23732.0, 'close': 23742.0},
#  {'open': 23295.0, 'close': 23314.0},
#  {'open': 23245.0, 'close': 23186.0},
#  {'open': 23408.0, 'close': 23315.0},
#  {'open': 23363.0, 'close': 23359.0},
#  {'open': 23336.0, 'close': 23378.0},
#  {'open': 23307.0, 'close': 23356.0},
#  {'open': 22868.0, 'close': 22862.0},
#  {'open': 22868.0, 'close': 22862.0},
#  {'open': 22756.0, 'close': 22753.0},
#  {'open': 22762.0, 'close': 22798.0},
#  {'open': 22637.0, 'close': 22697.0},
#  {'open': 22709.0, 'close': 22752.0},
#  {'open': 22709.0, 'close': 22752.0},
#  {'open': 22665.0, 'close': 22624.0},
#  {'open': 23054.0, 'close': 23095.0},
#  {'open': 22340.0, 'close': 22333.0},
#  {'open': 22594.0, 'close': 22484.0},
#  {'open': 21962.0, 'close': 22023.0},
#  {'open': 22294.0, 'close': 22245.0},
#  {'open': 22149.0, 'close': 22221.0},
#  {'open': 22127.0, 'close': 22123.0},
#  {'open': 22178.0, 'close': 22225.0},
#  {'open': 22318.0, 'close': 22335.0},
#  {'open': 21681.0, 'close': 21745.0},
#  {'open': 21730.0, 'close': 21677.0},
#  {'open': 22197.0, 'close': 22180.0},
#  {'open': 22116.0, 'close': 22116.0},
#  {'open': 21895.0, 'close': 21898.0},
#  {'open': 21475.0, 'close': 21550.0},
#  {'open': 21631.0, 'close': 21703.0},
#  {'open': 21449.0, 'close': 21392.0},
#  {'open': 21787.0, 'close': 21990.0},
#  {'open': 22569.0, 'close': 22537.0},
#  {'open': 22515.0, 'close': 22510.0},
#  {'open': 22713.0, 'close': 22623.0},
#  {'open': 22795.0, 'close': 22847.0},
#  {'open': 22773.0, 'close': 22774.0},
#  {'open': 23017.0, 'close': 23092.0},
#  {'open': 22948.0, 'close': 22966.0},
#  {'open': 23001.0, 'close': 22943.0},
#  {'open': 23291.0, 'close': 23320.0},
#  {'open': 23277.0, 'close': 23278.0},
#  {'open': 22714.0, 'close': 22719.0},
#  {'open': 22714.0, 'close': 22719.0},
#  {'open': 22721.0, 'close': 22735.0},
#  {'open': 22162.0, 'close': 22283.0},
#  {'open': 22089.0, 'close': 22097.0},
#  {'open': 21965.0, 'close': 22006.0},
#  {'open': 21768.0, 'close': 21917.0},
#  {'open': 21615.0, 'close': 21675.0},
#  {'open': 21417.0, 'close': 21468.0},
#  {'open': 21324.0, 'close': 21336.0},
#  {'open': 20645.0, 'close': 20654.0},
#  {'open': 20931.0, 'close': 20973.0},
#  {'open': 21008.0, 'close': 21054.0},
#  {'open': 20971.0, 'close': 20890.0},
#  {'open': 20971.0, 'close': 20890.0},
#  {'open': 20297.0, 'close': 20380.0},
#  {'open': 19943.0, 'close': 20002.0},
#  {'open': 19910.0, 'close': 19960.0},
#  {'open': 19910.0, 'close': 19960.0},
#  {'open': 19978.0, 'close': 19987.0},
#  {'open': 20600.0, 'close': 20413.0},
#  {'open': 20650.0, 'close': 20459.0},
#  {'open': 20650.0, 'close': 20459.0},
#  {'open': 20235.0, 'close': 20236.0},
#  {'open': 20452.0, 'close': 20456.0},
#  {'open': 20324.0, 'close': 20431.0},
#  {'open': 20632.0, 'close': 20657.0},
#  {'open': 20742.0, 'close': 20825.0},
#  {'open': 21364.0, 'close': 21405.0},
#  {'open': 21257.0, 'close': 21269.0},
#  {'open': 21257.0, 'close': 21269.0},
#  {'open': 21332.0, 'close': 21330.0},
#  {'open': 21324.0, 'close': 21327.0},
#  {'open': 21270.0, 'close': 21286.0},
#  {'open': 21345.0, 'close': 21366.0},
#  {'open': 21900.0, 'close': 21891.0},
#  {'open': 21858.0, 'close': 21890.0},
#  {'open': 21899.0, 'close': 21900.0},
#  {'open': 21867.0, 'close': 21860.0},
#  {'open': 21936.0, 'close': 21852.0},
#  {'open': 21922.0, 'close': 21874.0},
#  {'open': 22162.0, 'close': 22253.0},
#  {'open': 21872.0, 'close': 21980.0},
#  {'open': 21761.0, 'close': 21729.0},
#  {'open': 21655.0, 'close': 21636.0},
#  {'open': 22220.0, 'close': 21757.0},
#  {'open': 22467.0, 'close': 22455.0},
#  {'open': 22273.0, 'close': 22382.0},
#  {'open': 21737.0, 'close': 21659.0},
#  {'open': 21580.0, 'close': 21601.0},
#  {'open': 21989.0, 'close': 21964.0},
#  {'open': 21899.0, 'close': 21958.0},
#  {'open': 21523.0, 'close': 21620.0},
#  {'open': 21552.0, 'close': 21526.0},
#  {'open': 21552.0, 'close': 21526.0},
#  {'open': 22338.0, 'close': 22174.0},
#  {'open': 22580.0, 'close': 22634.0},
#  {'open': 22891.0, 'close': 22882.0},
#  {'open': 23082.0, 'close': 23096.0},
#  {'open': 23082.0, 'close': 23096.0},
#  {'open': 22922.0, 'close': 22965.0},
#  {'open': 23199.0, 'close': 23224.0},
#  {'open': 23135.0, 'close': 23210.0},
#  {'open': 23455.0, 'close': 23341.0},
#  {'open': 23320.0, 'close': 23349.0},
#  {'open': 23228.0, 'close': 23204.0},
#  {'open': 22920.0, 'close': 22921.0},
#  {'open': 23061.0, 'close': 23089.0},
#  {'open': 23054.0, 'close': 23064.0},
#  {'open': 22934.0, 'close': 22917.0},
#  {'open': 23171.0, 'close': 22980.0},
#  {'open': 23018.0, 'close': 23032.0},
#  {'open': 23193.0, 'close': 23278.0},
#  {'open': 23193.0, 'close': 23278.0},
#  {'open': 23345.0, 'close': 23301.0},
#  {'open': 23394.0, 'close': 23429.0},
#  {'open': 23394.0, 'close': 23429.0},
#  {'open': 22857.0, 'close': 22932.0},
#  {'open': 22733.0, 'close': 22752.0},
#  {'open': 22889.0, 'close': 22784.0},
#  {'open': 23008.0, 'close': 23015.0},
#  {'open': 23215.0, 'close': 23183.0},
#  {'open': 23067.0, 'close': 23251.0},
#  {'open': 22808.0, 'close': 22879.0},
#  {'open': 22705.0, 'close': 22720.0},
#  {'open': 22705.0, 'close': 22720.0},
#  {'open': 22542.0, 'close': 22489.0},
#  {'open': 22542.0, 'close': 22489.0},
#  {'open': 22587.0, 'close': 22507.0},
#  {'open': 23703.0, 'close': 23881.0},
#  {'open': 23540.0, 'close': 23617.0},
#  {'open': 23729.0, 'close': 23742.0},
#  {'open': 23837.0, 'close': 23856.0},
#  {'open': 23953.0, 'close': 23977.0},
#  {'open': 23925.0, 'close': 23904.0},
#  {'open': 23784.0, 'close': 23704.0},
#  {'open': 23619.0, 'close': 23591.0},
#  {'open': 23784.0, 'close': 23671.0},
#  {'open': 23804.0, 'close': 23820.0},
#  {'open': 23505.0, 'close': 23633.0},
#  {'open': 23231.0, 'close': 23297.0},
#  {'open': 23215.0, 'close': 23090.0},
#  {'open': 23073.0, 'close': 23118.0},
#  {'open': 23144.0, 'close': 23212.0},
#  {'open': 23171.0, 'close': 23075.0},
#  {'open': 23162.0, 'close': 23286.0},
#  {'open': 23209.0, 'close': 23177.0},
#  {'open': 23267.0, 'close': 23328.0},
#  {'open': 23325.0, 'close': 23310.0},
#  {'open': 23325.0, 'close': 23310.0},
#  {'open': 23325.0, 'close': 23367.0},
#  {'open': 22872.0, 'close': 22875.0},
#  {'open': 22872.0, 'close': 22875.0},
#  {'open': 22659.0, 'close': 22630.0},
#  {'open': 22690.0, 'close': 22666.0},
#  {'open': 22838.0, 'close': 22830.0},
#  {'open': 22930.0, 'close': 22952.0},
#  {'open': 22876.0, 'close': 22779.0},
#  {'open': 22788.0, 'close': 22900.0},
#  {'open': 22769.0, 'close': 22719.0},
#  {'open': 22845.0, 'close': 22827.0},
#  {'open': 22946.0, 'close': 23001.0},
#  {'open': 23170.0, 'close': 22850.0},
#  {'open': 23170.0, 'close': 22850.0},
#  {'open': 22973.0, 'close': 23073.0},
#  {'open': 23061.0, 'close': 23016.0},
#  {'open': 22751.0, 'close': 22863.0},
#  {'open': 22495.0, 'close': 22574.0},
#  {'open': 21969.0, 'close': 21936.0},
#  {'open': 21739.0, 'close': 21766.0},
#  {'open': 21445.0, 'close': 21532.0},
#  {'open': 21451.0, 'close': 21478.0},
#  {'open': 21563.0, 'close': 21595.0},
#  {'open': 21513.0, 'close': 21525.0},
#  {'open': 22128.0, 'close': 22183.0},
#  {'open': 22539.0, 'close': 22500.0},
#  {'open': 22387.0, 'close': 22612.0},
#  {'open': 22387.0, 'close': 22612.0},
#  {'open': 22566.0, 'close': 22552.0},
#  {'open': 22792.0, 'close': 22795.0},
#  {'open': 22635.0, 'close': 22630.0},
#  {'open': 22580.0, 'close': 22735.0},
#  {'open': 22562.0, 'close': 22492.0},
#  {'open': 22588.0, 'close': 22632.0},
#  {'open': 22216.0, 'close': 22204.0},
#  {'open': 22216.0, 'close': 22204.0},
#  {'open': 22198.0, 'close': 22126.0},
#  {'open': 21911.0, 'close': 21965.0},
#  {'open': 21948.0, 'close': 21966.0},
#  {'open': 21476.0, 'close': 21512.0},
#  {'open': 21476.0, 'close': 21512.0},
#  {'open': 21455.0, 'close': 21489.0},
#  {'open': 21523.0, 'close': 21501.0},
#  {'open': 21523.0, 'close': 21501.0},
#  {'open': 21515.0, 'close': 21523.0},
#  {'open': 21276.0, 'close': 21400.0},
#  {'open': 21604.0, 'close': 21627.0},
#  {'open': 21746.0, 'close': 21722.0},
#  {'open': 21820.0, 'close': 21830.0},
#  {'open': 21820.0, 'close': 21830.0},
#  {'open': 22073.0, 'close': 22117.0},
#  {'open': 22073.0, 'close': 22117.0},
#  {'open': 22453.0, 'close': 22484.0},
#  {'open': 22601.0, 'close': 22624.0},
#  {'open': 22364.0, 'close': 22394.0},
#  {'open': 22361.0, 'close': 22359.0},
#  {'open': 23052.0, 'close': 23038.0},
#  {'open': 22912.0, 'close': 23059.0},
#  {'open': 22661.0, 'close': 22746.0},
#  {'open': 22534.0, 'close': 22762.0},
#  {'open': 22483.0, 'close': 22509.0},
#  {'open': 22245.0, 'close': 22480.0},
#  {'open': 22183.0, 'close': 22122.0},
#  {'open': 21880.0, 'close': 21900.0},
#  {'open': 21880.0, 'close': 21900.0},
#  {'open': 22020.0, 'close': 21884.0},
#  {'open': 21713.0, 'close': 21945.0},
#  {'open': 21713.0, 'close': 21945.0},
#  {'open': 21528.0, 'close': 21595.0},
#  {'open': 21593.0, 'close': 21631.0},
#  {'open': 21672.0, 'close': 21665.0},
#  {'open': 22200.0, 'close': 22222.0},
#  {'open': 22532.0, 'close': 22411.0},
#  {'open': 22565.0, 'close': 22615.0},
#  {'open': 22743.0, 'close': 22632.0},
#  {'open': 22755.0, 'close': 22611.0},
#  {'open': 22755.0, 'close': 22611.0},
#  {'open': 22835.0, 'close': 22898.0},
#  {'open': 22928.0, 'close': 22904.0},
#  {'open': 22920.0, 'close': 22937.0},
#  {'open': 22920.0, 'close': 22937.0},
#  {'open': 23131.0, 'close': 22958.0},
#  {'open': 23162.0, 'close': 23172.0},
#  {'open': 22976.0, 'close': 23084.0},
#  {'open': 22990.0, 'close': 22986.0},
#  {'open': 23182.0, 'close': 23057.0},
#  {'open': 23100.0, 'close': 23073.0},
#  {'open': 23131.0, 'close': 22984.0},
#  {'open': 23263.0, 'close': 23087.0},
#  {'open': 23238.0, 'close': 23221.0},
#  {'open': 23153.0, 'close': 23178.0},
#  {'open': 23147.0, 'close': 23137.0},
#  {'open': 23147.0, 'close': 23137.0},
#  {'open': 23236.0, 'close': 23239.0},
#  {'open': 22881.0, 'close': 22878.0},
#  {'open': 23072.0, 'close': 23063.0},
#  {'open': 23178.0, 'close': 23164.0},
#  {'open': 23522.0, 'close': 23545.0},
#  {'open': 23584.0, 'close': 23597.0},
#  {'open': 23517.0, 'close': 23534.0},
#  {'open': 23508.0, 'close': 23528.0},
#  {'open': 23508.0, 'close': 23528.0},
#  {'open': 23232.0, 'close': 23260.0},
#  {'open': 23178.0, 'close': 23224.0},
#  {'open': 23218.0, 'close': 23268.0},
#  {'open': 23424.0, 'close': 23426.0},
#  {'open': 23451.0, 'close': 23505.0},
#  {'open': 23443.0, 'close': 23544.0},
#  {'open': 23395.0, 'close': 23341.0},
#  {'open': 23412.0, 'close': 23433.0},
#  {'open': 23412.0, 'close': 23433.0},
#  {'open': 23870.0, 'close': 23864.0},
#  {'open': 24028.0, 'close': 24023.0},
#  {'open': 24164.0, 'close': 24189.0},
#  {'open': 24842.0, 'close': 24755.0},
#  {'open': 24565.0, 'close': 24660.0},
#  {'open': 24577.0, 'close': 24573.0},
#  {'open': 24488.0, 'close': 24589.0},
#  {'open': 24477.0, 'close': 24408.0},
#  {'open': 24393.0, 'close': 24421.0},
#  {'open': 24323.0, 'close': 24348.0},
#  {'open': 24526.0, 'close': 24564.0},
#  {'open': 24809.0, 'close': 24877.0},
#  {'open': 24888.0, 'close': 24850.0},
#  {'open': 24765.0, 'close': 24880.0},
#  {'open': 24928.0, 'close': 24903.0},
#  {'open': 25127.0, 'close': 25095.0},
#  {'open': 24981.0, 'close': 24959.0},
#  {'open': 24981.0, 'close': 24959.0},
#  {'open': 25099.0, 'close': 25057.0},
#  {'open': 24956.0, 'close': 25044.0},
#  {'open': 25112.0, 'close': 25159.0},
#  {'open': 24720.0, 'close': 24747.0},
#  {'open': 24585.0, 'close': 24596.0},
#  {'open': 24585.0, 'close': 24596.0},
#  {'open': 24643.0, 'close': 24669.0},
#  {'open': 25199.0, 'close': 25254.0},
#  {'open': 25160.0, 'close': 25170.0},
#  {'open': 25160.0, 'close': 25170.0},
#  {'open': 24648.0, 'close': 24680.0},
#  {'open': 24525.0, 'close': 24583.0},
#  {'open': 24374.0, 'close': 24363.0},
#  {'open': 24378.0, 'close': 24382.0},
#  {'open': 24142.0, 'close': 24197.0},
#  {'open': 24336.0, 'close': 24241.0},
#  {'open': 23978.0, 'close': 24011.0},
#  {'open': 23874.0, 'close': 23898.0},
#  {'open': 23653.0, 'close': 23607.0},
#  {'open': 23226.0, 'close': 23250.0},
#  {'open': 22821.0, 'close': 23026.0},
#  {'open': 22616.0, 'close': 22588.0},
#  {'open': 23077.0, 'close': 22938.0},
#  {'open': 23372.0, 'close': 23211.0},
#  {'open': 23182.0, 'close': 23184.0},
#  {'open': 23182.0, 'close': 23184.0},
#  {'open': 23440.0, 'close': 23452.0},
#  {'open': 23093.0, 'close': 23180.0},
#  {'open': 23208.0, 'close': 23110.0},
#  {'open': 22962.0, 'close': 22857.0},
#  {'open': 23032.0, 'close': 23033.0},
#  {'open': 23334.0, 'close': 23323.0},
#  {'open': 23270.0, 'close': 23263.0},
#  {'open': 23086.0, 'close': 23137.0},
#  {'open': 23846.0, 'close': 23837.0},
#  {'open': 23823.0, 'close': 23712.0},
#  {'open': 23724.0, 'close': 23784.0},
#  {'open': 23410.0, 'close': 23511.0},
#  {'open': 23763.0, 'close': 23792.0},
#  {'open': 23913.0, 'close': 23851.0},
#  {'open': 23974.0, 'close': 23970.0},
#  {'open': 23466.0, 'close': 23442.0},
#  {'open': 23291.0, 'close': 23293.0},
#  {'open': 23893.0, 'close': 23950.0},
#  {'open': 23879.0, 'close': 23898.0},
#  {'open': 23858.0, 'close': 23912.0},
#  {'open': 24040.0, 'close': 24199.0},
#  {'open': 24070.0, 'close': 23929.0},
#  {'open': 24070.0, 'close': 23929.0},
#  {'open': 23474.0, 'close': 23530.0},
#  {'open': 23274.0, 'close': 23302.0},
#  {'open': 23943.0, 'close': 24069.0},
#  {'open': 24112.0, 'close': 24094.0},
#  {'open': 24112.0, 'close': 24094.0},
#  {'open': 23800.0, 'close': 23758.0},
#  {'open': 23800.0, 'close': 23758.0},
#  {'open': 23235.0, 'close': 23261.0},
#  {'open': 23283.0, 'close': 23345.0},
#  {'open': 22976.0, 'close': 22885.0},
#  {'open': 22715.0, 'close': 22874.0},
#  {'open': 23422.0, 'close': 23421.0},
#  {'open': 23422.0, 'close': 23421.0},
#  {'open': 23844.0, 'close': 23827.0},
#  {'open': 23835.0, 'close': 23681.0},
#  {'open': 23396.0, 'close': 23504.0},
#  {'open': 23552.0, 'close': 23350.0},
#  {'open': 23784.0, 'close': 23809.0},
#  {'open': 24096.0, 'close': 23994.0},
#  {'open': 24032.0, 'close': 24014.0},
#  {'open': 24160.0, 'close': 23961.0},
#  {'open': 24241.0, 'close': 24265.0},
#  {'open': 24165.0, 'close': 24220.0},
#  {'open': 24165.0, 'close': 24220.0},
#  {'open': 23945.0, 'close': 23965.0},
#  {'open': 24269.0, 'close': 24038.0},
#  {'open': 24812.0, 'close': 24855.0},
#  {'open': 24706.0, 'close': 24894.0},
#  {'open': 24613.0, 'close': 24693.0},
#  {'open': 24416.0, 'close': 24428.0},
#  {'open': 24408.0, 'close': 24494.0},
#  {'open': 24684.0, 'close': 25035.0},
#  {'open': 24684.0, 'close': 25035.0},
#  {'open': 24724.0, 'close': 24803.0},
#  {'open': 24724.0, 'close': 24803.0},
#  {'open': 24468.0, 'close': 24549.0},
#  {'open': 24444.0, 'close': 24473.0},
#  {'open': 24351.0, 'close': 24501.0},
#  {'open': 24380.0, 'close': 24280.0},
#  {'open': 24762.0, 'close': 24735.0},
#  {'open': 24814.0, 'close': 24769.0},
#  {'open': 24808.0, 'close': 24801.0},
#  {'open': 24701.0, 'close': 24723.0},
#  {'open': 24798.0, 'close': 24738.0},
#  {'open': 24813.0, 'close': 24823.0},
#  {'open': 24813.0, 'close': 24823.0},
#  {'open': 24768.0, 'close': 24833.0},
#  {'open': 24801.0, 'close': 24809.0},
#  {'open': 24474.0, 'close': 24582.0},
#  {'open': 23916.0, 'close': 23974.0},
#  {'open': 23822.0, 'close': 23792.0},
#  {'open': 23882.0, 'close': 24010.0},
#  {'open': 23882.0, 'close': 24010.0},
#  {'open': 24423.0, 'close': 24421.0},
#  {'open': 24446.0, 'close': 24437.0},
#  {'open': 24472.0, 'close': 24518.0},
#  {'open': 24434.0, 'close': 24456.0},
#  {'open': 24527.0, 'close': 24455.0},
#  {'open': 24527.0, 'close': 24455.0},
#  {'open': 24574.0, 'close': 24468.0},
#  {'open': 24474.0, 'close': 24498.0},
#  {'open': 24947.0, 'close': 24950.0},
#  {'open': 24947.0, 'close': 24950.0},
#  {'open': 25075.0, 'close': 24978.0},
#  {'open': 25206.0, 'close': 25213.0},
#  {'open': 25206.0, 'close': 25213.0},
#  {'open': 25756.0, 'close': 25767.0},
#  {'open': 27057.0, 'close': 26768.0},
#  {'open': 27057.0, 'close': 26768.0},
#  {'open': 27489.0, 'close': 27024.0},
#  {'open': 27328.0, 'close': 27403.0},
#  {'open': 27815.0, 'close': 27812.0},
#  {'open': 27629.0, 'close': 27608.0},
#  {'open': 27676.0, 'close': 27551.0},
#  {'open': 27919.0, 'close': 27877.0},
#  {'open': 28049.0, 'close': 28109.0},
#  {'open': 27847.0, 'close': 27859.0},
#  {'open': 28421.0, 'close': 28170.0},
#  {'open': 28314.0, 'close': 28363.0},
#  {'open': 28314.0, 'close': 28363.0},
#  {'open': 28278.0, 'close': 28305.0},
#  {'open': 28094.0, 'close': 28136.0},
#  {'open': 28094.0, 'close': 28136.0},
#  {'open': 27930.0, 'close': 27700.0},
#  {'open': 27930.0, 'close': 27700.0},
#  {'open': 27374.0, 'close': 27459.0},
#  {'open': 27374.0, 'close': 27459.0},
#  {'open': 27539.0, 'close': 27579.0},
#  {'open': 27180.0, 'close': 27183.0},
#  {'open': 27318.0, 'close': 27339.0},
#  {'open': 27356.0, 'close': 27544.0},
#  {'open': 27356.0, 'close': 27544.0},
#  {'open': 27475.0, 'close': 27493.0},
#  {'open': 27476.0, 'close': 27417.0},
#  {'open': 27476.0, 'close': 27417.0},
#  {'open': 28200.0, 'close': 28297.0},
#  {'open': 27744.0, 'close': 28012.0},
#  {'open': 27060.0, 'close': 27062.0},
#  {'open': 27344.0, 'close': 27043.0},
#  {'open': 27344.0, 'close': 27043.0},
#  {'open': 27146.0, 'close': 27171.0},
#  {'open': 27343.0, 'close': 27207.0},
#  {'open': 27389.0, 'close': 27441.0},
#  {'open': 27292.0, 'close': 27341.0},
#  {'open': 27292.0, 'close': 27341.0},
#  {'open': 26884.0, 'close': 26965.0},
#  {'open': 27006.0, 'close': 27022.0},
#  {'open': 26720.0, 'close': 26728.0},
#  {'open': 26712.0, 'close': 26853.0},
#  {'open': 26483.0, 'close': 26463.0},
#  {'open': 26500.0, 'close': 26423.0},
#  {'open': 26496.0, 'close': 26430.0},
#  {'open': 26708.0, 'close': 26625.0},
#  {'open': 26937.0, 'close': 26951.0},
#  {'open': 27244.0, 'close': 27274.0},
#  {'open': 27084.0, 'close': 27222.0},
#  {'open': 26671.0, 'close': 26772.0},
#  {'open': 26641.0, 'close': 26661.0},
#  {'open': 26641.0, 'close': 26661.0},
#  {'open': 26327.0, 'close': 25933.0},
#  {'open': 26320.0, 'close': 26325.0},
#  {'open': 25682.0, 'close': 25733.0},
#  {'open': 25333.0, 'close': 25389.0},
#  {'open': 23762.0, 'close': 24240.0},
#  {'open': 24835.0, 'close': 24859.0},
#  {'open': 24835.0, 'close': 24859.0},
#  {'open': 24993.0, 'close': 25102.0},
#  {'open': 24933.0, 'close': 25084.0},
#  {'open': 24978.0, 'close': 24947.0},
#  {'open': 25355.0, 'close': 25147.0},
#  {'open': 25504.0, 'close': 25310.0},
#  {'open': 25265.0, 'close': 25315.0},
#  {'open': 25121.0, 'close': 25102.0},
#  {'open': 24452.0, 'close': 24632.0},
#  {'open': 24222.0, 'close': 24313.0},
#  {'open': 24722.0, 'close': 24746.0},
#  {'open': 24250.0, 'close': 24341.0},
#  {'open': 24369.0, 'close': 24318.0},
#  {'open': 24253.0, 'close': 24352.0},
#  {'open': 24489.0, 'close': 24215.0},
#  {'open': 24335.0, 'close': 24167.0},
#  {'open': 24066.0, 'close': 24214.0},
#  {'open': 23773.0, 'close': 23746.0},
#  {'open': 23456.0, 'close': 23480.0},
#  {'open': 22571.0, 'close': 22868.0},
#  {'open': 22177.0, 'close': 22308.0},
#  {'open': 21157.0, 'close': 21591.0},
#  {'open': 21463.0, 'close': 21290.0},
#  {'open': 21496.0, 'close': 21482.0},
#  {'open': 21496.0, 'close': 21482.0},
#  {'open': 21332.0, 'close': 21422.0},
#  {'open': 20759.0, 'close': 20814.0},
#  {'open': 20466.0, 'close': 20516.0},
#  {'open': 21445.0, 'close': 21507.0},
#  {'open': 21523.0, 'close': 21641.0},
#  {'open': 21598.0, 'close': 21688.0},
#  {'open': 21382.0, 'close': 21399.0},
#  {'open': 22038.0, 'close': 22031.0},
#  {'open': 21906.0, 'close': 21791.0},
#  {'open': 21612.0, 'close': 21637.0},
#  {'open': 22039.0, 'close': 21829.0},
#  {'open': 21109.0, 'close': 21404.0},
#  {'open': 21267.0, 'close': 21275.0},
#  {'open': 20443.0, 'close': 20502.0},
#  {'open': 21832.0, 'close': 21859.0},
#  {'open': 22097.0, 'close': 21841.0},
#  {'open': 22621.0, 'close': 22542.0},
#  {'open': 22586.0, 'close': 22553.0},
#  {'open': 22421.0, 'close': 22464.0},
#  {'open': 22974.0, 'close': 23037.0},
#  {'open': 22927.0, 'close': 22928.0},
#  {'open': 22927.0, 'close': 22928.0},
#  {'open': 22797.0, 'close': 22818.0},
#  {'open': 23094.0, 'close': 23130.0},
#  {'open': 23094.0, 'close': 23130.0},
#  {'open': 23016.0, 'close': 23009.0},
#  {'open': 23016.0, 'close': 23009.0},
#  {'open': 23022.0, 'close': 23047.0},
#  {'open': 22875.0, 'close': 23018.0},
#  {'open': 22875.0, 'close': 23018.0},
#  {'open': 22437.0, 'close': 22417.0},
#  {'open': 23026.0, 'close': 23128.0},
#  {'open': 23017.0, 'close': 23034.0},
#  {'open': 22763.0, 'close': 22837.0},
#  {'open': 22345.0, 'close': 22373.0},
#  {'open': 22345.0, 'close': 22373.0},
#  {'open': 22374.0, 'close': 22395.0},
#  {'open': 22315.0, 'close': 22378.0},
#  {'open': 21983.0, 'close': 22003.0},
#  {'open': 22297.0, 'close': 22360.0},
#  {'open': 22490.0, 'close': 22489.0},
#  {'open': 22751.0, 'close': 22742.0},
#  {'open': 22751.0, 'close': 22742.0},
#  {'open': 22514.0, 'close': 22439.0},
#  {'open': 22514.0, 'close': 22439.0},
#  {'open': 22238.0, 'close': 22266.0},
#  {'open': 21972.0, 'close': 21949.0},
#  {'open': 22357.0, 'close': 22122.0},
#  {'open': 22284.0, 'close': 22392.0},
#  {'open': 22151.0, 'close': 22135.0},
#  {'open': 21735.0, 'close': 21733.0},
#  {'open': 21778.0, 'close': 21783.0},
#  {'open': 21100.0, 'close': 21069.0},
#  {'open': 21507.0, 'close': 21562.0},
#  {'open': 21912.0, 'close': 21750.0},
#  {'open': 21809.0, 'close': 21743.0},
#  {'open': 21804.0, 'close': 21702.0},
#  {'open': 21790.0, 'close': 21759.0},
#  {'open': 21998.0, 'close': 22115.0},
#  {'open': 21910.0, 'close': 22080.0},
#  {'open': 21904.0, 'close': 21912.0},
#  {'open': 21232.0, 'close': 21275.0},
#  {'open': 21232.0, 'close': 21275.0},
#  {'open': 19944.0, 'close': 19990.0},
#  {'open': 20114.0, 'close': 19992.0},
#  {'open': 19798.0, 'close': 19609.0},
#  {'open': 19542.0, 'close': 19761.0},
#  {'open': 19277.0, 'close': 19267.0},
#  {'open': 19312.0, 'close': 18887.0},
#  {'open': 19325.0, 'close': 19330.0},
#  {'open': 19125.0, 'close': 19163.0},
#  {'open': 19395.0, 'close': 19377.0},
#  {'open': 18964.0, 'close': 18850.0},
#  {'open': 18506.0, 'close': 18546.0},
#  {'open': 19230.0, 'close': 18899.0},
#  {'open': 19290.0, 'close': 19311.0},
#  {'open': 19446.0, 'close': 19396.0},
#  {'open': 19369.0, 'close': 19473.0},
#  {'open': 19096.0, 'close': 19237.0},
#  {'open': 19096.0, 'close': 19237.0},
#  {'open': 19034.0, 'close': 19119.0},
#  {'open': 19084.0, 'close': 19114.0},
#  {'open': 19084.0, 'close': 19114.0},
#  {'open': 19832.0, 'close': 19896.0},
#  {'open': 20149.0, 'close': 20197.0},
#  {'open': 20052.0, 'close': 19951.0},
#  {'open': 19872.0, 'close': 19881.0},
#  {'open': 20077.0, 'close': 20051.0},
#  {'open': 20093.0, 'close': 19947.0},
#  {'open': 20316.0, 'close': 20363.0},
#  {'open': 20508.0, 'close': 20517.0},
#  {'open': 20681.0, 'close': 20740.0},
#  {'open': 20622.0, 'close': 20623.0},
#  {'open': 20604.0, 'close': 20636.0},
#  {'open': 20424.0, 'close': 20427.0},
#  {'open': 20755.0, 'close': 20762.0},
#  {'open': 20755.0, 'close': 20762.0},
#  {'open': 20511.0, 'close': 20538.0},
#  {'open': 20168.0, 'close': 20177.0},
#  {'open': 20200.0, 'close': 20131.0},
#  {'open': 20212.0, 'close': 20272.0},
#  {'open': 20009.0, 'close': 20071.0},
#  {'open': 20489.0, 'close': 20301.0},
#  {'open': 20481.0, 'close': 20516.0},
#  {'open': 21332.0, 'close': 21413.0},
#  {'open': 21325.0, 'close': 21348.0},
#  {'open': 21325.0, 'close': 21348.0},
#  {'open': 21033.0, 'close': 21080.0},
#  {'open': 21328.0, 'close': 21337.0},
#  {'open': 21328.0, 'close': 21337.0},
#  {'open': 21391.0, 'close': 21399.0},
#  {'open': 21391.0, 'close': 21446.0},
#  {'open': 21357.0, 'close': 21335.0},
#  {'open': 21357.0, 'close': 21335.0},
#  {'open': 21361.0, 'close': 21386.0},
#  {'open': 21564.0, 'close': 21529.0},
#  {'open': 20958.0, 'close': 20992.0},
#  {'open': 20687.0, 'close': 20795.0},
#  {'open': 20030.0, 'close': 20036.0},
#  {'open': 20051.0, 'close': 20088.0},
#  {'open': 19957.0, 'close': 19897.0},
#  {'open': 19942.0, 'close': 20096.0},
#  {'open': 19817.0, 'close': 19895.0},
#  {'open': 19656.0, 'close': 19662.0},
#  {'open': 19656.0, 'close': 19662.0},
#  {'open': 19773.0, 'close': 19600.0},
#  {'open': 19817.0, 'close': 19821.0},
#  {'open': 19643.0, 'close': 19787.0},
#  {'open': 19642.0, 'close': 19651.0},
#  {'open': 19642.0, 'close': 19651.0},
#  {'open': 19888.0, 'close': 19835.0},
#  {'open': 19736.0, 'close': 19756.0},
#  {'open': 20302.0, 'close': 20264.0},
#  {'open': 20302.0, 'close': 20264.0},
#  {'open': 20494.0, 'close': 20393.0},
#  {'open': 20670.0, 'close': 20662.0},
#  {'open': 20670.0, 'close': 20662.0},
#  {'open': 20554.0, 'close': 20450.0},
#  {'open': 20542.0, 'close': 20480.0},
#  {'open': 20656.0, 'close': 20673.0},
#  {'open': 20965.0, 'close': 20940.0},
#  {'open': 21115.0, 'close': 21057.0},
#  {'open': 21013.0, 'close': 21062.0},
#  {'open': 20295.0, 'close': 20367.0},
#  {'open': 20277.0, 'close': 20290.0},
#  {'open': 20277.0, 'close': 20290.0},
#  {'open': 20255.0, 'close': 20032.0},
#  {'open': 19838.0, 'close': 19936.0},
#  {'open': 20430.0, 'close': 20442.0},
#  {'open': 20474.0, 'close': 20472.0},
#  {'open': 20757.0, 'close': 20790.0},
#  {'open': 20065.0, 'close': 20837.0},
#  {'open': 20025.0, 'close': 20044.0},
#  {'open': 19952.0, 'close': 19944.0},
#  {'open': 20633.0, 'close': 20666.0},
#  {'open': 20894.0, 'close': 20881.0},
#  {'open': 20366.0, 'close': 20343.0},
#  {'open': 20507.0, 'close': 20608.0},
#  {'open': 21011.0, 'close': 21000.0},
#  {'open': 21320.0, 'close': 21396.0},
#  {'open': 21329.0, 'close': 21336.0},
#  {'open': 21682.0, 'close': 21595.0},
#  {'open': 21689.0, 'close': 21679.0},
#  {'open': 21874.0, 'close': 21721.0},
#  {'open': 21936.0, 'close': 21955.0},
#  {'open': 21936.0, 'close': 21932.0},
#  {'open': 21935.0, 'close': 22019.0},
#  {'open': 22220.0, 'close': 21920.0},
#  {'open': 22136.0, 'close': 22148.0},
#  {'open': 21987.0, 'close': 21996.0},
#  {'open': 22929.0, 'close': 22930.0},
#  {'open': 22929.0, 'close': 22930.0},
#  {'open': 22817.0, 'close': 22794.0},
#  {'open': 23665.0, 'close': 23684.0},
#  {'open': 24169.0, 'close': 23925.0},
#  {'open': 23439.0, 'close': 23455.0},
#  {'open': 23272.0, 'close': 23252.0},
#  {'open': 23516.0, 'close': 23440.0},
#  {'open': 23494.0, 'close': 23447.0},
#  {'open': 23507.0, 'close': 23517.0},
#  {'open': 23748.0, 'close': 24023.0},
#  {'open': 23747.0, 'close': 23847.0},
#  {'open': 23468.0, 'close': 23508.0},
#  {'open': 23615.0, 'close': 23340.0},
#  {'open': 23404.0, 'close': 23402.0},
#  {'open': 23763.0, 'close': 23627.0},
#  {'open': 23428.0, 'close': 23797.0},
#  {'open': 23331.0, 'close': 23339.0},
#  {'open': 23037.0, 'close': 23349.0},
#  {'open': 23028.0, 'close': 23031.0},
#  {'open': 23226.0, 'close': 23233.0},
#  {'open': 23282.0, 'close': 23296.0},
#  {'open': 23282.0, 'close': 23296.0},
#  {'open': 22811.0, 'close': 22821.0},
#  {'open': 22644.0, 'close': 22693.0},
#  {'open': 22838.0, 'close': 22904.0},
#  {'open': 22174.0, 'close': 22899.0},
#  {'open': 22207.0, 'close': 22140.0},
#  {'open': 22274.0, 'close': 22215.0},
#  {'open': 22264.0, 'close': 22258.0},
#  {'open': 22716.0, 'close': 22630.0},
#  {'open': 22578.0, 'close': 22574.0},
#  {'open': 22712.0, 'close': 22606.0},
#  {'open': 22899.0, 'close': 22804.0},
#  {'open': 22899.0, 'close': 22804.0},
#  {'open': 22753.0, 'close': 22765.0},
#  {'open': 22804.0, 'close': 22829.0},
#  {'open': 22940.0, 'close': 22881.0},
#  {'open': 22617.0, 'close': 22685.0},
#  {'open': 22513.0, 'close': 22585.0},
#  {'open': 22787.0, 'close': 22814.0},
#  {'open': 22723.0, 'close': 22794.0},
#  {'open': 22385.0, 'close': 22393.0},
#  {'open': 22552.0, 'close': 22556.0},
#  {'open': 22072.0, 'close': 22074.0},
#  {'open': 21988.0, 'close': 22053.0},
#  {'open': 21827.0, 'close': 21962.0},
#  {'open': 21816.0, 'close': 21806.0},
#  {'open': 21815.0, 'close': 21755.0},
#  {'open': 21815.0, 'close': 21755.0},
#  {'open': 21760.0, 'close': 21772.0},
#  {'open': 21534.0, 'close': 21538.0},
#  {'open': 21607.0, 'close': 21624.0},
#  {'open': 22151.0, 'close': 21913.0},
#  {'open': 22134.0, 'close': 22167.0},
#  {'open': 22134.0, 'close': 22167.0},
#  {'open': 22905.0, 'close': 22929.0},
#  {'open': 22686.0, 'close': 22722.0},
#  {'open': 22777.0, 'close': 22779.0},
#  {'open': 23132.0, 'close': 22924.0},
#  {'open': 22910.0, 'close': 22914.0},
#  {'open': 23005.0, 'close': 22965.0},
#  ...]

# %%
t1=pd.DataFrame(bt1._res['trade'])
t1['diff']=t1.close-t1.open
t1['diff'].agg(['sum','count','mean'])
# Out:
# sum      12725.000000
# count     1453.000000
# mean         8.757743
# Name: diff, dtype: float64

# %%
bt._res['macd']
# Out:
# [{'begin': 23143.0,
#   'state': 'green',
#   'ma60_state': 'under',
#   'ma60_no': 0,
#   'no': 0,
#   'begin_idx': 0,
#   'cnt': 36,
#   'std_up': 0,
#   'std_dn': 0,
#   'day_no': 0,
#   'std_up_list': [],
#   'std_dn_list': [],
#   'max_close': 23143.0,
#   'min_close': 23076.0,
#   'max_up': 59.0,
#   'max_dn': 67.0,
#   'max_idx': 1,
#   'min_idx': 26,
#   'date': datetime.datetime(2011, 1, 3, 0, 0),
#   'maxdn_idx1': 1,
#   'maxdn_idx2': 26,
#   'maxup_idx1': 26,
#   'maxup_idx2': 35,
#   'end': 23125.0,
#   'end_idx': 35,
#   'end_no': 0,
#   'diff': 18.0,
#   'ma60_state_end': 'under',
#   'idx': 0},
#  {'std_up': 3,
#   'std_dn': 0,
#   'std_up_list': [{'diff': 122.0, 'idx': 59},
#    {'diff': 41.0, 'idx': 60},
#    {'diff': 32.0, 'idx': 69}],
#   'std_dn_list': [],
#   'prod': 'HSI1101',
#   'date': datetime.datetime(2011, 1, 3, 0, 0),
#   'day_no': 1,
#   'ma60_state': 'under',
#   'ma60_no': 0,
#   'no': 1,
#   'cnt': 81,
#   'state': 'red',
#   'begin': 23125.0,
#   'begin_idx': 35,
#   'max_close': 23430.0,
#   'min_close': 23116.0,
#   'max_idx': 51,
#   'min_idx': 12,
#   'max_up': 314.0,
#   'max_dn': 62.0,
#   'maxdn_idx1': 51,
#   'maxdn_idx2': 78,
#   'maxup_idx1': 12,
#   'maxup_idx2': 51,
#   'end': 23378.0,
#   'end_idx': 116,
#   'end_no': 0,
#   'diff': 253.0,
#   'ma60_state_end': 'over',
#   'idx': 1},
#  {'std_up': 0,
#   'std_dn': 0,
#   'std_up_list': [],
#   'std_dn_list': [],
#   'prod': 'HSI1101',
#   'date': datetime.datetime(2011, 1, 3, 0, 0),
#   'day_no': 2,
#   'ma60_state': 'over',
#   'ma60_no': 1,
#   'no': 1,
#   'cnt': 3,
#   'state': 'green',
#   'begin': 23378.0,
#   'begin_idx': 116,
#   'max_close': 23391.0,
#   'min_close': 23378.0,
#   'max_idx': 3,
#   'min_idx': 1,
#   'max_up': 13.0,
#   'max_dn': 0,
#   'maxup_idx1': 1,
#   'maxup_idx2': 3,
#   'end': 23402.0,
#   'end_idx': 119,
#   'end_no': 1,
#   'diff': -24.0,
#   'ma60_state_end': 'over',
#   'idx': 2},
#  {'std_up': 0,
#   'std_dn': 0,
#   'std_up_list': [],
#   'std_dn_list': [],
#   'prod': 'HSI1101',
#   'date': datetime.datetime(2011, 1, 3, 0, 0),
#   'day_no': 3,
#   'ma60_state': 'over',
#   'ma60_no': 1,
#   'no': 1,
#   'cnt': 28,
#   'state': 'red',
#   'begin': 23402.0,
#   'begin_idx': 119,
#   'max_close': 23415.0,
#   'min_close': 23392.0,
#   'max_idx': 10,
#   'min_idx': 3,
#   'max_up': 23.0,
#   'max_dn': 19.0,
#   'maxdn_idx1': 10,
#   'maxdn_idx2': 28,
#   'maxup_idx1': 3,
#   'maxup_idx2': 10,
#   'end': 23390.0,
#   'end_idx': 147,
#   'end_no': 1,
#   'diff': -12.0,
#   'ma60_state_end': 'over',
#   'idx': 3},
#  {'std_up': 1,
#   'std_dn': 0,
#   'std_up_list': [{'diff': 16.0, 'idx': 165}],
#   'std_dn_list': [],
#   'prod': 'HSI1101',
#   'date': datetime.datetime(2011, 1, 3, 0, 0),
#   'day_no': 4,
#   'ma60_state': 'over',
#   'ma60_no': 1,
#   'no': 2,
#   'cnt': 19,
#   'state': 'green',
#   'begin': 23390.0,
#   'begin_idx': 147,
#   'max_close': 23409.0,
#   'min_close': 23370.0,
#   'max_idx': 19,
#   'min_idx': 12,
#   'max_up': 39.0,
#   'max_dn': 20.0,
#   'maxdn_idx1': 1,
#   'maxdn_idx2': 12,
#   'maxup_idx1': 12,
#   'maxup_idx2': 19,
#   'end': 23422.0,
#   'end_idx': 166,
#   'end_no': 0,
#   'diff': -32.0,
#   'ma60_state_end': 'over',
#   'idx': 4},
#  {'std_up': 1,
#   'std_dn': 1,
#   'std_up_list': [{'diff': 13.0, 'idx': 166}],
#   'std_dn_list': [{'diff': -22.0, 'idx': 167}],
#   'prod': 'HSI1101',
#   'date': datetime.datetime(2011, 1, 3, 0, 0),
#   'day_no': 5,
#   'ma60_state': 'over',
#   'ma60_no': 3,
#   'no': 1,
#   'cnt': 2,
#   'state': 'red',
#   'begin': 23422.0,
#   'begin_idx': 166,
#   'max_close': 23422.0,
#   'min_close': 23400.0,
#   'max_idx': 1,
#   'min_idx': 2,
#   'max_up': 0,
#   'max_dn': 22.0,
#   'maxdn_idx1': 1,
#   'maxdn_idx2': 2,
#   'end': 23377.0,
#   'end_idx': 168,
#   'end_no': 0,
#   'diff': -45.0,
#   'ma60_state_end': 'under',
#   'idx': 5},
#  {'std_up': 1,
#   'std_dn': 1,
#   'std_up_list': [{'diff': 13.0, 'idx': 180}],
#   'std_dn_list': [{'diff': -23.0, 'idx': 168}],
#   'prod': 'HSI1101',
#   'date': datetime.datetime(2011, 1, 3, 0, 0),
#   'day_no': 6,
#   'ma60_state': 'under',
#   'ma60_no': 3,
#   'no': 1,
#   'cnt': 16,
#   'state': 'green',
#   'begin': 23377.0,
#   'begin_idx': 168,
#   'max_close': 23397.0,
#   'min_close': 23362.0,
#   'max_idx': 15,
#   'min_idx': 9,
#   'max_up': 35.0,
#   'max_dn': 15.0,
#   'maxdn_idx1': 1,
#   'maxdn_idx2': 9,
#   'maxup_idx1': 9,
#   'maxup_idx2': 15,
#   'end': 23392.0,
#   'end_idx': 184,
#   'end_no': 0,
#   'diff': -15.0,
#   'ma60_state_end': 'over',
#   'idx': 6},
#  {'std_up': 0,
#   'std_dn': 0,
#   'std_up_list': [],
#   'std_dn_list': [],
#   'prod': 'HSI1101',
#   'date': datetime.datetime(2011, 1, 3, 0, 0),
#   'day_no': 7,
#   'ma60_state': 'over',
#   'ma60_no': 4,
#   'no': 1,
#   'cnt': 2,
#   'state': 'red',
#   'begin': 23392.0,
#   'begin_idx': 184,
#   'max_close': 23392.0,
#   'min_close': 23385.0,
#   'max_idx': 1,
#   'min_idx': 2,
#   'max_up': 0,
#   'max_dn': 7.0,
#   'maxdn_idx1': 1,
#   'maxdn_idx2': 2,
#   'end': 23371.0,
#   'end_idx': 186,
#   'end_no': 0,
#   'diff': -21.0,
#   'ma60_state_end': 'under',
#   'idx': 7},
#  {'std_up': 0,
#   'std_dn': 1,
#   'std_up_list': [],
#   'std_dn_list': [{'diff': -12.0, 'idx': 186}],
#   'prod': 'HSI1101',
#   'date': datetime.datetime(2011, 1, 3, 0, 0),
#   'day_no': 8,
#   'ma60_state': 'under',
#   'ma60_no': 4,
#   'no': 1,
#   'cnt': 4,
#   'state': 'green',
#   'begin': 23371.0,
#   'begin_idx': 186,
#   'max_close': 23385.0,
#   'min_close': 23371.0,
#   'max_idx': 4,
#   'min_idx': 1,
#   'max_up': 14.0,
#   'max_dn': 0,
#   'maxup_idx1': 1,
#   'maxup_idx2': 4,
#   'end': 23404.0,
#   'end_idx': 190,
#   'end_no': 0,
#   'diff': -33.0,
#   'ma60_state_end': 'over',
#   'idx': 8},
#  {'std_up': 2,
#   'std_dn': 2,
#   'std_up_list': [{'diff': 19.0, 'idx': 190}, {'diff': 24.0, 'idx': 195}],
#   'std_dn_list': [{'diff': -23.0, 'idx': 222}, {'diff': -16.0, 'idx': 225}],
#   'prod': 'HSI1101',
#   'date': datetime.datetime(2011, 1, 3, 0, 0),
#   'day_no': 9,
#   'ma60_state': 'over',
#   'ma60_no': 5,
#   'no': 1,
#   'cnt': 36,
#   'state': 'red',
#   'begin': 23404.0,
#   'begin_idx': 190,
#   'max_close': 23453.0,
#   'min_close': 23390.0,
#   'max_idx': 30,
#   'min_idx': 5,
#   'max_up': 63.0,
#   'max_dn': 56.0,
#   'maxdn_idx1': 30,
#   'maxdn_idx2': 36,
#   'maxup_idx1': 5,
#   'maxup_idx2': 30,
#   'end': 23401.0,
#   'end_idx': 226,
#   'end_no': 0,
#   'diff': -3.0,
#   'ma60_state_end': 'under',
#   'idx': 9},
#  {'std_up': 0,
#   'std_dn': 1,
#   'std_up_list': [],
#   'std_dn_list': [{'diff': -16.0, 'idx': 241}],
#   'prod': 'HSI1101',
#   'date': datetime.datetime(2011, 1, 3, 0, 0),
#   'day_no': 10,
#   'ma60_state': 'under',
#   'ma60_no': 5,
#   'no': 1,
#   'cnt': 24,
#   'state': 'green',
#   'begin': 23401.0,
#   'begin_idx': 226,
#   'max_close': 23412.0,
#   'min_close': 23360.0,
#   'max_idx': 24,
#   'min_idx': 16,
#   'max_up': 52.0,
#   'max_dn': 41.0,
#   'maxdn_idx1': 1,
#   'maxdn_idx2': 16,
#   'maxup_idx1': 16,
#   'maxup_idx2': 24,
#   'end': 23421.0,
#   'end_idx': 250,
#   'end_no': 0,
#   'diff': -20.0,
#   'ma60_state_end': 'over',
#   'idx': 10},
#  {'std_up': 1,
#   'std_dn': 2,
#   'std_up_list': [{'diff': 19.0, 'idx': 254}],
#   'std_dn_list': [{'diff': -17.0, 'idx': 255}, {'diff': -14.0, 'idx': 265}],
#   'prod': 'HSI1101',
#   'date': datetime.datetime(2011, 1, 3, 0, 0),
#   'day_no': 11,
#   'ma60_state': 'over',
#   'ma60_no': 6,
#   'no': 1,
#   'cnt': 17,
#   'state': 'red',
#   'begin': 23421.0,
#   'begin_idx': 250,
#   'max_close': 23437.0,
#   'min_close': 23388.0,
#   'max_idx': 5,
#   'min_idx': 17,
#   'max_up': 27.0,
#   'max_dn': 49.0,
#   'maxdn_idx1': 5,
#   'maxdn_idx2': 17,
#   'maxup_idx1': 3,
#   'maxup_idx2': 5,
#   'end': 23379.0,
#   'end_idx': 267,
#   'end_no': 0,
#   'diff': -42.0,
#   'ma60_state_end': 'under',
#   'idx': 11},
#  {'std_up': 0,
#   'std_dn': 0,
#   'std_up_list': [],
#   'std_dn_list': [],
#   'prod': 'HSI1101',
#   'date': datetime.datetime(2011, 1, 3, 0, 0),
#   'day_no': 12,
#   'ma60_state': 'under',
#   'ma60_no': 6,
#   'no': 1,
#   'cnt': 3,
#   'state': 'green',
#   'begin': 23379.0,
#   'begin_idx': 267,
#   'max_close': 23380.0,
#   'min_close': 23371.0,
#   'max_idx': 3,
#   'min_idx': 2,
#   'max_up': 9.0,
#   'max_dn': 8.0,
#   'maxdn_idx1': 1,
#   'maxdn_idx2': 2,
#   'maxup_idx1': 2,
#   'maxup_idx2': 3,
#   'end': 23380.0,
#   'end_idx': 270,
#   'end_no': 1,
#   'diff': -1.0,
#   'ma60_state_end': 'under',
#   'idx': 12},
#  {'begin': 23437.0,
#   'state': 'green',
#   'ma60_state': 'over',
#   'ma60_no': 0,
#   'no': 0,
#   'begin_idx': 0,
#   'cnt': 2,
#   'std_up': 1,
#   'std_dn': 0,
#   'day_no': 0,
#   'std_up_list': [{'diff': 50.0, 'idx': 0}],
#   'std_dn_list': [],
#   'max_close': 23437.0,
#   'min_close': 23437.0,
#   'max_up': 0,
#   'max_dn': 0,
#   'max_idx': 1,
#   'min_idx': 1,
#   'date': datetime.datetime(2011, 1, 4, 0, 0),
#   'end': 23432.0,
#   'end_idx': 1,
#   'end_no': 0,
#   'diff': 5.0,
#   'ma60_state_end': 'over',
#   'idx': 13},
#  {'std_up': 5,
#   'std_dn': 1,
#   'std_up_list': [{'diff': 21.0, 'idx': 3},
#    {'diff': 19.0, 'idx': 24},
#    {'diff': 23.0, 'idx': 26},
#    {'diff': 23.0, 'idx': 34},
#    {'diff': 34.0, 'idx': 35}],
#   'std_dn_list': [{'diff': -29.0, 'idx': 18}],
#   'prod': 'HSI1101',
#   'date': datetime.datetime(2011, 1, 4, 0, 0),
#   'day_no': 1,
#   'ma60_state': 'over',
#   'ma60_no': 0,
#   'no': 1,
#   'cnt': 60,
#   'state': 'red',
#   'begin': 23432.0,
#   'begin_idx': 1,
#   'max_close': 23552.0,
#   'min_close': 23407.0,
#   'max_idx': 41,
#   'min_idx': 18,
#   'max_up': 145.0,
#   'max_dn': 64.0,
#   'maxup_idx1': 18,
#   'maxup_idx2': 41,
#   'maxdn_idx1': 41,
#   'maxdn_idx2': 60,
#   'end': 23492.0,
#   'end_idx': 61,
#   'end_no': 0,
#   'diff': 60.0,
#   'ma60_state_end': 'over',
#   'idx': 14},
#  {'std_up': 0,
#   'std_dn': 0,
#   'std_up_list': [],
#   'std_dn_list': [],
#   'prod': 'HSI1101',
#   'date': datetime.datetime(2011, 1, 4, 0, 0),
#   'day_no': 2,
#   'ma60_state': 'over',
#   'ma60_no': 4,
#   'no': 1,
#   'cnt': 5,
#   'state': 'green',
#   'begin': 23492.0,
#   'begin_idx': 61,
#   'max_close': 23519.0,
#   'min_close': 23492.0,
#   'max_idx': 5,
#   'min_idx': 1,
#   'max_up': 27.0,
#   'max_dn': 0,
#   'maxup_idx1': 1,
#   'maxup_idx2': 5,
#   'end': 23525.0,
#   'end_idx': 66,
#   'end_no': 1,
#   'diff': -33.0,
#   'ma60_state_end': 'over',
#   'idx': 15},
#  {'std_up': 3,
#   'std_dn': 1,
#   'std_up_list': [{'diff': 17.0, 'idx': 76},
#    {'diff': 18.0, 'idx': 86},
#    {'diff': 26.0, 'idx': 98}],
#   'std_dn_list': [{'diff': -23.0, 'idx': 96}],
#   'prod': 'HSI1101',
#   'date': datetime.datetime(2011, 1, 4, 0, 0),
#   'day_no': 3,
#   'ma60_state': 'over',
#   'ma60_no': 4,
#   'no': 1,
#   'cnt': 73,
#   'state': 'red',
#   'begin': 23525.0,
#   'begin_idx': 66,
#   'max_close': 23580.0,
#   'min_close': 23512.0,
#   'max_idx': 51,
#   'min_idx': 4,
#   'max_up': 68.0,
#   'max_dn': 41.0,
#   'maxup_idx1': 4,
#   'maxup_idx2': 51,
#   'maxdn_idx1': 11,
#   'maxdn_idx2': 19,
#   'end': 23554.0,
#   'end_idx': 139,
#   'end_no': 1,
#   'diff': 29.0,
#   'ma60_state_end': 'over',
#   'idx': 16},
#  {'std_up': 1,
#   'std_dn': 1,
#   'std_up_list': [{'diff': 10.0, 'idx': 160}],
#   'std_dn_list': [{'diff': -12.0, 'idx': 149}],
#   'prod': 'HSI1101',
#   'date': datetime.datetime(2011, 1, 4, 0, 0),
#   'day_no': 4,
#   'ma60_state': 'over',
#   'ma60_no': 4,
#   'no': 2,
#   'cnt': 26,
#   'state': 'green',
#   'begin': 23554.0,
#   'begin_idx': 139,
#   'max_close': 23554.0,
#   'min_close': 23538.0,
#   'max_idx': 1,
#   'min_idx': 20,
#   'max_up': 15.0,
#   'max_dn': 16.0,
#   'maxdn_idx1': 1,
#   'maxdn_idx2': 20,
#   'maxup_idx1': 20,
#   'maxup_idx2': 22,
#   'end': 23573.0,
#   'end_idx': 165,
#   'end_no': 0,
#   'diff': -19.0,
#   'ma60_state_end': 'over',
#   'idx': 17},
#  {'std_up': 1,
#   'std_dn': 1,
#   'std_up_list': [{'diff': 9.0, 'idx': 165}],
#   'std_dn_list': [{'diff': -27.0, 'idx': 166}],
#   'prod': 'HSI1101',
#   'date': datetime.datetime(2011, 1, 4, 0, 0),
#   'day_no': 5,
#   'ma60_state': 'over',
#   'ma60_no': 7,
#   'no': 1,
#   'cnt': 2,
#   'state': 'red',
#   'begin': 23573.0,
#   'begin_idx': 165,
#   'max_close': 23573.0,
#   'min_close': 23545.0,
#   'max_idx': 1,
#   'min_idx': 2,
#   'max_up': 0,
#   'max_dn': 28.0,
#   'maxdn_idx1': 1,
#   'maxdn_idx2': 2,
#   'end': 23541.0,
#   'end_idx': 167,
#   'end_no': 0,
#   'diff': -32.0,
#   'ma60_state_end': 'under',
#   'idx': 18},
#  {'std_up': 1,
#   'std_dn': 0,
#   'std_up_list': [{'diff': 13.0, 'idx': 171}],
#   'std_dn_list': [],
#   'prod': 'HSI1101',
#   'date': datetime.datetime(2011, 1, 4, 0, 0),
#   'day_no': 6,
#   'ma60_state': 'under',
#   'ma60_no': 8,
#   'no': 1,
#   'cnt': 6,
#   'state': 'green',
#   'begin': 23541.0,
#   'begin_idx': 167,
#   'max_close': 23559.0,
#   'min_close': 23535.0,
#   'max_idx': 6,
#   'min_idx': 4,
#   'max_up': 24.0,
#   'max_dn': 14.0,
#   'maxup_idx1': 4,
#   'maxup_idx2': 6,
#   'maxdn_idx1': 2,
#   'maxdn_idx2': 4,
#   'end': 23551.0,
#   'end_idx': 173,
#   'end_no': 0,
#   'diff': -10.0,
#   'ma60_state_end': 'over',
#   'idx': 19},
#  {'std_up': 6,
#   'std_dn': 2,
#   'std_up_list': [{'diff': 18.0, 'idx': 177},
#    {'diff': 11.0, 'idx': 178},
#    {'diff': 18.0, 'idx': 195},
#    {'diff': 60.0, 'idx': 197},
#    {'diff': 20.0, 'idx': 215},
#    {'diff': 20.0, 'idx': 216}],
#   'std_dn_list': [{'diff': -19.0, 'idx': 191}, {'diff': -18.0, 'idx': 238}],
#   'prod': 'HSI1101',
#   'date': datetime.datetime(2011, 1, 4, 0, 0),
#   'day_no': 7,
#   'ma60_state': 'over',
#   'ma60_no': 9,
#   'no': 1,
#   'cnt': 67,
#   'state': 'red',
#   'begin': 23551.0,
#   'begin_idx': 173,
#   'max_close': 23676.0,
#   'min_close': 23551.0,
#   'max_idx': 44,
#   'min_idx': 1,
#   'max_up': 125.0,
#   'max_dn': 50.0,
#   'maxup_idx1': 1,
#   'maxup_idx2': 44,
#   'maxdn_idx1': 44,
#   'maxdn_idx2': 54,
#   'end': 23620.0,
#   'end_idx': 240,
#   'end_no': 0,
#   'diff': 69.0,
#   'ma60_state_end': 'under',
#   'idx': 20},
#  {'std_up': 0,
#   'std_dn': 0,
#   'std_up_list': [],
#   'std_dn_list': [],
#   'prod': 'HSI1101',
#   'date': datetime.datetime(2011, 1, 4, 0, 0),
#   'day_no': 8,
#   'ma60_state': 'under',
#   'ma60_no': 10,
#   'no': 1,
#   'cnt': 3,
#   'state': 'green',
#   'begin': 23620.0,
#   'begin_idx': 240,
#   'max_close': 23640.0,
#   'min_close': 23620.0,
#   'max_idx': 3,
#   'min_idx': 1,
#   'max_up': 20.0,
#   'max_dn': 0,
#   'maxup_idx1': 1,
#   'maxup_idx2': 3,
#   'end': 23649.0,
#   'end_idx': 243,
#   'end_no': 0,
#   'diff': -29.0,
#   'ma60_state_end': 'over',
#   'idx': 21},
#  {'std_up': 0,
#   'std_dn': 0,
#   'std_up_list': [],
#   'std_dn_list': [],
#   'prod': 'HSI1101',
#   'date': datetime.datetime(2011, 1, 4, 0, 0),
#   'day_no': 9,
#   'ma60_state': 'over',
#   'ma60_no': 10,
#   'no': 1,
#   'cnt': 9,
#   'state': 'red',
#   'begin': 23649.0,
#   'begin_idx': 243,
#   'max_close': 23656.0,
#   'min_close': 23628.0,
#   'max_idx': 2,
#   'min_idx': 9,
#   'max_up': 7.0,
#   'max_dn': 28.0,
#   'maxup_idx1': 1,
#   'maxup_idx2': 2,
#   'maxdn_idx1': 2,
#   'maxdn_idx2': 9,
#   'end': 23638.0,
#   'end_idx': 252,
#   'end_no': 1,
#   'diff': -11.0,
#   'ma60_state_end': 'over',
#   'idx': 22},
#  {'std_up': 0,
#   'std_dn': 0,
#   'std_up_list': [],
#   'std_dn_list': [],
#   'prod': 'HSI1101',
#   'date': datetime.datetime(2011, 1, 4, 0, 0),
#   'day_no': 10,
#   'ma60_state': 'over',
#   'ma60_no': 10,
#   'no': 1,
#   'cnt': 1,
#   'state': 'green',
#   'begin': 23638.0,
#   'begin_idx': 252,
#   'max_close': 23638.0,
#   'min_close': 23638.0,
#   'max_idx': 1,
#   'min_idx': 1,
#   'max_up': 0,
#   'max_dn': 0,
#   'end': 23642.0,
#   'end_idx': 253,
#   'end_no': 1,
#   'diff': -4.0,
#   'ma60_state_end': 'over',
#   'idx': 23},
#  {'std_up': 2,
#   'std_dn': 1,
#   'std_up_list': [{'diff': 38.0, 'idx': 254}, {'diff': 24.0, 'idx': 266}],
#   'std_dn_list': [{'diff': -23.0, 'idx': 255}],
#   'prod': 'HSI1101',
#   'date': datetime.datetime(2011, 1, 4, 0, 0),
#   'day_no': 11,
#   'ma60_state': 'over',
#   'ma60_no': 10,
#   'no': 2,
#   'cnt': 17,
#   'state': 'red',
#   'begin': 23642.0,
#   'begin_idx': 253,
#   'max_close': 23678.0,
#   'min_close': 23640.0,
#   'max_idx': 2,
#   'min_idx': 12,
#   'max_up': 36.0,
#   'max_dn': 38.0,
#   'maxup_idx1': 1,
#   'maxup_idx2': 2,
#   'maxdn_idx1': 2,
#   'maxdn_idx2': 12,
#   'end': 23670.0,
#   'end_idx': 270,
#   'end_no': 2,
#   'diff': 28.0,
#   'ma60_state_end': 'over',
#   'idx': 24},
#  {'begin': 23586.0,
#   'state': 'green',
#   'ma60_state': 'under',
#   'ma60_no': 0,
#   'no': 0,
#   'begin_idx': 0,
#   'cnt': 31,
#   'std_up': 2,
#   'std_dn': 1,
#   'day_no': 0,
#   'std_up_list': [{'diff': 18.0, 'idx': 1}, {'diff': 18.0, 'idx': 16}],
#   'std_dn_list': [{'diff': -18.0, 'idx': 0}],
#   'max_close': 23627.0,
#   'min_close': 23586.0,
#   'max_up': 41.0,
#   'max_dn': 23.0,
#   'max_idx': 31,
#   'min_idx': 1,
#   'date': datetime.datetime(2011, 1, 5, 0, 0),
#   'maxup_idx1': 1,
#   'maxup_idx2': 31,
#   'maxdn_idx1': 22,
#   'maxdn_idx2': 26,
#   'end': 23654.0,
#   'end_idx': 30,
#   'end_no': 0,
#   'diff': -68.0,
#   'ma60_state_end': 'over',
#   'idx': 25},
#  {'std_up': 5,
#   'std_dn': 4,
#   'std_up_list': [{'diff': 26.0, 'idx': 30},
#    {'diff': 21.0, 'idx': 33},
#    {'diff': 20.0, 'idx': 35},
#    {'diff': 19.0, 'idx': 37},
#    {'diff': 36.0, 'idx': 45}],
#   'std_dn_list': [{'diff': -21.0, 'idx': 34},
#    {'diff': -26.0, 'idx': 40},
#    {'diff': -22.0, 'idx': 52},
#    {'diff': -23.0, 'idx': 56}],
#   'prod': 'HSI1101',
#   'date': datetime.datetime(2011, 1, 5, 0, 0),
#   'day_no': 1,
#   'ma60_state': 'over',
#   'ma60_no': 3,
#   'no': 1,
#   'cnt': 29,
#   'state': 'red',
#   'begin': 23654.0,
#   'begin_idx': 30,
#   'max_close': 23709.0,
#   'min_close': 23636.0,
#   'max_idx': 16,
#   'min_idx': 3,
#   'max_up': 73.0,
#   'max_dn': 69.0,
#   'maxdn_idx1': 16,
#   'maxdn_idx2': 29,
#   'maxup_idx1': 3,
#   'maxup_idx2': 16,
#   'end': 23641.0,
#   'end_idx': 59,
#   'end_no': 0,
#   'diff': -13.0,
#   'ma60_state_end': 'under',
#   'idx': 26},
#  {'std_up': 0,
#   'std_dn': 0,
#   'std_up_list': [],
#   'std_dn_list': [],
#   'prod': 'HSI1101',
#   'date': datetime.datetime(2011, 1, 5, 0, 0),
#   'day_no': 2,
#   'ma60_state': 'under',
#   'ma60_no': 3,
#   'no': 1,
#   'cnt': 36,
#   'state': 'green',
#   'begin': 23641.0,
#   'begin_idx': 59,
#   'max_close': 23643.0,
#   'min_close': 23592.0,
#   'max_idx': 4,
#   'min_idx': 23,
#   'max_up': 41.0,
#   'max_dn': 51.0,
#   'maxdn_idx1': 4,
#   'maxdn_idx2': 23,
#   'maxup_idx1': 23,
#   'maxup_idx2': 34,
#   'end': 23627.0,
#   'end_idx': 95,
#   'end_no': 0,
#   'diff': 14.0,
#   'ma60_state_end': 'under',
#   'idx': 27},
#  {'std_up': 1,
#   'std_dn': 1,
#   'std_up_list': [{'diff': 12.0, 'idx': 112}],
#   'std_dn_list': [{'diff': -13.0, 'idx': 132}],
#   'prod': 'HSI1101',
#   'date': datetime.datetime(2011, 1, 5, 0, 0),
#   'day_no': 3,
#   'ma60_state': 'under',
#   'ma60_no': 4,
#   'no': 1,
#   'cnt': 43,
#   'state': 'red',
#   'begin': 23627.0,
#   'begin_idx': 95,
#   'max_close': 23675.0,
#   'min_close': 23621.0,
#   'max_idx': 33,
#   'min_idx': 3,
#   'max_up': 54.0,
#   'max_dn': 29.0,
#   'maxdn_idx1': 33,
#   'maxdn_idx2': 43,
#   'maxup_idx1': 3,
#   'maxup_idx2': 33,
#   'end': 23644.0,
#   'end_idx': 138,
#   'end_no': 0,
#   'diff': 17.0,
#   'ma60_state_end': 'under',
#   'idx': 28},
#  {'std_up': 1,
#   'std_dn': 0,
#   'std_up_list': [{'diff': 11.0, 'idx': 142}],
#   'std_dn_list': [],
#   'prod': 'HSI1101',
#   'date': datetime.datetime(2011, 1, 5, 0, 0),
#   'day_no': 4,
#   'ma60_state': 'under',
#   'ma60_no': 6,
#   'no': 1,
#   'cnt': 5,
#   'state': 'green',
#   'begin': 23644.0,
#   'begin_idx': 138,
#   'max_close': 23657.0,
#   'min_close': 23644.0,
#   'max_idx': 5,
#   'min_idx': 1,
#   'max_up': 13.0,
#   'max_dn': 0,
#   'maxup_idx1': 1,
#   'maxup_idx2': 5,
#   'end': 23662.0,
#   'end_idx': 143,
#   'end_no': 0,
#   'diff': -18.0,
#   'ma60_state_end': 'over',
#   'idx': 29},
#  {'std_up': 4,
#   'std_dn': 0,
#   'std_up_list': [{'diff': 21.0, 'idx': 145},
#    {'diff': 15.0, 'idx': 154},
#    {'diff': 12.0, 'idx': 159},
#    {'diff': 14.0, 'idx': 165}],
#   'std_dn_list': [],
#   'prod': 'HSI1101',
#   'date': datetime.datetime(2011, 1, 5, 0, 0),
#   'day_no': 5,
#   'ma60_state': 'over',
#   'ma60_no': 7,
#   'no': 1,
#   'cnt': 24,
#   'state': 'red',
#   'begin': 23662.0,
#   'begin_idx': 143,
#   'max_close': 23696.0,
#   'min_close': 23662.0,
#   'max_idx': 13,
#   'min_idx': 1,
#   'max_up': 34.0,
#   'max_dn': 34.0,
#   'maxup_idx1': 1,
#   'maxup_idx2': 13,
#   'maxdn_idx1': 13,
#   'maxdn_idx2': 23,
#   'end': 23654.0,
#   'end_idx': 167,
#   'end_no': 0,
#   'diff': -8.0,
#   'ma60_state_end': 'under',
#   'idx': 30},
#  {'std_up': 4,
#   'std_dn': 5,
#   'std_up_list': [{'diff': 16.0, 'idx': 171},
#    {'diff': 11.0, 'idx': 176},
#    {'diff': 19.0, 'idx': 190},
#    {'diff': 20.0, 'idx': 196}],
#   'std_dn_list': [{'diff': -11.0, 'idx': 180},
#    {'diff': -31.0, 'idx': 183},
#    {'diff': -13.0, 'idx': 185},
#    {'diff': -19.0, 'idx': 188},
#    {'diff': -19.0, 'idx': 199}],
#   'prod': 'HSI1101',
#   'date': datetime.datetime(2011, 1, 5, 0, 0),
#   'day_no': 6,
#   'ma60_state': 'under',
#   'ma60_no': 7,
#   'no': 1,
#   'cnt': 37,
#   'state': 'green',
#   'begin': 23654.0,
#   'begin_idx': 167,
#   'max_close': 23679.0,
#   'min_close': 23620.0,
#   'max_idx': 13,
#   'min_idx': 22,
#   'max_up': 38.0,
#   'max_dn': 59.0,
#   'maxdn_idx1': 13,
#   'maxdn_idx2': 22,
#   'maxup_idx1': 22,
#   'maxup_idx2': 30,
#   'end': 23660.0,
#   'end_idx': 204,
#   'end_no': 0,
#   'diff': -6.0,
#   'ma60_state_end': 'over',
#   'idx': 31},
#  {'std_up': 5,
#   'std_dn': 1,
#   'std_up_list': [{'diff': 21.0, 'idx': 206},
#    {'diff': 40.0, 'idx': 207},
#    {'diff': 26.0, 'idx': 211},
#    {'diff': 18.0, 'idx': 216},
#    {'diff': 21.0, 'idx': 222}],
#   'std_dn_list': [{'diff': -20.0, 'idx': 208}],
#   'prod': 'HSI1101',
#   'date': datetime.datetime(2011, 1, 5, 0, 0),
#   'day_no': 7,
#   'ma60_state': 'over',
#   'ma60_no': 13,
#   'no': 1,
#   'cnt': 52,
#   'state': 'red',
#   'begin': 23660.0,
#   'begin_idx': 204,
#   'max_close': 23787.0,
#   'min_close': 23660.0,
#   'max_idx': 23,
#   'min_idx': 1,
#   'max_up': 127.0,
#   'max_dn': 42.0,
#   'maxup_idx1': 1,
#   'maxup_idx2': 23,
#   'maxdn_idx1': 23,
#   'maxdn_idx2': 38,
#   'end': 23735.0,
#   'end_idx': 256,
#   'end_no': 0,
#   'diff': 75.0,
#   'ma60_state_end': 'under',
#   'idx': 32},
#  {'std_up': 0,
#   'std_dn': 1,
#   'std_up_list': [],
#   'std_dn_list': [{'diff': -20.0, 'idx': 256}],
#   'prod': 'HSI1101',
#   'date': datetime.datetime(2011, 1, 5, 0, 0),
#   'day_no': 8,
#   'ma60_state': 'under',
#   'ma60_no': 13,
#   'no': 1,
#   'cnt': 8,
#   'state': 'green',
#   'begin': 23735.0,
#   'begin_idx': 256,
#   'max_close': 23763.0,
#   'min_close': 23735.0,
#   'max_idx': 7,
#   'min_idx': 1,
#   'max_up': 28.0,
#   'max_dn': 7.0,
#   'maxup_idx1': 1,
#   'maxup_idx2': 7,
#   'maxdn_idx1': 3,
#   'maxdn_idx2': 5,
#   'end': 23759.0,
#   'end_idx': 264,
#   'end_no': 0,
#   'diff': -24.0,
#   'ma60_state_end': 'over',
#   'idx': 33},
#  {'std_up': 0,
#   'std_dn': 0,
#   'std_up_list': [],
#   'std_dn_list': [],
#   'prod': 'HSI1101',
#   'date': datetime.datetime(2011, 1, 5, 0, 0),
#   'day_no': 9,
#   'ma60_state': 'over',
#   'ma60_no': 15,
#   'no': 1,
#   'cnt': 6,
#   'state': 'red',
#   'begin': 23759.0,
#   'begin_idx': 264,
#   'max_close': 23761.0,
#   'min_close': 23754.0,
#   'max_idx': 4,
#   'min_idx': 2,
#   'max_up': 7.0,
#   'max_dn': 7.0,
#   'maxdn_idx1': 4,
#   'maxdn_idx2': 6,
#   'maxup_idx1': 2,
#   'maxup_idx2': 4,
#   'end': 23754.0,
#   'end_idx': 270,
#   'end_no': 1,
#   'diff': -5.0,
#   'ma60_state_end': 'over',
#   'idx': 34},
#  {'begin': 23833.0,
#   'state': 'red',
#   'ma60_state': 'over',
#   'ma60_no': 0,
#   'no': 0,
#   'begin_idx': 0,
#   'cnt': 24,
#   'std_up': 1,
#   'std_dn': 3,
#   'day_no': 0,
#   'std_up_list': [{'diff': 24.0, 'idx': 5}],
#   'std_dn_list': [{'diff': -20.0, 'idx': 1},
#    {'diff': -14.0, 'idx': 9},
#    {'diff': -26.0, 'idx': 21}],
#   'max_close': 23838.0,
#   'min_close': 23768.0,
#   'max_up': 25.0,
#   'max_dn': 70.0,
#   'max_idx': 7,
#   'min_idx': 23,
#   'date': datetime.datetime(2011, 1, 6, 0, 0),
#   'maxdn_idx1': 7,
#   'maxdn_idx2': 23,
#   'maxup_idx1': 3,
#   'maxup_idx2': 7,
#   'end': 23772.0,
#   'end_idx': 23,
#   'end_no': 0,
#   'diff': -61.0,
#   'ma60_state_end': 'under',
#   'idx': 35},
#  {'std_up': 1,
#   'std_dn': 0,
#   'std_up_list': [{'diff': 27.0, 'idx': 28}],
#   'std_dn_list': [],
#   'prod': 'HSI1101',
#   'date': datetime.datetime(2011, 1, 6, 0, 0),
#   'day_no': 1,
#   'ma60_state': 'under',
#   'ma60_no': 1,
#   'no': 1,
#   'cnt': 7,
#   'state': 'green',
#   'begin': 23772.0,
#   'begin_idx': 23,
#   'max_close': 23807.0,
#   'min_close': 23765.0,
#   'max_idx': 7,
#   'min_idx': 3,
#   'max_up': 42.0,
#   'max_dn': 7.0,
#   'maxdn_idx1': 1,
#   'maxdn_idx2': 3,
#   'maxup_idx1': 3,
#   'maxup_idx2': 7,
#   'end': 23830.0,
#   'end_idx': 30,
#   'end_no': 0,
#   'diff': -58.0,
#   'ma60_state_end': 'over',
#   'idx': 36},
#  {'std_up': 1,
#   'std_dn': 2,
#   'std_up_list': [{'diff': 23.0, 'idx': 30}],
#   'std_dn_list': [{'diff': -22.0, 'idx': 36}, {'diff': -26.0, 'idx': 37}],
#   'prod': 'HSI1101',
#   'date': datetime.datetime(2011, 1, 6, 0, 0),
#   'day_no': 2,
#   'ma60_state': 'over',
#   'ma60_no': 1,
#   'no': 1,
#   'cnt': 12,
#   'state': 'red',
#   'begin': 23830.0,
#   'begin_idx': 30,
#   'max_close': 23834.0,
#   'min_close': 23784.0,
#   'max_idx': 2,
#   'min_idx': 8,
#   'max_up': 12.0,
#   'max_dn': 50.0,
#   'maxup_idx1': 3,
#   'maxup_idx2': 6,
#   'maxdn_idx1': 2,
#   'maxdn_idx2': 8,
#   'end': 23780.0,
#   'end_idx': 42,
#   'end_no': 0,
#   'diff': -50.0,
#   'ma60_state_end': 'under',
#   'idx': 37},
#  {'std_up': 1,
#   'std_dn': 2,
#   'std_up_list': [{'diff': 17.0, 'idx': 64}],
#   'std_dn_list': [{'diff': -21.0, 'idx': 65}, {'diff': -24.0, 'idx': 69}],
#   'prod': 'HSI1101',
#   'date': datetime.datetime(2011, 1, 6, 0, 0),
#   'day_no': 3,
#   'ma60_state': 'under',
#   'ma60_no': 3,
#   'no': 1,
#   'cnt': 38,
#   'state': 'green',
#   'begin': 23780.0,
#   'begin_idx': 42,
#   'max_close': 23785.0,
#   'min_close': 23722.0,
#   'max_idx': 23,
#   'min_idx': 29,
#   'max_up': 55.0,
#   'max_dn': 63.0,
#   'maxdn_idx1': 23,
#   'maxdn_idx2': 29,
#   'maxup_idx1': 29,
#   'maxup_idx2': 38,
#   'end': 23767.0,
#   'end_idx': 80,
#   'end_no': 0,
#   'diff': 13.0,
#   'ma60_state_end': 'over',
#   'idx': 38},
#  {'std_up': 3,
#   'std_dn': 0,
#   'std_up_list': [{'diff': 14.0, 'idx': 91},
#    {'diff': 19.0, 'idx': 95},
#    {'diff': 14.0, 'idx': 111}],
#   'std_dn_list': [],
#   'prod': 'HSI1101',
#   'date': datetime.datetime(2011, 1, 6, 0, 0),
#   'day_no': 4,
#   'ma60_state': 'over',
#   'ma60_no': 4,
#   'no': 1,
#   'cnt': 54,
#   'state': 'red',
#   'begin': 23767.0,
#   'begin_idx': 80,
#   'max_close': 23833.0,
#   'min_close': 23765.0,
#   'max_idx': 42,
#   'min_idx': 11,
#   'max_up': 68.0,
#   'max_dn': 30.0,
#   'maxdn_idx1': 42,
#   'maxdn_idx2': 51,
#   'maxup_idx1': 11,
#   'maxup_idx2': 42,
#   'end': 23805.0,
#   'end_idx': 134,
#   'end_no': 0,
#   'diff': 38.0,
#   'ma60_state_end': 'over',
#   'idx': 39},
#  {'std_up': 0,
#   'std_dn': 0,
#   'std_up_list': [],
#   'std_dn_list': [],
#   'prod': 'HSI1101',
#   'date': datetime.datetime(2011, 1, 6, 0, 0),
#   'day_no': 5,
#   'ma60_state': 'over',
#   'ma60_no': 5,
#   'no': 1,
#   'cnt': 4,
#   'state': 'green',
#   'begin': 23805.0,
#   'begin_idx': 134,
#   'max_close': 23813.0,
#   'min_close': 23805.0,
#   'max_idx': 4,
#   'min_idx': 1,
#   'max_up': 8.0,
#   'max_dn': 0,
#   'maxup_idx1': 1,
#   'maxup_idx2': 4,
#   'end': 23816.0,
#   'end_idx': 138,
#   'end_no': 1,
#   'diff': -11.0,
#   'ma60_state_end': 'over',
#   'idx': 40},
#  {'std_up': 0,
#   'std_dn': 0,
#   'std_up_list': [],
#   'std_dn_list': [],
#   'prod': 'HSI1101',
#   'date': datetime.datetime(2011, 1, 6, 0, 0),
#   'day_no': 6,
#   'ma60_state': 'over',
#   'ma60_no': 5,
#   'no': 1,
#   'cnt': 12,
#   'state': 'red',
#   'begin': 23816.0,
#   'begin_idx': 138,
#   'max_close': 23825.0,
#   'min_close': 23803.0,
#   'max_idx': 6,
#   'min_idx': 12,
#   'max_up': 10.0,
#   'max_dn': 22.0,
#   'maxdn_idx1': 6,
#   'maxdn_idx2': 12,
#   'maxup_idx1': 3,
#   'maxup_idx2': 6,
#   'end': 23804.0,
#   'end_idx': 150,
#   'end_no': 0,
#   'diff': -12.0,
#   'ma60_state_end': 'under',
#   'idx': 41},
#  {'std_up': 3,
#   'std_dn': 2,
#   'std_up_list': [{'diff': 11.0, 'idx': 163},
#    {'diff': 11.0, 'idx': 168},
#    {'diff': 14.0, 'idx': 171}],
#   'std_dn_list': [{'diff': -11.0, 'idx': 152}, {'diff': -11.0, 'idx': 165}],
#   'prod': 'HSI1101',
#   'date': datetime.datetime(2011, 1, 6, 0, 0),
#   'day_no': 7,
#   'ma60_state': 'under',
#   'ma60_no': 6,
#   'no': 1,
#   'cnt': 22,
#   'state': 'green',
#   'begin': 23804.0,
#   'begin_idx': 150,
#   'max_close': 23816.0,
#   'min_close': 23770.0,
#   'max_idx': 22,
#   'min_idx': 16,
#   'max_up': 46.0,
#   'max_dn': 34.0,
#   'maxdn_idx1': 1,
#   'maxdn_idx2': 16,
#   'maxup_idx1': 16,
#   'maxup_idx2': 22,
#   'end': 23818.0,
#   'end_idx': 172,
#   'end_no': 0,
#   'diff': -14.0,
#   'ma60_state_end': 'over',
#   'idx': 42},
#  {'std_up': 0,
#   'std_dn': 2,
#   'std_up_list': [],
#   'std_dn_list': [{'diff': -14.0, 'idx': 177}, {'diff': -13.0, 'idx': 178}],
#   'prod': 'HSI1101',
#   'date': datetime.datetime(2011, 1, 6, 0, 0),
#   'day_no': 8,
#   'ma60_state': 'over',
#   'ma60_no': 6,
#   'no': 1,
#   'cnt': 7,
#   'state': 'red',
#   'begin': 23818.0,
#   'begin_idx': 172,
#   'max_close': 23818.0,
#   'min_close': 23784.0,
#   'max_idx': 1,
#   'min_idx': 7,
#   'max_up': 7.0,
#   'max_dn': 34.0,
#   'maxdn_idx1': 1,
#   'maxdn_idx2': 7,
#   'maxup_idx1': 3,
#   'maxup_idx2': 4,
#   'end': 23772.0,
#   'end_idx': 179,
#   'end_no': 0,
#   'diff': -46.0,
#   'ma60_state_end': 'under',
#   'idx': 43},
#  {'std_up': 6,
#   'std_dn': 4,
#   'std_up_list': [{'diff': 12.0, 'idx': 180},
#    {'diff': 10.0, 'idx': 185},
#    {'diff': 13.0, 'idx': 193},
#    {'diff': 27.0, 'idx': 195},
#    {'diff': 17.0, 'idx': 210},
#    {'diff': 14.0, 'idx': 216}],
#   'std_dn_list': [{'diff': -12.0, 'idx': 179},
#    {'diff': -18.0, 'idx': 190},
#    {'diff': -12.0, 'idx': 194},
#    {'diff': -13.0, 'idx': 208}],
#   'prod': 'HSI1101',
#   'date': datetime.datetime(2011, 1, 6, 0, 0),
#   'day_no': 9,
#   'ma60_state': 'under',
#   'ma60_no': 7,
#   'no': 1,
#   'cnt': 47,
#   'state': 'green',
#   'begin': 23772.0,
#   'begin_idx': 179,
#   'max_close': 23791.0,
#   'min_close': 23741.0,
#   'max_idx': 22,
#   'min_idx': 30,
#   'max_up': 45.0,
#   'max_dn': 50.0,
#   'maxup_idx1': 12,
#   'maxup_idx2': 22,
#   'maxdn_idx1': 22,
#   'maxdn_idx2': 30,
#   'end': 23784.0,
#   'end_idx': 226,
#   'end_no': 0,
#   'diff': -12.0,
#   'ma60_state_end': 'over',
#   'idx': 44},
#  {'std_up': 2,
#   'std_dn': 2,
#   'std_up_list': [{'diff': 18.0, 'idx': 226}, {'diff': 30.0, 'idx': 227}],
#   'std_dn_list': [{'diff': -15.0, 'idx': 228}, {'diff': -20.0, 'idx': 237}],
#   'prod': 'HSI1101',
#   'date': datetime.datetime(2011, 1, 6, 0, 0),
#   'day_no': 10,
#   'ma60_state': 'over',
#   'ma60_no': 10,
#   'no': 1,
#   'cnt': 12,
#   'state': 'red',
#   'begin': 23784.0,
#   'begin_idx': 226,
#   'max_close': 23813.0,
#   'min_close': 23755.0,
#   'max_idx': 2,
#   'min_idx': 12,
#   'max_up': 29.0,
#   'max_dn': 58.0,
#   'maxup_idx1': 1,
#   'maxup_idx2': 2,
#   'maxdn_idx1': 2,
#   'maxdn_idx2': 12,
#   'end': 23759.0,
#   'end_idx': 238,
#   'end_no': 0,
#   'diff': -25.0,
#   'ma60_state_end': 'under',
#   'idx': 45},
#  {'std_up': 1,
#   'std_dn': 0,
#   'std_up_list': [{'diff': 23.0, 'idx': 241}],
#   'std_dn_list': [],
#   'prod': 'HSI1101',
#   'date': datetime.datetime(2011, 1, 6, 0, 0),
#   'day_no': 11,
#   'ma60_state': 'under',
#   'ma60_no': 12,
#   'no': 1,
#   'cnt': 4,
#   'state': 'green',
#   'begin': 23759.0,
#   'begin_idx': 238,
#   'max_close': 23790.0,
#   'min_close': 23759.0,
#   'max_idx': 4,
#   'min_idx': 1,
#   'max_up': 31.0,
#   'max_dn': 0,
#   'maxup_idx1': 1,
#   'maxup_idx2': 4,
#   'end': 23796.0,
#   'end_idx': 242,
#   'end_no': 0,
#   'diff': -37.0,
#   'ma60_state_end': 'over',
#   'idx': 46},
#  {'std_up': 0,
#   'std_dn': 1,
#   'std_up_list': [],
#   'std_dn_list': [{'diff': -17.0, 'idx': 243}],
#   'prod': 'HSI1101',
#   'date': datetime.datetime(2011, 1, 6, 0, 0),
#   'day_no': 12,
#   'ma60_state': 'over',
#   'ma60_no': 12,
#   'no': 1,
#   'cnt': 3,
#   'state': 'red',
#   'begin': 23796.0,
#   'begin_idx': 242,
#   'max_close': 23796.0,
#   'min_close': 23772.0,
#   'max_idx': 1,
#   'min_idx': 3,
#   'max_up': 0,
#   'max_dn': 24.0,
#   'maxdn_idx1': 1,
#   'maxdn_idx2': 3,
#   'end': 23762.0,
#   'end_idx': 245,
#   'end_no': 0,
#   'diff': -34.0,
#   'ma60_state_end': 'under',
#   'idx': 47},
#  {'std_up': 0,
#   'std_dn': 0,
#   'std_up_list': [],
#   'std_dn_list': [],
#   'prod': 'HSI1101',
#   'date': datetime.datetime(2011, 1, 6, 0, 0),
#   'day_no': 13,
#   'ma60_state': 'under',
#   'ma60_no': 13,
#   'no': 1,
#   'cnt': 4,
#   'state': 'green',
#   'begin': 23762.0,
#   'begin_idx': 245,
#   'max_close': 23777.0,
#   'min_close': 23762.0,
#   'max_idx': 4,
#   'min_idx': 1,
#   'max_up': 15.0,
#   'max_dn': 2.0,
#   'maxup_idx1': 1,
#   'maxup_idx2': 4,
#   'maxdn_idx1': 2,
#   'maxdn_idx2': 3,
#   'end': 23787.0,
#   'end_idx': 249,
#   'end_no': 0,
#   'diff': -25.0,
#   'ma60_state_end': 'over',
#   'idx': 48},
#  {'std_up': 1,
#   'std_dn': 0,
#   'std_up_list': [{'diff': 15.0, 'idx': 269}],
#   'std_dn_list': [],
#   'prod': 'HSI1101',
#   'date': datetime.datetime(2011, 1, 6, 0, 0),
#   'day_no': 14,
#   'ma60_state': 'over',
#   'ma60_no': 13,
#   'no': 1,
#   'cnt': 21,
#   'state': 'red',
#   'begin': 23787.0,
#   'begin_idx': 249,
#   'max_close': 23806.0,
#   'min_close': 23772.0,
#   'max_idx': 21,
#   'min_idx': 7,
#   'max_up': 34.0,
#   'max_dn': 21.0,
#   'maxup_idx1': 7,
#   'maxup_idx2': 21,
#   'maxdn_idx1': 4,
#   'maxdn_idx2': 7,
#   'end': 23806.0,
#   'end_idx': 270,
#   'end_no': 0,
#   'diff': 19.0,
#   'ma60_state_end': 'over',
#   'idx': 49},
#  {'begin': 23790.0,
#   'state': 'red',
#   'ma60_state': 'over',
#   'ma60_no': 0,
#   'no': 0,
#   'begin_idx': 0,
#   'cnt': 5,
#   'std_up': 0,
#   'std_dn': 0,
#   'day_no': 0,
#   'std_up_list': [],
#   'std_dn_list': [],
#   'max_close': 23790.0,
#   'min_close': 23775.0,
#   'max_up': 11.0,
#   'max_dn': 15.0,
#   'max_idx': 1,
#   'min_idx': 5,
#   'date': datetime.datetime(2011, 1, 7, 0, 0),
#   'maxdn_idx1': 1,
#   'maxdn_idx2': 5,
#   'maxup_idx1': 3,
#   'maxup_idx2': 4,
#   'end': 23769.0,
#   'end_idx': 4,
#   'end_no': 0,
#   'diff': -21.0,
#   'ma60_state_end': 'under',
#   'idx': 50},
#  {'std_up': 3,
#   'std_dn': 4,
#   'std_up_list': [{'diff': 15.0, 'idx': 19},
#    {'diff': 19.0, 'idx': 22},
#    {'diff': 23.0, 'idx': 26}],
#   'std_dn_list': [{'diff': -18.0, 'idx': 14},
#    {'diff': -16.0, 'idx': 16},
#    {'diff': -20.0, 'idx': 17},
#    {'diff': -18.0, 'idx': 18}],
#   'prod': 'HSI1101',
#   'date': datetime.datetime(2011, 1, 7, 0, 0),
#   'day_no': 1,
#   'ma60_state': 'under',
#   'ma60_no': 2,
#   'no': 1,
#   'cnt': 26,
#   'state': 'green',
#   'begin': 23769.0,
#   'begin_idx': 4,
#   'max_close': 23785.0,
#   'min_close': 23710.0,
#   'max_idx': 24,
#   'min_idx': 15,
#   'max_up': 75.0,
#   'max_dn': 71.0,
#   'maxdn_idx1': 10,
#   'maxdn_idx2': 15,
#   'maxup_idx1': 15,
#   'maxup_idx2': 24,
#   'end': 23775.0,
#   'end_idx': 30,
#   'end_no': 0,
#   'diff': -6.0,
#   'ma60_state_end': 'over',
#   'idx': 51},
#  {'std_up': 3,
#   'std_dn': 0,
#   'std_up_list': [{'diff': 16.0, 'idx': 38},
#    {'diff': 21.0, 'idx': 44},
#    {'diff': 33.0, 'idx': 51}],
#   'std_dn_list': [],
#   'prod': 'HSI1101',
#   'date': datetime.datetime(2011, 1, 7, 0, 0),
#   'day_no': 2,
#   'ma60_state': 'over',
#   'ma60_no': 3,
#   'no': 1,
#   'cnt': 41,
#   'state': 'red',
#   'begin': 23775.0,
#   'begin_idx': 30,
#   'max_close': 23849.0,
#   'min_close': 23760.0,
#   'max_idx': 23,
#   'min_idx': 6,
#   'max_up': 89.0,
#   'max_dn': 61.0,
#   'maxdn_idx1': 23,
#   'maxdn_idx2': 37,
#   'maxup_idx1': 6,
#   'maxup_idx2': 23,
#   'end': 23798.0,
#   'end_idx': 71,
#   'end_no': 0,
#   'diff': 23.0,
#   'ma60_state_end': 'over',
#   'idx': 52},
#  {'std_up': 0,
#   'std_dn': 0,
#   'std_up_list': [],
#   'std_dn_list': [],
#   'prod': 'HSI1101',
#   'date': datetime.datetime(2011, 1, 7, 0, 0),
#   'day_no': 3,
#   'ma60_state': 'over',
#   'ma60_no': 5,
#   'no': 1,
#   'cnt': 6,
#   'state': 'green',
#   'begin': 23798.0,
#   'begin_idx': 71,
#   'max_close': 23806.0,
#   'min_close': 23790.0,
#   'max_idx': 6,
#   'min_idx': 3,
#   'max_up': 16.0,
#   'max_dn': 8.0,
#   'maxdn_idx1': 1,
#   'maxdn_idx2': 3,
#   'maxup_idx1': 3,
#   'maxup_idx2': 6,
#   'end': 23819.0,
#   'end_idx': 77,
#   'end_no': 0,
#   'diff': -21.0,
#   'ma60_state_end': 'over',
#   'idx': 53},
#  {'std_up': 6,
#   'std_dn': 2,
#   'std_up_list': [{'diff': 16.0, 'idx': 87},
#    {'diff': 17.0, 'idx': 89},
#    {'diff': 14.0, 'idx': 111},
#    {'diff': 12.0, 'idx': 128},
#    {'diff': 13.0, 'idx': 129},
#    {'diff': 13.0, 'idx': 130}],
#   'std_dn_list': [{'diff': -14.0, 'idx': 119}, {'diff': -12.0, 'idx': 143}],
#   'prod': 'HSI1101',
#   'date': datetime.datetime(2011, 1, 7, 0, 0),
#   'day_no': 4,
#   'ma60_state': 'over',
#   'ma60_no': 6,
#   'no': 1,
#   'cnt': 70,
#   'state': 'red',
#   'begin': 23819.0,
#   'begin_idx': 77,
#   'max_close': 23918.0,
#   'min_close': 23807.0,
#   'max_idx': 54,
#   'min_idx': 10,
#   'max_up': 111.0,
#   'max_dn': 48.0,
#   'maxup_idx1': 10,
#   'maxup_idx2': 54,
#   'maxdn_idx1': 54,
#   'maxdn_idx2': 70,
#   'end': 23872.0,
#   'end_idx': 147,
#   'end_no': 0,
#   'diff': 53.0,
#   'ma60_state_end': 'over',
#   'idx': 54},
#  {'std_up': 6,
#   'std_dn': 11,
#   'std_up_list': [{'diff': 15.0, 'idx': 164},
#    {'diff': 27.0, 'idx': 167},
#    {'diff': 19.0, 'idx': 181},
#    {'diff': 15.0, 'idx': 199},
#    {'diff': 23.0, 'idx': 224},
#    {'diff': 15.0, 'idx': 226}],
#   'std_dn_list': [{'diff': -12.0, 'idx': 149},
#    {'diff': -11.0, 'idx': 159},
#    {'diff': -36.0, 'idx': 166},
#    {'diff': -20.0, 'idx': 196},
#    {'diff': -17.0, 'idx': 197},
#    {'diff': -22.0, 'idx': 215},
#    {'diff': -20.0, 'idx': 220},
#    {'diff': -21.0, 'idx': 235},
#    {'diff': -21.0, 'idx': 238},
#    {'diff': -16.0, 'idx': 242},
#    {'diff': -20.0, 'idx': 246}],
#   'prod': 'HSI1101',
#   'date': datetime.datetime(2011, 1, 7, 0, 0),
#   'day_no': 5,
#   'ma60_state': 'over',
#   'ma60_no': 7,
#   'no': 1,
#   'cnt': 114,
#   'state': 'green',
#   'begin': 23872.0,
#   'begin_idx': 147,
#   'max_close': 23872.0,
#   'min_close': 23679.0,
#   'max_idx': 1,
#   'min_idx': 102,
#   'max_up': 65.0,
#   'max_dn': 193.0,
#   'maxdn_idx1': 1,
#   'maxdn_idx2': 102,
#   'maxup_idx1': 20,
#   'maxup_idx2': 37,
#   'end': 23730.0,
#   'end_idx': 261,
#   'end_no': 0,
#   'diff': 142.0,
#   'ma60_state_end': 'over',
#   'idx': 55},
#  {'std_up': 1,
#   'std_dn': 0,
#   'std_up_list': [{'diff': 19.0, 'idx': 261}],
#   'std_dn_list': [],
#   'prod': 'HSI1101',
#   'date': datetime.datetime(2011, 1, 7, 0, 0),
#   'day_no': 6,
#   'ma60_state': 'over',
#   'ma60_no': 8,
#   'no': 1,
#   'cnt': 11,
#   'state': 'red',
#   'begin': 23730.0,
#   'begin_idx': 261,
#   'max_close': 23736.0,
#   'min_close': 23718.0,
#   'max_idx': 11,
#   'min_idx': 2,
#   'max_up': 18.0,
#   'max_dn': 12.0,
#   'maxdn_idx1': 1,
#   'maxdn_idx2': 2,
#   'maxup_idx1': 2,
#   'maxup_idx2': 11,
#   'end': 23736.0,
#   'end_idx': 272,
#   'end_no': 0,
#   'diff': 6.0,
#   'ma60_state_end': 'over',
#   'idx': 56},
#  {'begin': 23671.0,
#   'state': 'red',
#   'ma60_state': 'under',
#   'ma60_no': 0,
#   'no': 0,
#   'begin_idx': 0,
#   'cnt': 2,
#   'std_up': 0,
#   'std_dn': 0,
#   'day_no': 0,
#   'std_up_list': [],
#   'std_dn_list': [],
#   'max_close': 23671.0,
#   'min_close': 23671.0,
#   'max_up': 0,
#   'max_dn': 0,
#   'max_idx': 1,
#   'min_idx': 1,
#   'date': datetime.datetime(2011, 1, 10, 0, 0),
#   'end': 23693.0,
#   'end_idx': 1,
#   'end_no': 0,
#   'diff': 22.0,
#   'ma60_state_end': 'under',
#   'idx': 57},
#  {'std_up': 1,
#   'std_dn': 0,
#   'std_up_list': [{'diff': 21.0, 'idx': 1}],
#   'std_dn_list': [],
#   'prod': 'HSI1101',
#   'date': datetime.datetime(2011, 1, 10, 0, 0),
#   'day_no': 1,
#   'ma60_state': 'under',
#   'ma60_no': 0,
#   'no': 1,
#   'cnt': 2,
#   'state': 'green',
#   'begin': 23693.0,
#   'begin_idx': 1,
#   'max_close': 23708.0,
#   'min_close': 23693.0,
#   'max_idx': 2,
#   'min_idx': 1,
#   'max_up': 15.0,
#   'max_dn': 0,
#   'maxup_idx1': 1,
#   'maxup_idx2': 2,
#   'end': 23727.0,
#   'end_idx': 3,
#   'end_no': 0,
#   'diff': -34.0,
#   'ma60_state_end': 'over',
#   'idx': 58},
#  {'std_up': 4,
#   'std_dn': 1,
#   'std_up_list': [{'diff': 19.0, 'idx': 3},
#    {'diff': 42.0, 'idx': 4},
#    {'diff': 21.0, 'idx': 11},
#    {'diff': 19.0, 'idx': 16}],
#   'std_dn_list': [{'diff': -22.0, 'idx': 30}],
#   'prod': 'HSI1101',
#   'date': datetime.datetime(2011, 1, 10, 0, 0),
#   'day_no': 2,
#   'ma60_state': 'over',
#   'ma60_no': 1,
#   'no': 1,
#   'cnt': 29,
#   'state': 'red',
#   'begin': 23727.0,
#   'begin_idx': 3,
#   'max_close': 23803.0,
#   'min_close': 23727.0,
#   'max_idx': 23,
#   'min_idx': 1,
#   'max_up': 76.0,
#   'max_dn': 67.0,
#   'maxup_idx1': 1,
#   'maxup_idx2': 23,
#   'maxdn_idx1': 23,
#   'maxdn_idx2': 29,
#   'end': 23738.0,
#   'end_idx': 32,
#   'end_no': 0,
#   'diff': 11.0,
#   'ma60_state_end': 'under',
#   'idx': 59},
#  {'std_up': 3,
#   'std_dn': 0,
#   'std_up_list': [{'diff': 24.0, 'idx': 47},
#    {'diff': 26.0, 'idx': 63},
#    {'diff': 23.0, 'idx': 65}],
#   'std_dn_list': [],
#   'prod': 'HSI1101',
#   'date': datetime.datetime(2011, 1, 10, 0, 0),
#   'day_no': 3,
#   'ma60_state': 'under',
#   'ma60_no': 1,
#   'no': 1,
#   'cnt': 37,
#   'state': 'green',
#   'begin': 23738.0,
#   'begin_idx': 32,
#   'max_close': 23743.0,
#   'min_close': 23650.0,
#   'max_idx': 3,
#   'min_idx': 29,
#   'max_up': 75.0,
#   'max_dn': 93.0,
#   'maxdn_idx1': 3,
#   'maxdn_idx2': 29,
#   'maxup_idx1': 29,
#   'maxup_idx2': 37,
#   'end': 23715.0,
#   'end_idx': 69,
#   'end_no': 0,
#   'diff': 23.0,
#   'ma60_state_end': 'over',
#   'idx': 60},
#  {'std_up': 0,
#   'std_dn': 0,
#   'std_up_list': [],
#   'std_dn_list': [],
#   'prod': 'HSI1101',
#   'date': datetime.datetime(2011, 1, 10, 0, 0),
#   'day_no': 4,
#   'ma60_state': 'over',
#   'ma60_no': 3,
#   'no': 1,
#   'cnt': 6,
#   'state': 'red',
#   'begin': 23715.0,
#   'begin_idx': 69,
#   'max_close': 23715.0,
#   'min_close': 23695.0,
#   'max_idx': 1,
#   'min_idx': 6,
#   'max_up': 12.0,
#   'max_dn': 20.0,
#   'maxdn_idx1': 1,
#   'maxdn_idx2': 6,
#   'maxup_idx1': 2,
#   'maxup_idx2': 3,
#   'end': 23682.0,
#   'end_idx': 75,
#   'end_no': 0,
#   'diff': -33.0,
#   'ma60_state_end': 'under',
#   'idx': 61},
#  {'std_up': 0,
#   'std_dn': 0,
#   'std_up_list': [],
#   'std_dn_list': [],
#   'prod': 'HSI1101',
#   'date': datetime.datetime(2011, 1, 10, 0, 0),
#   'day_no': 5,
#   'ma60_state': 'under',
#   'ma60_no': 4,
#   'no': 1,
#   'cnt': 1,
#   'state': 'green',
#   'begin': 23682.0,
#   'begin_idx': 75,
#   'max_close': 23682.0,
#   'min_close': 23682.0,
#   'max_idx': 1,
#   'min_idx': 1,
#   'max_up': 0,
#   'max_dn': 0,
#   'end': 23719.0,
#   'end_idx': 76,
#   'end_no': 0,
#   'diff': -37.0,
#   'ma60_state_end': 'over',
#   'idx': 62},
#  {'std_up': 1,
#   'std_dn': 1,
#   'std_up_list': [{'diff': 37.0, 'idx': 76}],
#   'std_dn_list': [{'diff': -21.0, 'idx': 78}],
#   'prod': 'HSI1101',
#   'date': datetime.datetime(2011, 1, 10, 0, 0),
#   'day_no': 6,
#   'ma60_state': 'over',
#   'ma60_no': 5,
#   'no': 1,
#   'cnt': 4,
#   'state': 'red',
#   'begin': 23719.0,
#   'begin_idx': 76,
#   'max_close': 23722.0,
#   'min_close': 23688.0,
#   'max_idx': 2,
#   'min_idx': 4,
#   'max_up': 3.0,
#   'max_dn': 34.0,
#   'maxup_idx1': 1,
#   'maxup_idx2': 2,
#   'maxdn_idx1': 2,
#   'maxdn_idx2': 4,
#   'end': 23685.0,
#   'end_idx': 80,
#   'end_no': 0,
#   'diff': -34.0,
#   'ma60_state_end': 'under',
#   'idx': 63},
#  {'std_up': 1,
#   'std_dn': 0,
#   'std_up_list': [{'diff': 19.0, 'idx': 86}],
#   'std_dn_list': [],
#   'prod': 'HSI1101',
#   'date': datetime.datetime(2011, 1, 10, 0, 0),
#   'day_no': 7,
#   'ma60_state': 'under',
#   'ma60_no': 5,
#   'no': 1,
#   'cnt': 10,
#   'state': 'green',
#   'begin': 23685.0,
#   'begin_idx': 80,
#   'max_close': 23709.0,
#   'min_close': 23675.0,
#   'max_idx': 10,
#   'min_idx': 6,
#   'max_up': 34.0,
#   'max_dn': 27.0,
#   'maxup_idx1': 6,
#   'maxup_idx2': 10,
#   'maxdn_idx1': 4,
#   'maxdn_idx2': 6,
#   'end': 23723.0,
#   'end_idx': 90,
#   'end_no': 0,
#   'diff': -38.0,
#   'ma60_state_end': 'over',
#   'idx': 64},
#  {'std_up': 0,
#   'std_dn': 1,
#   'std_up_list': [],
#   'std_dn_list': [{'diff': -28.0, 'idx': 98}],
#   'prod': 'HSI1101',
#   'date': datetime.datetime(2011, 1, 10, 0, 0),
#   'day_no': 8,
#   'ma60_state': 'over',
#   'ma60_no': 6,
#   'no': 1,
#   'cnt': 9,
#   'state': 'red',
#   'begin': 23723.0,
#   'begin_idx': 90,
#   'max_close': 23726.0,
#   'min_close': 23683.0,
#   'max_idx': 2,
#   'min_idx': 9,
#   'max_up': 9.0,
#   'max_dn': 43.0,
#   'maxup_idx1': 3,
#   'maxup_idx2': 5,
#   'maxdn_idx1': 2,
#   'maxdn_idx2': 9,
#   'end': 23672.0,
#   'end_idx': 99,
#   'end_no': 0,
#   'diff': -51.0,
#   'ma60_state_end': 'under',
#   'idx': 65},
#  {'std_up': 0,
#   'std_dn': 0,
#   'std_up_list': [],
#   'std_dn_list': [],
#   'prod': 'HSI1101',
#   'date': datetime.datetime(2011, 1, 10, 0, 0),
#   'day_no': 9,
#   'ma60_state': 'under',
#   'ma60_no': 6,
#   'no': 1,
#   'cnt': 10,
#   'state': 'green',
#   'begin': 23672.0,
#   'begin_idx': 99,
#   'max_close': 23708.0,
#   'min_close': 23672.0,
#   'max_idx': 10,
#   'min_idx': 1,
#   'max_up': 36.0,
#   'max_dn': 7.0,
#   'maxup_idx1': 1,
#   'maxup_idx2': 10,
#   'maxdn_idx1': 4,
#   'maxdn_idx2': 5,
#   'end': 23715.0,
#   'end_idx': 109,
#   'end_no': 0,
#   'diff': -43.0,
#   'ma60_state_end': 'over',
#   'idx': 66},
#  {'std_up': 0,
#   'std_dn': 0,
#   'std_up_list': [],
#   'std_dn_list': [],
#   'prod': 'HSI1101',
#   'date': datetime.datetime(2011, 1, 10, 0, 0),
#   'day_no': 10,
#   'ma60_state': 'over',
#   'ma60_no': 7,
#   'no': 1,
#   'cnt': 5,
#   'state': 'red',
#   'begin': 23715.0,
#   'begin_idx': 109,
#   'max_close': 23715.0,
#   'min_close': 23693.0,
#   'max_idx': 1,
#   'min_idx': 5,
#   'max_up': 0,
#   'max_dn': 22.0,
#   'maxdn_idx1': 1,
#   'maxdn_idx2': 5,
#   'end': 23686.0,
#   'end_idx': 114,
#   'end_no': 0,
#   'diff': -29.0,
#   'ma60_state_end': 'under',
#   'idx': 67},
#  {'std_up': 0,
#   'std_dn': 1,
#   'std_up_list': [],
#   'std_dn_list': [{'diff': -19.0, 'idx': 125}],
#   'prod': 'HSI1101',
#   'date': datetime.datetime(2011, 1, 10, 0, 0),
#   'day_no': 11,
#   'ma60_state': 'under',
#   'ma60_no': 7,
#   'no': 1,
#   'cnt': 39,
#   'state': 'green',
#   'begin': 23686.0,
#   'begin_idx': 114,
#   'max_close': 23703.0,
#   'min_close': 23656.0,
#   'max_idx': 11,
#   'min_idx': 17,
#   'max_up': 30.0,
#   'max_dn': 47.0,
#   'maxdn_idx1': 11,
#   'maxdn_idx2': 17,
#   'maxup_idx1': 17,
#   'maxup_idx2': 26,
#   'end': 23689.0,
#   'end_idx': 153,
#   'end_no': 0,
#   'diff': -3.0,
#   'ma60_state_end': 'over',
#   'idx': 68},
#  {'std_up': 0,
#   'std_dn': 0,
#   'std_up_list': [],
#   'std_dn_list': [],
#   'prod': 'HSI1101',
#   'date': datetime.datetime(2011, 1, 10, 0, 0),
#   'day_no': 12,
#   'ma60_state': 'over',
#   'ma60_no': 9,
#   'no': 1,
#   'cnt': 12,
#   'state': 'red',
#   'begin': 23689.0,
#   'begin_idx': 153,
#   'max_close': 23696.0,
#   'min_close': 23682.0,
#   'max_idx': 8,
#   'min_idx': 11,
#   'max_up': 7.0,
#   'max_dn': 14.0,
#   'maxup_idx1': 1,
#   'maxup_idx2': 8,
#   'maxdn_idx1': 8,
#   'maxdn_idx2': 11,
#   'end': 23613.0,
#   'end_idx': 165,
#   'end_no': 0,
#   'diff': -76.0,
#   'ma60_state_end': 'under',
#   'idx': 69},
#  {'std_up': 5,
#   'std_dn': 5,
#   'std_up_list': [{'diff': 33.0, 'idx': 169},
#    {'diff': 24.0, 'idx': 185},
#    {'diff': 33.0, 'idx': 226},
#    {'diff': 14.0, 'idx': 235},
#    {'diff': 20.0, 'idx': 241}],
#   'std_dn_list': [{'diff': -27.0, 'idx': 165},
#    {'diff': -75.0, 'idx': 168},
#    {'diff': -32.0, 'idx': 170},
#    {'diff': -35.0, 'idx': 171},
#    {'diff': -19.0, 'idx': 229}],
#   'prod': 'HSI1101',
#   'date': datetime.datetime(2011, 1, 10, 0, 0),
#   'day_no': 13,
#   'ma60_state': 'under',
#   'ma60_no': 10,
#   'no': 1,
#   'cnt': 92,
#   'state': 'green',
#   'begin': 23613.0,
#   'begin_idx': 165,
#   'max_close': 23621.0,
#   'min_close': 23496.0,
#   'max_idx': 2,
#   'min_idx': 76,
#   'max_up': 56.0,
#   'max_dn': 125.0,
#   'maxup_idx1': 13,
#   'maxup_idx2': 33,
#   'maxdn_idx1': 2,
#   'maxdn_idx2': 76,
#   'end': 23528.0,
#   'end_idx': 257,
#   'end_no': 0,
#   'diff': 85.0,
#   'ma60_state_end': 'over',
#   'idx': 70},
#  {'std_up': 0,
#   'std_dn': 0,
#   'std_up_list': [],
#   'std_dn_list': [],
#   'prod': 'HSI1101',
#   'date': datetime.datetime(2011, 1, 10, 0, 0),
#   'day_no': 14,
#   'ma60_state': 'over',
#   'ma60_no': 11,
#   'no': 1,
#   'cnt': 14,
#   'state': 'red',
#   'begin': 23528.0,
#   'begin_idx': 257,
#   'max_close': 23531.0,
#   'min_close': 23509.0,
#   'max_idx': 2,
#   'min_idx': 11,
#   'max_up': 14.0,
#   'max_dn': 22.0,
#   'maxup_idx1': 11,
#   'maxup_idx2': 13,
#   'maxdn_idx1': 2,
#   'maxdn_idx2': 11,
#   'end': 23517.0,
#   'end_idx': 271,
#   'end_no': 0,
#   'diff': -11.0,
#   'ma60_state_end': 'under',
#   'idx': 71},
#  {'begin': 23570.0,
#   'state': 'red',
#   'ma60_state': 'over',
#   'ma60_no': 0,
#   'no': 0,
#   'begin_idx': 0,
#   'cnt': 24,
#   'std_up': 2,
#   'std_dn': 4,
#   'day_no': 0,
#   'std_up_list': [{'diff': 27.0, 'idx': 1}, {'diff': 19.0, 'idx': 5}],
#   'std_dn_list': [{'diff': -15.0, 'idx': 0},
#    {'diff': -15.0, 'idx': 17},
#    {'diff': -17.0, 'idx': 19},
#    {'diff': -20.0, 'idx': 20}],
#   'max_close': 23643.0,
#   'min_close': 23570.0,
#   'max_up': 73.0,
#   'max_dn': 73.0,
#   'max_idx': 12,
#   'min_idx': 1,
#   'date': datetime.datetime(2011, 1, 11, 0, 0),
#   'maxup_idx1': 1,
#   'maxup_idx2': 12,
#   'maxdn_idx1': 12,
#   'maxdn_idx2': 22,
#   'end': 23528.0,
#   'end_idx': 23,
#   'end_no': 0,
#   'diff': -42.0,
#   'ma60_state_end': 'under',
#   'idx': 72},
#  {'std_up': 3,
#   'std_dn': 1,
#   'std_up_list': [{'diff': 17.0, 'idx': 24},
#    {'diff': 18.0, 'idx': 28},
#    {'diff': 16.0, 'idx': 31}],
#   'std_dn_list': [{'diff': -44.0, 'idx': 23}],
#   'prod': 'HSI1101',
#   'date': datetime.datetime(2011, 1, 11, 0, 0),
#   'day_no': 1,
#   'ma60_state': 'under',
#   'ma60_no': 2,
#   'no': 1,
#   'cnt': 12,
#   'state': 'green',
#   'begin': 23528.0,
#   'begin_idx': 23,
#   'max_close': 23590.0,
#   'min_close': 23528.0,
#   'max_idx': 12,
#   'min_idx': 1,
#   'max_up': 62.0,
#   'max_dn': 6.0,
#   'maxup_idx1': 1,
#   'maxup_idx2': 12,
#   'maxdn_idx1': 6,
#   'maxdn_idx2': 7,
#   'end': 23612.0,
#   'end_idx': 35,
#   'end_no': 0,
#   'diff': -84.0,
#   'ma60_state_end': 'over',
#   'idx': 73},
#  {'std_up': 1,
#   'std_dn': 2,
#   'std_up_list': [{'diff': 21.0, 'idx': 35}],
#   'std_dn_list': [{'diff': -24.0, 'idx': 41}, {'diff': -21.0, 'idx': 45}],
#   'prod': 'HSI1101',
#   'date': datetime.datetime(2011, 1, 11, 0, 0),
#   'day_no': 2,
#   'ma60_state': 'over',
#   'ma60_no': 2,
#   'no': 1,
#   'cnt': 11,
#   'state': 'red',
#   'begin': 23612.0,
#   'begin_idx': 35,
#   'max_close': 23618.0,
#   'min_close': 23569.0,
#   'max_idx': 3,
#   'min_idx': 11,
#   'max_up': 13.0,
#   'max_dn': 49.0,
#   'maxdn_idx1': 3,
#   'maxdn_idx2': 11,
#   'maxup_idx1': 2,
#   'maxup_idx2': 3,
#   'end': 23572.0,
#   'end_idx': 46,
#   'end_no': 0,
#   'diff': -40.0,
# ...
#   'cnt': 11,
#   'state': 'green',
#   'begin': 22941.0,
#   'begin_idx': 143,
#   'max_close': 22957.0,
#   'min_close': 22920.0,
#   'max_idx': 10,
#   'min_idx': 6,
#   'max_up': 37.0,
#   'max_dn': 24.0,
#   'maxup_idx1': 6,
#   'maxup_idx2': 10,
#   'maxdn_idx1': 2,
#   'maxdn_idx2': 6,
#   'end': 22955.0,
#   'end_idx': 154,
#   'end_no': 0,
#   'diff': -14.0,
#   'ma60_state_end': 'over',
#   'idx': 976},
#  {'std_up': 7,
#   'std_dn': 4,
#   'std_up_list': [{'diff': 11.0, 'idx': 161},
#    {'diff': 12.0, 'idx': 166},
#    {'diff': 16.0, 'idx': 169},
#    {'diff': 19.0, 'idx': 172},
#    {'diff': 20.0, 'idx': 184},
#    {'diff': 15.0, 'idx': 185},
#    {'diff': 16.0, 'idx': 188}],
#   'std_dn_list': [{'diff': -20.0, 'idx': 174},
#    {'diff': -22.0, 'idx': 189},
#    {'diff': -15.0, 'idx': 199},
#    {'diff': -22.0, 'idx': 201}],
#   'prod': 'HSI1105',
#   'date': datetime.datetime(2011, 5, 6, 0, 0),
#   'day_no': 9,
#   'ma60_state': 'over',
#   'ma60_no': 13,
#   'no': 1,
#   'cnt': 49,
#   'state': 'red',
#   'begin': 22955.0,
#   'begin_idx': 154,
#   'max_close': 23045.0,
#   'min_close': 22941.0,
#   'max_idx': 32,
#   'min_idx': 7,
#   'max_up': 104.0,
#   'max_dn': 56.0,
#   'maxup_idx1': 7,
#   'maxup_idx2': 32,
#   'maxdn_idx1': 32,
#   'maxdn_idx2': 49,
#   'end': 22975.0,
#   'end_idx': 203,
#   'end_no': 0,
#   'diff': 20.0,
#   'ma60_state_end': 'under',
#   'idx': 977},
#  {'std_up': 1,
#   'std_dn': 0,
#   'std_up_list': [{'diff': 16.0, 'idx': 219}],
#   'std_dn_list': [],
#   'prod': 'HSI1105',
#   'date': datetime.datetime(2011, 5, 6, 0, 0),
#   'day_no': 10,
#   'ma60_state': 'under',
#   'ma60_no': 14,
#   'no': 1,
#   'cnt': 18,
#   'state': 'green',
#   'begin': 22975.0,
#   'begin_idx': 203,
#   'max_close': 23017.0,
#   'min_close': 22969.0,
#   'max_idx': 18,
#   'min_idx': 10,
#   'max_up': 48.0,
#   'max_dn': 24.0,
#   'maxup_idx1': 10,
#   'maxup_idx2': 18,
#   'maxdn_idx1': 8,
#   'maxdn_idx2': 10,
#   'end': 23020.0,
#   'end_idx': 221,
#   'end_no': 0,
#   'diff': -45.0,
#   'ma60_state_end': 'over',
#   'idx': 978},
#  {'std_up': 0,
#   'std_dn': 0,
#   'std_up_list': [],
#   'std_dn_list': [],
#   'prod': 'HSI1105',
#   'date': datetime.datetime(2011, 5, 6, 0, 0),
#   'day_no': 11,
#   'ma60_state': 'over',
#   'ma60_no': 16,
#   'no': 1,
#   'cnt': 19,
#   'state': 'red',
#   'begin': 23020.0,
#   'begin_idx': 221,
#   'max_close': 23025.0,
#   'min_close': 22995.0,
#   'max_idx': 4,
#   'min_idx': 11,
#   'max_up': 25.0,
#   'max_dn': 30.0,
#   'maxdn_idx1': 4,
#   'maxdn_idx2': 11,
#   'maxup_idx1': 11,
#   'maxup_idx2': 16,
#   'end': 22983.0,
#   'end_idx': 240,
#   'end_no': 0,
#   'diff': -37.0,
#   'ma60_state_end': 'under',
#   'idx': 979},
#  {'std_up': 1,
#   'std_dn': 1,
#   'std_up_list': [{'diff': 15.0, 'idx': 246}],
#   'std_dn_list': [{'diff': -15.0, 'idx': 240}],
#   'prod': 'HSI1105',
#   'date': datetime.datetime(2011, 5, 6, 0, 0),
#   'day_no': 12,
#   'ma60_state': 'under',
#   'ma60_no': 17,
#   'no': 1,
#   'cnt': 13,
#   'state': 'green',
#   'begin': 22983.0,
#   'begin_idx': 240,
#   'max_close': 23009.0,
#   'min_close': 22976.0,
#   'max_idx': 13,
#   'min_idx': 2,
#   'max_up': 33.0,
#   'max_dn': 12.0,
#   'maxdn_idx1': 7,
#   'maxdn_idx2': 11,
#   'maxup_idx1': 2,
#   'maxup_idx2': 13,
#   'end': 23016.0,
#   'end_idx': 253,
#   'end_no': 0,
#   'diff': -33.0,
#   'ma60_state_end': 'over',
#   'idx': 980},
#  {'std_up': 0,
#   'std_dn': 0,
#   'std_up_list': [],
#   'std_dn_list': [],
#   'prod': 'HSI1105',
#   'date': datetime.datetime(2011, 5, 6, 0, 0),
#   'day_no': 13,
#   'ma60_state': 'over',
#   'ma60_no': 19,
#   'no': 1,
#   'cnt': 9,
#   'state': 'red',
#   'begin': 23016.0,
#   'begin_idx': 253,
#   'max_close': 23023.0,
#   'min_close': 22992.0,
#   'max_idx': 3,
#   'min_idx': 8,
#   'max_up': 9.0,
#   'max_dn': 31.0,
#   'maxdn_idx1': 3,
#   'maxdn_idx2': 8,
#   'maxup_idx1': 2,
#   'maxup_idx2': 3,
#   'end': 22989.0,
#   'end_idx': 262,
#   'end_no': 0,
#   'diff': -27.0,
#   'ma60_state_end': 'under',
#   'idx': 981},
#  {'std_up': 3,
#   'std_dn': 2,
#   'std_up_list': [{'diff': 20.0, 'idx': 265},
#    {'diff': 31.0, 'idx': 293},
#    {'diff': 18.0, 'idx': 295}],
#   'std_dn_list': [{'diff': -16.0, 'idx': 276}, {'diff': -20.0, 'idx': 285}],
#   'prod': 'HSI1105',
#   'date': datetime.datetime(2011, 5, 6, 0, 0),
#   'day_no': 14,
#   'ma60_state': 'under',
#   'ma60_no': 19,
#   'no': 1,
#   'cnt': 40,
#   'state': 'green',
#   'begin': 22989.0,
#   'begin_idx': 262,
#   'max_close': 23003.0,
#   'min_close': 22950.0,
#   'max_idx': 5,
#   'min_idx': 31,
#   'max_up': 42.0,
#   'max_dn': 53.0,
#   'maxdn_idx1': 5,
#   'maxdn_idx2': 31,
#   'maxup_idx1': 31,
#   'maxup_idx2': 34,
#   'end': 22995.0,
#   'end_idx': 302,
#   'end_no': 0,
#   'diff': -6.0,
#   'ma60_state_end': 'over',
#   'idx': 982},
#  {'std_up': 0,
#   'std_dn': 0,
#   'std_up_list': [],
#   'std_dn_list': [],
#   'prod': 'HSI1105',
#   'date': datetime.datetime(2011, 5, 6, 0, 0),
#   'day_no': 15,
#   'ma60_state': 'over',
#   'ma60_no': 25,
#   'no': 1,
#   'cnt': 3,
#   'state': 'red',
#   'begin': 22995.0,
#   'begin_idx': 302,
#   'max_close': 22995.0,
#   'min_close': 22972.0,
#   'max_idx': 1,
#   'min_idx': 3,
#   'max_up': 0,
#   'max_dn': 23.0,
#   'maxdn_idx1': 1,
#   'maxdn_idx2': 3,
#   'end': 22963.0,
#   'end_idx': 305,
#   'end_no': 0,
#   'diff': -32.0,
#   'ma60_state_end': 'under',
#   'idx': 983},
#  {'std_up': 0,
#   'std_dn': 0,
#   'std_up_list': [],
#   'std_dn_list': [],
#   'prod': 'HSI1105',
#   'date': datetime.datetime(2011, 5, 6, 0, 0),
#   'day_no': 16,
#   'ma60_state': 'under',
#   'ma60_no': 25,
#   'no': 1,
#   'cnt': 5,
#   'state': 'green',
#   'begin': 22963.0,
#   'begin_idx': 305,
#   'max_close': 22985.0,
#   'min_close': 22963.0,
#   'max_idx': 5,
#   'min_idx': 1,
#   'max_up': 22.0,
#   'max_dn': 3.0,
#   'maxup_idx1': 1,
#   'maxup_idx2': 5,
#   'maxdn_idx1': 3,
#   'maxdn_idx2': 4,
#   'end': 22996.0,
#   'end_idx': 310,
#   'end_no': 0,
#   'diff': -33.0,
#   'ma60_state_end': 'over',
#   'idx': 984},
#  {'std_up': 1,
#   'std_dn': 0,
#   'std_up_list': [{'diff': 16.0, 'idx': 314}],
#   'std_dn_list': [],
#   'prod': 'HSI1105',
#   'date': datetime.datetime(2011, 5, 6, 0, 0),
#   'day_no': 17,
#   'ma60_state': 'over',
#   'ma60_no': 26,
#   'no': 1,
#   'cnt': 13,
#   'state': 'red',
#   'begin': 22996.0,
#   'begin_idx': 310,
#   'max_close': 22996.0,
#   'min_close': 22977.0,
#   'max_idx': 1,
#   'min_idx': 12,
#   'max_up': 16.0,
#   'max_dn': 19.0,
#   'maxdn_idx1': 1,
#   'maxdn_idx2': 12,
#   'maxup_idx1': 4,
#   'maxup_idx2': 5,
#   'end': 22978.0,
#   'end_idx': 323,
#   'end_no': 0,
#   'diff': -18.0,
#   'ma60_state_end': 'under',
#   'idx': 985},
#  {'std_up': 0,
#   'std_dn': 0,
#   'std_up_list': [],
#   'std_dn_list': [],
#   'prod': 'HSI1105',
#   'date': datetime.datetime(2011, 5, 6, 0, 0),
#   'day_no': 18,
#   'ma60_state': 'under',
#   'ma60_no': 27,
#   'no': 1,
#   'cnt': 7,
#   'state': 'green',
#   'begin': 22978.0,
#   'begin_idx': 323,
#   'max_close': 22980.0,
#   'min_close': 22970.0,
#   'max_idx': 2,
#   'min_idx': 4,
#   'max_up': 9.0,
#   'max_dn': 10.0,
#   'maxup_idx1': 4,
#   'maxup_idx2': 6,
#   'maxdn_idx1': 2,
#   'maxdn_idx2': 4,
#   'end': 22970.0,
#   'end_idx': 330,
#   'end_no': 1,
#   'diff': 8.0,
#   'ma60_state_end': 'under',
#   'idx': 986},
#  {'begin': 23050.0,
#   'state': 'red',
#   'ma60_state': 'over',
#   'ma60_no': 0,
#   'no': 0,
#   'begin_idx': 0,
#   'cnt': 108,
#   'std_up': 8,
#   'std_dn': 3,
#   'day_no': 0,
#   'std_up_list': [{'diff': 15.0, 'idx': 4},
#    {'diff': 16.0, 'idx': 15},
#    {'diff': 25.0, 'idx': 21},
#    {'diff': 17.0, 'idx': 22},
#    {'diff': 31.0, 'idx': 28},
#    {'diff': 27.0, 'idx': 40},
#    {'diff': 17.0, 'idx': 66},
#    {'diff': 26.0, 'idx': 67}],
#   'std_dn_list': [{'diff': -27.0, 'idx': 16},
#    {'diff': -19.0, 'idx': 34},
#    {'diff': -24.0, 'idx': 76}],
#   'max_close': 23222.0,
#   'min_close': 23040.0,
#   'max_up': 182.0,
#   'max_dn': 43.0,
#   'max_idx': 100,
#   'min_idx': 3,
#   'date': datetime.datetime(2011, 5, 9, 0, 0),
#   'maxdn_idx1': 42,
#   'maxdn_idx2': 47,
#   'maxup_idx1': 3,
#   'maxup_idx2': 100,
#   'end': 23188.0,
#   'end_idx': 107,
#   'end_no': 0,
#   'diff': 138.0,
#   'ma60_state_end': 'over',
#   'idx': 987},
#  {'std_up': 0,
#   'std_dn': 0,
#   'std_up_list': [],
#   'std_dn_list': [],
#   'prod': 'HSI1105',
#   'date': datetime.datetime(2011, 5, 9, 0, 0),
#   'day_no': 1,
#   'ma60_state': 'over',
#   'ma60_no': 0,
#   'no': 1,
#   'cnt': 14,
#   'state': 'green',
#   'begin': 23188.0,
#   'begin_idx': 107,
#   'max_close': 23201.0,
#   'min_close': 23184.0,
#   'max_idx': 6,
#   'min_idx': 3,
#   'max_up': 17.0,
#   'max_dn': 15.0,
#   'maxup_idx1': 3,
#   'maxup_idx2': 6,
#   'maxdn_idx1': 6,
#   'maxdn_idx2': 8,
#   'end': 23213.0,
#   'end_idx': 121,
#   'end_no': 1,
#   'diff': -25.0,
#   'ma60_state_end': 'over',
#   'idx': 988},
#  {'std_up': 0,
#   'std_dn': 1,
#   'std_up_list': [],
#   'std_dn_list': [{'diff': -17.0, 'idx': 131}],
#   'prod': 'HSI1105',
#   'date': datetime.datetime(2011, 5, 9, 0, 0),
#   'day_no': 2,
#   'ma60_state': 'over',
#   'ma60_no': 0,
#   'no': 1,
#   'cnt': 13,
#   'state': 'red',
#   'begin': 23213.0,
#   'begin_idx': 121,
#   'max_close': 23215.0,
#   'min_close': 23193.0,
#   'max_idx': 2,
#   'min_idx': 11,
#   'max_up': 6.0,
#   'max_dn': 22.0,
#   'maxup_idx1': 5,
#   'maxup_idx2': 8,
#   'maxdn_idx1': 2,
#   'maxdn_idx2': 11,
#   'end': 23196.0,
#   'end_idx': 134,
#   'end_no': 1,
#   'diff': -17.0,
#   'ma60_state_end': 'over',
#   'idx': 989},
#  {'std_up': 0,
#   'std_dn': 2,
#   'std_up_list': [],
#   'std_dn_list': [{'diff': -10.0, 'idx': 143}, {'diff': -10.0, 'idx': 144}],
#   'prod': 'HSI1105',
#   'date': datetime.datetime(2011, 5, 9, 0, 0),
#   'day_no': 3,
#   'ma60_state': 'over',
#   'ma60_no': 0,
#   'no': 2,
#   'cnt': 24,
#   'state': 'green',
#   'begin': 23196.0,
#   'begin_idx': 134,
#   'max_close': 23202.0,
#   'min_close': 23179.0,
#   'max_idx': 5,
#   'min_idx': 12,
#   'max_up': 20.0,
#   'max_dn': 23.0,
#   'maxdn_idx1': 5,
#   'maxdn_idx2': 12,
#   'maxup_idx1': 12,
#   'maxup_idx2': 23,
#   'end': 23203.0,
#   'end_idx': 158,
#   'end_no': 0,
#   'diff': -7.0,
#   'ma60_state_end': 'over',
#   'idx': 990},
#  {'std_up': 1,
#   'std_dn': 1,
#   'std_up_list': [{'diff': 9.0, 'idx': 165}],
#   'std_dn_list': [{'diff': -9.0, 'idx': 163}],
#   'prod': 'HSI1105',
#   'date': datetime.datetime(2011, 5, 9, 0, 0),
#   'day_no': 4,
#   'ma60_state': 'over',
#   'ma60_no': 3,
#   'no': 1,
#   'cnt': 8,
#   'state': 'red',
#   'begin': 23203.0,
#   'begin_idx': 158,
#   'max_close': 23211.0,
#   'min_close': 23192.0,
#   'max_idx': 3,
#   'min_idx': 7,
#   'max_up': 8.0,
#   'max_dn': 19.0,
#   'maxup_idx1': 1,
#   'maxup_idx2': 3,
#   'maxdn_idx1': 3,
#   'maxdn_idx2': 7,
#   'end': 23183.0,
#   'end_idx': 166,
#   'end_no': 0,
#   'diff': -20.0,
#   'ma60_state_end': 'under',
#   'idx': 991},
#  {'std_up': 1,
#   'std_dn': 2,
#   'std_up_list': [{'diff': 11.0, 'idx': 180}],
#   'std_dn_list': [{'diff': -15.0, 'idx': 166}, {'diff': -12.0, 'idx': 168}],
#   'prod': 'HSI1105',
#   'date': datetime.datetime(2011, 5, 9, 0, 0),
#   'day_no': 5,
#   'ma60_state': 'under',
#   'ma60_no': 5,
#   'no': 1,
#   'cnt': 15,
#   'state': 'green',
#   'begin': 23183.0,
#   'begin_idx': 166,
#   'max_close': 23200.0,
#   'min_close': 23173.0,
#   'max_idx': 15,
#   'min_idx': 5,
#   'max_up': 27.0,
#   'max_dn': 15.0,
#   'maxup_idx1': 5,
#   'maxup_idx2': 15,
#   'maxdn_idx1': 2,
#   'maxdn_idx2': 5,
#   'end': 23204.0,
#   'end_idx': 181,
#   'end_no': 0,
#   'diff': -21.0,
#   'ma60_state_end': 'over',
#   'idx': 992},
#  {'std_up': 0,
#   'std_dn': 0,
#   'std_up_list': [],
#   'std_dn_list': [],
#   'prod': 'HSI1105',
#   'date': datetime.datetime(2011, 5, 9, 0, 0),
#   'day_no': 6,
#   'ma60_state': 'over',
#   'ma60_no': 6,
#   'no': 1,
#   'cnt': 5,
#   'state': 'red',
#   'begin': 23204.0,
#   'begin_idx': 181,
#   'max_close': 23204.0,
#   'min_close': 23188.0,
#   'max_idx': 1,
#   'min_idx': 5,
#   'max_up': 0,
#   'max_dn': 16.0,
#   'maxdn_idx1': 1,
#   'maxdn_idx2': 5,
#   'end': 23171.0,
#   'end_idx': 186,
#   'end_no': 0,
#   'diff': -33.0,
#   'ma60_state_end': 'under',
#   'idx': 993},
#  {'std_up': 3,
#   'std_dn': 6,
#   'std_up_list': [{'diff': 15.0, 'idx': 213},
#    {'diff': 12.0, 'idx': 220},
#    {'diff': 13.0, 'idx': 228}],
#   'std_dn_list': [{'diff': -15.0, 'idx': 186},
#    {'diff': -13.0, 'idx': 187},
#    {'diff': -10.0, 'idx': 203},
#    {'diff': -23.0, 'idx': 208},
#    {'diff': -23.0, 'idx': 209},
#    {'diff': -22.0, 'idx': 212}],
#   'prod': 'HSI1105',
#   'date': datetime.datetime(2011, 5, 9, 0, 0),
#   'day_no': 7,
#   'ma60_state': 'under',
#   'ma60_no': 7,
#   'no': 1,
#   'cnt': 68,
#   'state': 'green',
#   'begin': 23171.0,
#   'begin_idx': 186,
#   'max_close': 23171.0,
#   'min_close': 23069.0,
#   'max_idx': 1,
#   'min_idx': 42,
#   'max_up': 34.0,
#   'max_dn': 102.0,
#   'maxdn_idx1': 1,
#   'maxdn_idx2': 42,
#   'maxup_idx1': 42,
#   'maxup_idx2': 54,
#   'end': 23113.0,
#   'end_idx': 254,
#   'end_no': 0,
#   'diff': 58.0,
#   'ma60_state_end': 'over',
#   'idx': 994},
#  {'std_up': 2,
#   'std_dn': 2,
#   'std_up_list': [{'diff': 13.0, 'idx': 254}, {'diff': 14.0, 'idx': 257}],
#   'std_dn_list': [{'diff': -10.0, 'idx': 287}, {'diff': -9.0, 'idx': 288}],
#   'prod': 'HSI1105',
#   'date': datetime.datetime(2011, 5, 9, 0, 0),
#   'day_no': 8,
#   'ma60_state': 'over',
#   'ma60_no': 7,
#   'no': 1,
#   'cnt': 36,
#   'state': 'red',
#   'begin': 23113.0,
#   'begin_idx': 254,
#   'max_close': 23138.0,
#   'min_close': 23107.0,
#   'max_idx': 15,
#   'min_idx': 22,
#   'max_up': 25.0,
#   'max_dn': 31.0,
#   'maxup_idx1': 1,
#   'maxup_idx2': 15,
#   'maxdn_idx1': 15,
#   'maxdn_idx2': 22,
#   'end': 23108.0,
#   'end_idx': 290,
#   'end_no': 0,
#   'diff': -5.0,
#   'ma60_state_end': 'under',
#   'idx': 995},
#  {'std_up': 1,
#   'std_dn': 0,
#   'std_up_list': [{'diff': 12.0, 'idx': 295}],
#   'std_dn_list': [],
#   'prod': 'HSI1105',
#   'date': datetime.datetime(2011, 5, 9, 0, 0),
#   'day_no': 9,
#   'ma60_state': 'under',
#   'ma60_no': 10,
#   'no': 1,
#   'cnt': 6,
#   'state': 'green',
#   'begin': 23108.0,
#   'begin_idx': 290,
#   'max_close': 23124.0,
#   'min_close': 23108.0,
#   'max_idx': 6,
#   'min_idx': 1,
#   'max_up': 16.0,
#   'max_dn': 2.0,
#   'maxup_idx1': 1,
#   'maxup_idx2': 6,
#   'maxdn_idx1': 2,
#   'maxdn_idx2': 3,
#   'end': 23139.0,
#   'end_idx': 296,
#   'end_no': 0,
#   'diff': -31.0,
#   'ma60_state_end': 'over',
#   'idx': 996},
#  {'std_up': 7,
#   'std_dn': 2,
#   'std_up_list': [{'diff': 15.0, 'idx': 296},
#    {'diff': 11.0, 'idx': 300},
#    {'diff': 18.0, 'idx': 303},
#    {'diff': 14.0, 'idx': 306},
#    {'diff': 12.0, 'idx': 310},
#    {'diff': 11.0, 'idx': 312},
#    {'diff': 11.0, 'idx': 324}],
#   'std_dn_list': [{'diff': -11.0, 'idx': 321}, {'diff': -25.0, 'idx': 329}],
#   'prod': 'HSI1105',
#   'date': datetime.datetime(2011, 5, 9, 0, 0),
#   'day_no': 10,
#   'ma60_state': 'over',
#   'ma60_no': 10,
#   'no': 1,
#   'cnt': 34,
#   'state': 'red',
#   'begin': 23139.0,
#   'begin_idx': 296,
#   'max_close': 23192.0,
#   'min_close': 23128.0,
#   'max_idx': 18,
#   'min_idx': 3,
#   'max_up': 64.0,
#   'max_dn': 32.0,
#   'maxdn_idx1': 18,
#   'maxdn_idx2': 34,
#   'maxup_idx1': 3,
#   'maxup_idx2': 18,
#   'end': 23160.0,
#   'end_idx': 330,
#   'end_no': 1,
#   'diff': 21.0,
#   'ma60_state_end': 'over',
#   'idx': 997},
#  {'begin': 23320.0,
#   'state': 'red',
#   'ma60_state': 'over',
#   'ma60_no': 0,
#   'no': 0,
#   'begin_idx': 0,
#   'cnt': 27,
#   'std_up': 3,
#   'std_dn': 5,
#   'day_no': 0,
#   'std_up_list': [{'diff': 19.0, 'idx': 1},
#    {'diff': 18.0, 'idx': 2},
#    {'diff': 39.0, 'idx': 7}],
#   'std_dn_list': [{'diff': -17.0, 'idx': 15},
#    {'diff': -18.0, 'idx': 16},
#    {'diff': -16.0, 'idx': 19},
#    {'diff': -19.0, 'idx': 22},
#    {'diff': -42.0, 'idx': 23}],
#   'max_close': 23404.0,
#   'min_close': 23262.0,
#   'max_up': 84.0,
#   'max_dn': 142.0,
#   'max_idx': 10,
#   'min_idx': 26,
#   'date': datetime.datetime(2011, 5, 11, 0, 0),
#   'maxup_idx1': 1,
#   'maxup_idx2': 10,
#   'maxdn_idx1': 10,
#   'maxdn_idx2': 26,
#   'end': 23278.0,
#   'end_idx': 26,
#   'end_no': 0,
#   'diff': -42.0,
#   'ma60_state_end': 'over',
#   'idx': 998},
#  {'std_up': 3,
#   'std_dn': 6,
#   'std_up_list': [{'diff': 20.0, 'idx': 39},
#    {'diff': 21.0, 'idx': 42},
#    {'diff': 31.0, 'idx': 72}],
#   'std_dn_list': [{'diff': -28.0, 'idx': 30},
#    {'diff': -25.0, 'idx': 37},
#    {'diff': -49.0, 'idx': 46},
#    {'diff': -34.0, 'idx': 47},
#    {'diff': -28.0, 'idx': 49},
#    {'diff': -43.0, 'idx': 52}],
#   'prod': 'HSI1105',
#   'date': datetime.datetime(2011, 5, 11, 0, 0),
#   'day_no': 1,
#   'ma60_state': 'over',
#   'ma60_no': 0,
#   'no': 1,
#   'cnt': 70,
#   'state': 'green',
#   'begin': 23278.0,
#   'begin_idx': 26,
#   'max_close': 23292.0,
#   'min_close': 23082.0,
#   'max_idx': 4,
#   'min_idx': 46,
#   'max_up': 52.0,
#   'max_dn': 210.0,
#   'maxup_idx1': 46,
#   'maxup_idx2': 60,
#   'maxdn_idx1': 4,
#   'maxdn_idx2': 46,
#   'end': 23133.0,
#   'end_idx': 96,
#   'end_no': 0,
#   'diff': 145.0,
#   'ma60_state_end': 'under',
#   'idx': 999},
#  ...]

# %%
bt=BT_Trade(hf)
bt.contract_all()
# Out:
# ---init-----
