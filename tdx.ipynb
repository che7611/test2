# %%
# %matplotlib inline

from pytdx.hq import TdxHq_API
from pytdx.params import TDXParams
import pymysql
import pandas as pd
import matplotlib.pyplot as plt
import scipy as sp
import numpy as np
import datetime as dt
from matplotlib.lines import TICKLEFT, TICKRIGHT, Line2D
from matplotlib.patches import Rectangle


api = TdxHq_API()
if api.connect('119.147.212.81', 7709):
    data1=api.get_history_minute_time_data(TDXParams.MARKET_SH, '600300', 20161209)
    print("OK")
# Out:
# OK

# %%
api.connect('119.147.212.81', 7709)
api.get_and_parse_block_info(TDXParams.BLOCK_SZ)
shList=api.get_security_list(1, 0)
sh_df=api.to_df(shList)
szList=api.get_security_list(0, 0)
sz_df=api.to_df(szList)
sz_df
# Out:
#        code  volunit  decimal_point    name     pre_close
# 0    395001      100              2    主板Ａ股  4.620000e+02
# 1    395002      100              2    主板Ｂ股  2.880000e+02
# 2    395003      100              2     中小板  9.290000e+02
# 3    395004      100              2     创业板  7.490000e+02
# 4    395005      100              2    存托凭证  5.877472e-39
# 5    395011      100              2    封闭基金  3.276850e+04
# 6    395012      100              2    ＬＯＦｓ  2.390000e+02
# 7    395013      100              2    ＥＴＦｓ  4.160000e+02
# 8    395014      100              2    分级基金  2.240000e+02
# 9    395021      100              2   可 转 债  7.400000e+01
# 10   395022      100              2     企业债  1.544000e+03
# 11   395024      100              2     公司债  5.940000e+02
# 12   395031      100              2      国债  3.401000e+03
# 13   395032      100              2    债券回购  2.640000e+02
# 14   395041      100              2    股票权证  5.877472e-39
# 15   395099      100              2   总 成 交  2.188000e+03
# 16   399001      100              2    深证成指  1.026770e+04
# 17   399002      100              2    深成指R  1.242040e+04
# 18   399003      100              2    成份Ｂ指  5.517952e+03
# 19   399004      100              2  深证100R  5.457659e+03
# 20   399005      100              2    中小板指  6.610066e+03
# 21   399006      100              2    创业板指  1.760892e+03
# 22   399007      100              2   深证300  4.320535e+03
# 23   399008      100              2   中小300  1.303750e+03
# 24   399009      100              2   深证200  4.194002e+03
# 25   399010      100              2   深证700  6.424696e+03
# 26   399011      100              2  深证1000  4.926386e+03
# 27   399012      100              2   创业300  2.591555e+03
# 28   399013      100              2    深市精选  4.652542e+03
# 29   399015      100              2    中小创新  2.105114e+03
# ..      ...      ...            ...     ...           ...
# 970  002167      100              2    东方锆业  7.530000e+00
# 971  002168      100              2    惠程科技  9.680000e+02
# 972  002169      100              2    智光电气  5.770000e+00
# 973  002170      100              2    芭田股份  4.500000e+00
# 974  002171      100              2    楚江新材  6.860000e+00
# 975  002172      100              2    澳洋健康  5.040000e+00
# 976  002173      100              2    创新医疗  2.800575e+02
# 977  002174      100              2    游族网络  2.509000e+01
# 978  002175      100              2    东方网络  5.900000e+00
# 979  002176      100              2    江特电机  6.280000e+00
# 980  002177      100              2    御银股份  6.140000e+00
# 981  002178      100              2    延华智能  4.910000e+00
# 982  002179      100              2    中航光电  1.840400e+02
# 983  002180      100              2     纳思达  3.113000e+01
# 984  002181      100              2   粤 传 媒  6.450000e+00
# 985  002182      100              2    云海金属  2.320450e+02
# 986  002183      100              2   怡 亚 通  5.900000e+00
# 987  002184      100              2    海得控制  1.160060e+03
# 988  002185      100              2    华天科技  5.990000e+00
# 989  002186      100              2   全 聚 德  1.400023e+03
# 990  002187      100              2    广百股份  3.760225e+02
# 991  002188      100              2   *ST巴士  4.470000e+00
# 992  002189      100              2    利达光电  2.889000e+01
# 993  002190      100              2   *ST集成  1.760000e+01
# 994  002191      100              2    劲嘉股份  1.944047e+03
# 995  002192      100              2    融捷股份  2.981000e+01
# 996  002193      100              2    如意集团  7.440450e+02
# 997  002194      100              2   *ST凡谷  1.496057e+03
# 998  002195      100              2    二三四五  6.460000e+00
# 999  002196      100              2    方正电机  6.270000e+00
#
# [1000 rows x 5 columns]

# %%
print(api.get_finance_info(0, '000001'))
# Out:
# OrderedDict([('market', 0), ('code', '000001'), ('liutongguben', 17170246250.0), ('province', 18), ('industry', 1), ('updated_date', 20190311), ('ipo_date', 19910403), ('zongguben', 17170411250.0), ('guojiagu', 1801990000.0), ('faqirenfarengu', 231890000000.0), ('farengu', 1057860000000.0), ('bgu', 0.0), ('hgu', 0.0), ('zhigonggu', 13899.999856948853), ('zongzichan', 34185920000000.0), ('liudongzichan', 0.0), ('gudingzichan', 108990000000.0), ('wuxingzichan', 47710000000.0), ('gudongrenshu', 369119.0), ('liudongfuzhai', 0.0), ('changqifuzhai', 0.0), ('zibengongjijin', 564650000000.0), ('jingzichan', 2400420000000.0), ('zhuyingshouru', 1167160000000.0), ('zhuyinglirun', 0.0), ('yingshouzhangkuan', 0.0), ('yingyelirun', 323050000000.0), ('touzishouyu', 91860000000.0), ('jingyingxianjinliu', -573230000000.0), ('zongxianjinliu', 230800000000.0), ('cunhuo', 0.0), ('lirunzonghe', 322310000000.0), ('shuihoulirun', 248180000000.0), ('jinglirun', 248180000000.0), ('weifenpeilirun', 950370000000.0), ('meigujingzichan', 12.819999694824219), ('baoliu2', 12.0)])

# %%
def GetAllHis(stock,mk=1):
    data=[]
    for i in range(10):
        data+=api.get_index_bars(9,mk,stock,(9-i)*800,800)
    df=api.to_df(data)
    return df

# %%
api.connect('119.147.212.81', 7709)
z500=GetAllHis('000905')
sh=GetAllHis('000001')
sh50=GetAllHis('000016')
hs300=GetAllHis('000300')
sz=GetAllHis('399001',mk=0)
sz05=GetAllHis('399005',mk=0)
sz06=GetAllHis('399006',mk=0)
print(len(z500),len(sh),len(sh50),len(hs300),len(sz),len(sz05),len(sz06))
# Out:
# 2968 6916 3705 3462 6861 3206 2148

# %%
cnt=3455
vv1=sh.tail(cnt)['close'].values
vv2=hs300['close'].values
vv1a=sz.tail(cnt)['close'].values
vv3=sh.tail(2961)['close'].values
vv4=z500['close'].values
vv5=sh.tail(3698)['close'].values
vv6=sh50['close'].values
vv7=sh.tail(6854)['close'].values
vv8=sz['close'].values
res=round(np.corrcoef(vv1,vv2)[0][1],3)
res1=round(np.corrcoef(vv3,vv4)[0][1],3)
res2=round(np.corrcoef(vv5,vv6)[0][1],3)
res3=round(np.corrcoef(vv7,vv8)[0][1],3)
res4=round(np.corrcoef(vv1a,vv2)[0][1],3)
print("sh:hs300 corr:",res)
print("sh:z500 corr:",res1)
print("sh:sh50 corr:",res2)
print("sh:sz corr:",res3)
print("sz:hs300 corr:",res4)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-acf06d8af2f4> in <module>()
#       9 vv7=sh.tail(6854)['close'].values
#      10 vv8=sz['close'].values
# ---> 11 res=round(np.corrcoef(vv1,vv2)[0][1],3)
#      12 res1=round(np.corrcoef(vv3,vv4)[0][1],3)
#      13 res2=round(np.corrcoef(vv5,vv6)[0][1],3)
#
# d:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\function_base.py in corrcoef(x, y, rowvar, bias, ddof)
#    3157         warnings.warn('bias and ddof have no effect and are deprecated',
#    3158                       DeprecationWarning, stacklevel=2)
# -> 3159     c = cov(x, y, rowvar)
#    3160     try:
#    3161         d = diag(c)
#
# d:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\function_base.py in cov(m, y, rowvar, bias, ddof, fweights, aweights)
#    3026         if not rowvar and y.shape[0] != 1:
#    3027             y = y.T
# -> 3028         X = np.vstack((X, y))
#    3029
#    3030     if ddof is None:
#
# d:\ProgramData\Anaconda3\lib\site-packages\numpy\core\shape_base.py in vstack(tup)
#     235
#     236     """
# --> 237     return _nx.concatenate([atleast_2d(_m) for _m in tup], 0)
#     238
#     239 def hstack(tup):
#
# ValueError: all the input array dimensions except for the concatenation axis must match exactly

# %%
fig = plt.figure(figsize=(30, 12))
ax = fig.add_subplot(111)
plt.plot(vv3,c='r')
plt.plot(vv4,c='b')
ax2 = ax.twinx()
plt.plot(vv4-vv3)

# %%
plt.plot(vv2-vv1);
plt.axhline((vv1-vv2).mean(), color="red", linestyle="--");
plt.xlabel("Time"); plt.ylabel("Price");
plt.legend(["Y-X", "Mean"]);

# %%
from statsmodels.tsa.stattools import adfuller

a3=vv2-vv1
adftest = adfuller(a3)#使用 adf 单位根检验平稳性 


result = pd.Series(adftest[0:4], index=['Test Statistic','p-value','Lags Used','Number of Observations Used'])


for key,value in adftest[4].items():
    result['Critical Value (%s)'%key] = value


print(result)
# Out:
# Test Statistic                   -1.466707
# p-value                           0.549912
# Lags Used                        26.000000
# Number of Observations Used    3428.000000
# Critical Value (1%)              -3.432259
# Critical Value (5%)              -2.862384
# Critical Value (10%)             -2.567219
# dtype: float64

# %%
# rolling_correlation_cn = 
import pandas as pd

rolling_correlation_cn.plot()
plt.xlabel('Day')
plt.ylabel('New 60-day Rolling Correlation')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-522-9e459e6685f1> in <module>()
#       2 import pandas as pd
#       3
# ----> 4 rolling_correlation_cn.plot()
#       5 plt.xlabel('Day')
#       6 plt.ylabel('New 60-day Rolling Correlation')
#
# NameError: name 'rolling_correlation_cn' is not defined

# %%
rolling_correlation_cn = pd.rolling_correlation_cn

# %%
rolling_correlation_cn = pd.rolling_correlation_cn

# %%
#------calc corrcoef 相关性
#匹配的K线个数
df1=sh
length=200
vv1=df1.tail(length)['close'].values
vv2=df1['close'].values
rows=len(vv2)

maxCorr=0

resList=[]
# dt1=dt.datetime.now
for i in range(0,rows-length*2):
    vv3=vv2[i:length+i]
    corr=round(np.corrcoef(vv1,vv3)[0][1],3)
    resList.append(corr)


df_corr=pd.DataFrame(resList)
df_corr.columns=['Corr']
df_corr.sort_values('Corr',ascending=False,inplace=True)

newList=[]
diff=60
for row in df_corr.iterrows():
    index=row[0]
    insert=True
    for i in newList:
        if i> index-diff and i< index+diff:
            insert=False
    if insert:
        newList.append(index)
        
df_res=df_corr.loc[newList]
df_res['datetime']=df_res.apply(lambda x:zs1.iloc[x.name]['datetime'],axis=1)
df_res.head(20)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-a493e7a03f63> in <module>()
#      33
#      34 df_res=df_corr.loc[newList]
# ---> 35 df_res['datetime']=df_res.apply(lambda x:zs1.iloc[x.name]['datetime'],axis=1)
#      36 df_res.head(20)
#
# d:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, broadcast, raw, reduce, args, **kwds)
#    4260                         f, axis,
#    4261                         reduce=reduce,
# -> 4262                         ignore_failures=ignore_failures)
#    4263             else:
#    4264                 return self._apply_broadcast(f, axis)
#
# d:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in _apply_standard(self, func, axis, ignore_failures, reduce)
#    4356             try:
#    4357                 for i, v in enumerate(series_gen):
# -> 4358                     results[i] = func(v)
#    4359                     keys.append(v.name)
#    4360             except Exception as e:
#
# <ipython-input-7-a493e7a03f63> in <lambda>(x)
#      33
#      34 df_res=df_corr.loc[newList]
# ---> 35 df_res['datetime']=df_res.apply(lambda x:zs1.iloc[x.name]['datetime'],axis=1)
#      36 df_res.head(20)
#
# NameError: ("name 'zs1' is not defined", 'occurred at index 3037')

# %%
fig = plt.figure(figsize=(30, 12))
ax = fig.add_subplot(111)
DrawIndex(3031,500,500)

# %%
add1=300
add2=0
df2=zs1.tail(500)
v1=1
DrawKK(df2,add1=add1,add2=add2,corr=v1,isSave=True,file="res/now.jpg")
# Out:
# <module 'matplotlib.pyplot' from 'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
def DrawIndex(ind,add1=0,add2=0):
#     index=ii
#     ind=newRec.index[index]
    if add1>ind:
        add1=ind
    begin=ind-add1
    end=begin+length+add2+add1
    df2=df1.iloc[begin:end]
    v1=df_res.loc[ind]['Corr']
#     print(newRec.iloc[index],v1)
    file="res/%s.jpg"%(ind)
    DrawKK(df2,add1=add1,add2=add2,corr=v1,file=file)

def DrawKK(aa,add1=0,add2=0,file='res/test.jpg',corr=0,isSave=False):
    fig = plt.figure(figsize=(30, 12))
    ax = fig.add_subplot(111)
    ax.clear()
    k_width = 50
    k_diff = 10
    kline = k_width + k_diff
    d=0
    rows=len(aa)
    if add1>0:
        ax.axvline((add1+1)*kline,ymax=1,c='b',ls='dashed')
    if add2>0:
        ax.axvline((rows-add2+1)*kline,ymax=1,c='b',ls='dashed')
    for i in aa.iterrows():
        d=d+1
        x = d * kline
        O = i[1]['open']
        C = i[1]['close']
        L = i[1]['low']
        H = i[1]['high']
        hh = abs(C - O)
        x1 = x + k_width / 2
        if C > O:
            a = False
            y = O
            cc = 'R'
            # 上影线 下影线
            line1 = Line2D((x1, x1), (C, H), color=cc)
            line2 = Line2D((x1, x1), (O, L), color=cc)

            ax.add_line(line1)
            ax.add_line(line2)
        else:
            a = True
            y = C
            cc = 'C'
            # 影线
            line = Line2D((x1, x1), (L, H), color=cc)
            ax.add_line(line)
        hh = abs(C - O)

        # K线实体
        rec = Rectangle((x, y), k_width, hh, fill=a, color=cc)
        ax.add_patch(rec)
    ax.grid()
    ax.autoscale_view()
    time1=aa.iloc[add1]['datetime']
    if add2==0:
        diff=-1
    else:
        diff=-add2-1
    time2=aa.iloc[diff]['datetime']
    title="%s--%s,Corr:%.3f" %(time1,time2,corr)
    plt.title(title, fontsize=20, color='r')
    if isSave:
        fig.savefig(file)
    return plt

# %%
class Analyse_CORR:
    def __init__(self,source,target):
        self.Data=source #数据源
        self.DataT=target
        self.Amount=len(target)  #分析的个数
        self.V1=target['close'].values #分析的数据集
        self.V2=source['close'].values #总数据集
        
    def corr(self):
        resList=[]
        vv1=self.V1
        vv2=self.V2
        rows=len(vv2)
        length=self.Amount
        for i in range(0,rows-length):
            vv3=vv2[i:length+i]
            corr=round(np.corrcoef(vv1,vv3)[0][1],3)
            resList.append(corr)
        diff=int(length*0.5)
        return self.fix_corr(resList,diff)
    
    def fix_corr(self,source,diff=60):
        df_corr=pd.DataFrame(source)
        df_corr.columns=['Corr']
        df_corr.sort_values('Corr',ascending=False,inplace=True)

        newList=[]
        for row in df_corr.iterrows():
            index=row[0]
            insert=True
            for i in newList:
                if i> index-diff and i< index+diff:
                    insert=False
                    break
            if insert:
                newList.append(index)

        df_res=df_corr.loc[newList]
        df_res['datetime']=df_res.apply(lambda x:self.Data.iloc[x.name]['datetime'],axis=1)
        self.DF_CORR=df_res
        return df_res
    
    #draw kline
    def DrawKK(self,aa,add1=0,add2=0,file='res/test.jpg',corr=0,isSave=False):
        fig = plt.figure(figsize=(30, 12))
        ax = fig.add_subplot(111)
        ax.clear()
        k_width = 50
        k_diff = 10
        kline = k_width + k_diff
        d=0
        rows=len(aa)
        if add1>0:
            ax.axvline((add1+1)*kline,ymax=1,c='b',ls='dashed')
        if add2>0:
            ax.axvline((rows-add2+1)*kline,ymax=1,c='b',ls='dashed')
        for i in aa.iterrows():
            d=d+1
            x = d * kline
            O = i[1]['open']
            C = i[1]['close']
            L = i[1]['low']
            H = i[1]['high']
            hh = abs(C - O)
            x1 = x + k_width / 2
            if C > O:
                a = False
                y = O
                cc = 'R'
                # 上影线 下影线
                line1 = Line2D((x1, x1), (C, H), color=cc)
                line2 = Line2D((x1, x1), (O, L), color=cc)

                ax.add_line(line1)
                ax.add_line(line2)
            else:
                a = True
                y = C
                cc = 'C'
                # 影线
                line = Line2D((x1, x1), (L, H), color=cc)
                ax.add_line(line)
            hh = abs(C - O)

            # K线实体
            rec = Rectangle((x, y), k_width, hh, fill=a, color=cc)
            ax.add_patch(rec)
        ax.grid()
        ax.autoscale_view()
        time1=aa.iloc[add1]['datetime']
        if add2==0:
            diff=-1
        else:
            diff=-add2-1
        time2=aa.iloc[diff]['datetime']
        title="%s--%s,Corr:%.3f" %(time1,time2,corr)
        plt.title(title, fontsize=20, color='r')
        if isSave:
            file="res/%d_%.7s.jpg"%(self.Amount,time1)
            fig.savefig(file)
        return plt
    
    def DrawIndex(self,ind,add1=0,add2=0,isSave=False):
        if add1>ind:
            add1=ind
        begin=ind-add1
        length=self.Amount
        end=begin+length+add2+add1
        df2=self.Data.iloc[begin:end]
        v1=self.DF_CORR.loc[ind]['Corr']
        file="res/%s.jpg"%(ind)
        self.DrawKK(df2,add1=add1,add2=add2,corr=v1,file=file,isSave=isSave)
        
    def DrawNo(self,no,add1=0,add2=0,isSave=False):
        index=self.DF_CORR.index[no]
        self.DrawIndex(index,add1,add2,isSave)

# %%
cnt=200
df_source=sh[0:-200]
df_target=sh.tail(cnt)
sa=Analyse_CORR(df_source,df_target)
dt1=dt.datetime.now()
sa.corr()
dt2=dt.datetime.now()
print(dt2-dt1)
sa.DF_CORR.head(20)
# Out:
# 0:00:00.975055
#        Corr          datetime
# 3037  0.890  2003-04-16 15:00
# 5228  0.872  2012-04-26 15:00
# 765   0.845  1993-12-17 15:00
# 360   0.829  1992-05-21 15:00
# 1943  0.792  1998-09-21 15:00
# 1204  0.772  1995-09-14 15:00
# 5604  0.753  2013-11-18 15:00
# 2121  0.725  1999-06-21 15:00
# 4678  0.698  2010-01-15 15:00
# 4314  0.663  2008-07-22 15:00
# 2855  0.592  2002-07-16 15:00
# 947   0.592  1994-09-07 15:00
# 3     0.577  1990-12-24 15:00
# 1606  0.563  1997-05-12 15:00
# 3436  0.554  2004-12-08 15:00
# 187   0.536  1991-09-12 15:00
# 6340  0.519  2016-11-22 15:00
# 2666  0.488  2001-09-21 15:00
# 6084  0.484  2015-11-05 15:00
# 3593  0.470  2005-08-03 15:00

# %%
sa.DrawNo(0,200,300)

# %%
sa.DrawNo(1,200,300)

# %%
sa.DrawNo(2,200,300)

# %%
sa.DF_CORR
# Out:
#        Corr          datetime
# 5222  0.879  2012-04-18 15:00
# 3031  0.863  2003-04-08 15:00
# 758   0.863  1993-12-08 15:00
# 360   0.771  1992-05-21 15:00
# 1197  0.762  1995-09-05 15:00
# 4675  0.752  2010-01-12 15:00
# 5604  0.711  2013-11-18 15:00
# 1936  0.701  1998-09-10 15:00
# 4276  0.692  2008-05-28 15:00
# 945   0.690  1994-09-05 15:00
# 2846  0.677  2002-07-03 15:00
# 1599  0.675  1997-04-29 15:00
# 3430  0.668  2004-11-30 15:00
# 2604  0.630  2001-06-27 15:00
# 5001  0.590  2011-05-20 15:00
# 2120  0.584  1999-06-18 15:00
# 6085  0.576  2015-11-06 15:00
# 561   0.540  1993-03-05 15:00
# 5414  0.538  2013-01-28 15:00
# 3301  0.462  2004-05-26 15:00
# 6340  0.417  2016-11-22 15:00
# 5984  0.397  2015-06-08 15:00
# 2     0.371  1990-12-21 15:00
# 4176  0.356  2007-12-26 15:00
# 180   0.355  1991-09-03 15:00
# 3593  0.277  2005-08-03 15:00
# 2379  0.256  2000-07-18 15:00
# 3754  0.190  2006-04-05 15:00
# 1824  0.150  1998-04-06 15:00
# 3201  0.126  2003-12-18 15:00
# 1394  0.113  1996-06-26 15:00
# 4855  0.090  2010-10-15 15:00
# 5704  0.073  2014-04-16 15:00
# 2704  0.058  2001-11-21 15:00
# 4550  0.006  2009-07-10 15:00
# 4076 -0.042  2007-08-01 15:00
# 4376 -0.092  2008-10-24 15:00
# 5112 -0.119  2011-11-02 15:00
# 3932 -0.121  2006-12-25 15:00
# 5804 -0.244  2014-09-09 15:00
# 2504 -0.248  2001-01-17 15:00
# 6236 -0.254  2016-06-20 15:00
# 6440 -0.255  2017-04-21 15:00
# 2278 -0.284  2000-02-21 15:00
# 1699 -0.330  1997-09-22 15:00
# 1499 -0.348  1996-11-25 15:00
# 1045 -0.419  1995-01-26 15:00
# 460  -0.592  1992-10-12 15:00
